# %%
# !pip -q install git+https://github.com/huggingface/transformers
# !pip install -q datasets loralib sentencepiece
# !pip -q install bitsandbytes accelerate
# !pip -q install langchain
# !pip install einops
# !pip install faiss-gpu
# !pip install --upgrade --quiet  langchain-community chromadb bs4 qdrant-client
# !pip install langchainhub

# !pip install --upgrade --quiet  wikipedia
# !pip install --upgrade --quiet  arxiv
# !pip install --upgrade --quiet  pymupdf

# !pip install xmltodict

# !pip install unstructured
# !pip install PyMuPDF
# !pip install pdfminer.six
# !pip install qdrant-client
# !pip install sentence_transformers
# !pip install pi_heif
# !pip install unstructured_inference
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 35.2 MB/s eta 0:00:00
#   Building wheel for transformers (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 13.8 MB/s eta 0:00:00
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.8.0)
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 9.2 MB/s eta 0:00:00
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.7.2
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 33.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 628.3/628.3 kB 34.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 48.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.2/267.2 kB 21.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 20.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 82.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 74.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 50.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.7/409.7 kB 30.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 57.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 75.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 31.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 26.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 101.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.6/442.6 kB 32.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.2/168.2 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.1 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.1 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 5.29.1 which is incompatible.
# transformers 4.48.0.dev0 requires tokenizers<0.22,>=0.21, but you have tokenizers 0.20.3 which is incompatible.
# Collecting langchainhub
#   Downloading langchainhub-0.1.21-py3-none-any.whl.metadata (659 bytes)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchainhub) (24.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchainhub) (2.32.3)
# Collecting types-requests<3.0.0.0,>=2.31.0.2 (from langchainhub)
#   Downloading types_requests-2.32.0.20241016-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchainhub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchainhub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchainhub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchainhub) (2024.8.30)
# Downloading langchainhub-0.1.21-py3-none-any.whl (5.2 kB)
# Downloading types_requests-2.32.0.20241016-py3-none-any.whl (15 kB)
# Installing collected packages: types-requests, langchainhub
# Successfully installed langchainhub-0.1.21 types-requests-2.32.0.20241016
#   Preparing metadata (setup.py) ... done
#   Building wheel for wikipedia (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 3.0 MB/s eta 0:00:00
#   Building wheel for sgmllib3k (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 95.2 MB/s eta 0:00:00
# Collecting xmltodict
#   Downloading xmltodict-0.14.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Downloading xmltodict-0.14.2-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.14.2
# Collecting unstructured
#   Downloading unstructured-0.16.10-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured) (5.2.0)
# Collecting filetype (from unstructured)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from unstructured) (5.3.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from unstructured) (3.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from unstructured) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from unstructured) (4.12.3)
# Collecting emoji (from unstructured)
#   Downloading emoji-2.14.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from unstructured) (0.6.7)
# Collecting python-iso639 (from unstructured)
#   Downloading python_iso639-2024.10.22-py3-none-any.whl.metadata (13 kB)
# Collecting langdetect (from unstructured)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 22.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from unstructured) (1.26.4)
# Collecting rapidfuzz (from unstructured)
#   Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: backoff in /usr/local/lib/python3.10/dist-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from unstructured) (4.12.2)
# Collecting unstructured-client (from unstructured)
#   Downloading unstructured_client-0.28.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from unstructured) (1.17.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from unstructured) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unstructured) (5.9.5)
# Collecting python-oxmsg (from unstructured)
#   Downloading python_oxmsg-0.0.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.10/dist-packages (from unstructured) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->unstructured) (2.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->unstructured) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib->unstructured) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured) (2024.9.11)
# Collecting olefile (from python-oxmsg->unstructured)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured) (2024.8.30)
# Collecting aiofiles>=24.1.0 (from unstructured-client->unstructured)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: cryptography>=3.1 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (43.0.3)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (0.2.0)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (0.28.0)
# Collecting jsonpath-python<2.0.0,>=1.0.6 (from unstructured-client->unstructured)
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (1.6.0)
# Collecting pydantic<2.10.0,>=2.9.2 (from unstructured-client->unstructured)
#   Downloading pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.4/149.4 kB 12.7 MB/s eta 0:00:00
# Collecting pypdf>=4.0 (from unstructured-client->unstructured)
#   Downloading pypdf-5.1.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (2.8.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->unstructured-client->unstructured) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.10.0,>=2.9.2->unstructured-client->unstructured) (0.7.0)
# Collecting pydantic-core==2.23.4 (from pydantic<2.10.0,>=2.9.2->unstructured-client->unstructured)
#   Downloading pydantic_core-2.23.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.22)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.2.2)
# Downloading unstructured-0.16.10-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 55.5 MB/s eta 0:00:00
# Downloading emoji-2.14.0-py3-none-any.whl (586 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.9/586.9 kB 25.2 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_iso639-2024.10.22-py3-none-any.whl (274 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.9/274.9 kB 22.7 MB/s eta 0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_oxmsg-0.0.1-py3-none-any.whl (31 kB)
# Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 58.0 MB/s eta 0:00:00
# Downloading unstructured_client-0.28.1-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.9/62.9 kB 4.6 MB/s eta 0:00:00
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Downloading pydantic-2.9.2-py3-none-any.whl (434 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.9/434.9 kB 33.4 MB/s eta 0:00:00
# Downloading pydantic_core-2.23.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 68.5 MB/s eta 0:00:00
# Downloading pypdf-5.1.0-py3-none-any.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 25.3 MB/s eta 0:00:00
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 10.8 MB/s eta 0:00:00
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=2f4fcfe9bb6fdb542963331161c61db2af90045736b0d6c5221ef8212ea47f89
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: filetype, rapidfuzz, python-magic, python-iso639, pypdf, pydantic-core, olefile, langdetect, jsonpath-python, emoji, aiofiles, python-oxmsg, pydantic, unstructured-client, unstructured
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.27.1
#     Uninstalling pydantic_core-2.27.1:
#       Successfully uninstalled pydantic_core-2.27.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.3
#     Uninstalling pydantic-2.10.3:
#       Successfully uninstalled pydantic-2.10.3
# Successfully installed aiofiles-24.1.0 emoji-2.14.0 filetype-1.2.0 jsonpath-python-1.0.6 langdetect-1.0.9 olefile-0.47 pydantic-2.9.2 pydantic-core-2.23.4 pypdf-5.1.0 python-iso639-2024.10.22 python-magic-0.4.27 python-oxmsg-0.0.1 rapidfuzz-3.10.1 unstructured-0.16.10 unstructured-client-0.28.1
# Requirement already satisfied: PyMuPDF in /usr/local/lib/python3.10/dist-packages (1.25.0)
# Collecting pdfminer.six
#   Downloading pdfminer.six-20240706-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six) (3.4.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.22)
# Downloading pdfminer.six-20240706-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 52.4 MB/s eta 0:00:00
# Installing collected packages: pdfminer.six
# Successfully installed pdfminer.six-20240706
# Requirement already satisfied: qdrant-client in /usr/local/lib/python3.10/dist-packages (1.12.1)
# Requirement already satisfied: grpcio>=1.41.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (1.68.1)
# Requirement already satisfied: grpcio-tools>=1.41.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (1.68.1)
# Requirement already satisfied: httpx>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.20.0->qdrant-client) (0.28.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (1.26.4)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (2.10.1)
# Requirement already satisfied: pydantic>=1.10.8 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (2.9.2)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (2.2.3)
# Requirement already satisfied: protobuf<6.0dev,>=5.26.1 in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.41.0->qdrant-client) (5.29.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.41.0->qdrant-client) (75.1.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (0.14.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.20.0->qdrant-client) (4.1.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10.8->qdrant-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10.8->qdrant-client) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10.8->qdrant-client) (4.12.2)
# Requirement already satisfied: hyperframe<7,>=6.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (4.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.2.2)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.48.0.dev0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.6)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.26.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (11.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.9.11)
# Collecting tokenizers<0.22,>=0.21 (from transformers<5.0.0,>=4.41.0->sentence_transformers)
#   Using cached tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.4.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2024.8.30)
# Using cached tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# Installing collected packages: tokenizers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.3
#     Uninstalling tokenizers-0.20.3:
#       Successfully uninstalled tokenizers-0.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chromadb 0.5.23 requires tokenizers<=0.20.3,>=0.13.2, but you have tokenizers 0.21.0 which is incompatible.
# Successfully installed tokenizers-0.21.0
# Collecting pi_heif
#   Downloading pi_heif-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: pillow>=10.1.0 in /usr/local/lib/python3.10/dist-packages (from pi_heif) (11.0.0)
# Downloading pi_heif-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.7 MB/s eta 0:00:00
# Installing collected packages: pi_heif
# Successfully installed pi_heif-0.21.0
# Collecting unstructured_inference
#   Downloading unstructured_inference-0.8.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting layoutparser (from unstructured_inference)
#   Downloading layoutparser-0.3.4-py3-none-any.whl.metadata (7.7 kB)
# Collecting python-multipart (from unstructured_inference)
#   Downloading python_multipart-0.0.19-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unstructured_inference) (0.26.3)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from unstructured_inference) (1.26.4)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /usr/local/lib/python3.10/dist-packages (from unstructured_inference) (4.10.0.84)
# Collecting onnx (from unstructured_inference)
#   Downloading onnx-1.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: onnxruntime>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from unstructured_inference) (1.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from unstructured_inference) (3.8.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from unstructured_inference) (2.5.1+cu121)
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (from unstructured_inference) (1.0.12)
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.10/dist-packages (from unstructured_inference) (4.48.0.dev0)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (from unstructured_inference) (3.10.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.17.0->unstructured_inference) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.17.0->unstructured_inference) (24.3.25)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.17.0->unstructured_inference) (24.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.17.0->unstructured_inference) (5.29.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.17.0->unstructured_inference) (1.13.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured_inference) (3.16.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured_inference) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured_inference) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured_inference) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured_inference) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured_inference) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured_inference) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unstructured_inference) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unstructured_inference) (4.12.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from layoutparser->unstructured_inference) (1.13.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from layoutparser->unstructured_inference) (2.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from layoutparser->unstructured_inference) (11.0.0)
# Collecting iopath (from layoutparser->unstructured_inference)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pdfplumber (from layoutparser->unstructured_inference)
#   Downloading pdfplumber-0.11.4-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 3.8 MB/s eta 0:00:00
# Collecting pdf2image (from layoutparser->unstructured_inference)
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured_inference) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured_inference) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured_inference) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured_inference) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured_inference) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured_inference) (2.8.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm->unstructured_inference) (0.20.1+cu121)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->unstructured_inference) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->unstructured_inference) (3.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.17.0->unstructured_inference) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->unstructured_inference) (1.16.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.17.0->unstructured_inference) (10.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath->layoutparser->unstructured_inference) (2.10.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->unstructured_inference) (3.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->layoutparser->unstructured_inference) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->layoutparser->unstructured_inference) (2024.2)
# Collecting pdfminer.six==20231228 (from pdfplumber->layoutparser->unstructured_inference)
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Collecting pypdfium2>=4.18.0 (from pdfplumber->layoutparser->unstructured_inference)
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber->layoutparser->unstructured_inference) (3.4.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber->layoutparser->unstructured_inference) (43.0.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.25.1->unstructured_inference) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.25.1->unstructured_inference) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.25.1->unstructured_inference) (2024.8.30)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber->layoutparser->unstructured_inference) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber->layoutparser->unstructured_inference) (2.22)
# Downloading unstructured_inference-0.8.1-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 3.8 MB/s eta 0:00:00
# Downloading layoutparser-0.3.4-py3-none-any.whl (19.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 59.1 MB/s eta 0:00:00
# Downloading onnx-1.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 74.1 MB/s eta 0:00:00
# Downloading python_multipart-0.0.19-py3-none-any.whl (24 kB)
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading pdfplumber-0.11.4-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 5.3 MB/s eta 0:00:00
# Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 68.5 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 66.6 MB/s eta 0:00:00
# Building wheels for collected packages: iopath
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31528 sha256=a296ad97258b984207cbc99a9354d4b8773d16669db1d622dbea79c2f1eac22e
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built iopath
# Installing collected packages: python-multipart, pypdfium2, pdf2image, onnx, iopath, pdfminer.six, pdfplumber, layoutparser, unstructured_inference
#   Attempting uninstall: pdfminer.six
#     Found existing installation: pdfminer.six 20240706
#     Uninstalling pdfminer.six-20240706:
#       Successfully uninstalled pdfminer.six-20240706
# Successfully installed iopath-0.1.10 layoutparser-0.3.4 onnx-1.17.0 pdf2image-1.17.0 pdfminer.six-20231228 pdfplumber-0.11.4 pypdfium2-4.30.0 python-multipart-0.0.19 unstructured_inference-0.8.1

# %%
import logging
import os
logging.basicConfig(level=logging.INFO)
from google.colab import userdata
import locale

import torch
import os
import bs4
import json
import numpy as np
import time
import pandas as pd

from pprint import pprint

import locale
import uuid


import fitz
import requests
from langchain.embeddings import HuggingFaceEmbeddings
from typing import Tuple, List, Optional
from pathlib import Path
import tempfile
from google.colab import files
import requests
from typing import Optional, Dict
from collections import defaultdict
from typing import List, Dict
import subprocess
import pkg_resources


from transformers import AutoTokenizer , AutoModelForCausalLM
from transformers import pipeline, BitsAndBytesConfig

from langchain.llms import HuggingFacePipeline
from langchain import PromptTemplate, LLMChain
from langchain_core.prompts import ChatPromptTemplate
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_text_splitters import CharacterTextSplitter
from langchain_core.output_parsers import StrOutputParser
from langchain import hub
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import FAISS
from langchain_community.vectorstores import Chroma
from langchain_community.vectorstores import Qdrant
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.utils.math import cosine_similarity
from langchain.schema import Document

from langchain_community.document_loaders import ArxivLoader
from langchain_community.document_loaders import TextLoader
from langchain_community.document_loaders import WikipediaLoader
from langchain_community.document_loaders import OnlinePDFLoader
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.document_loaders import PubMedLoader
from langchain.vectorstores import Qdrant
from qdrant_client import QdrantClient
from langchain.text_splitter import RecursiveCharacterTextSplitter

from langchain_community.chat_models import ChatCohere

from langchain.document_loaders import PyMuPDFLoader
from langchain.prompts import ChatPromptTemplate

from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, pipeline
import torch
from google.colab import userdata
from google.colab import drive
import re
# Out:
# <ipython-input-1-3cc5fbafaee5>:33: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
drive.mount('/content/drive')
locale.getpreferredencoding = lambda: "UTF-8"
# Out:
# Mounted at /content/drive

# %%
# Define paths dynamically based on the company name
# policy_paths = f"/content/drive/MyDrive/210 Capstone/policy/company_name}_eu.pdf"
# #gdpr_url = "https://eur-lex.europa.eu/legal-content/EN/TXT/PDF/?uri=CELEX:32016R0679"
# gdpr_drive_path = "/content/drive/MyDrive/210 Capstone/GDPR.pdf"
base_embeddings = HuggingFaceEmbeddings(model_name="multi-qa-mpnet-base-dot-v1")

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

QDRANT_API_KEY = userdata.get('QDRANT_API_KEY')

# %%
def fn_local_with_paths(input_data: Dict) -> Tuple[Optional[str], Optional[str], str, str, str]:
    """
    Retrieve the uploaded policy file and GDPR document from Google Drive.

    Args:
        input_data (dict): Input JSON containing `file_name`, `company_name`, `uuid`, and `question_type`.

    Returns:
        tuple: Paths to policy document, GDPR document, company name, uuid, and document type.
    """
    print("Received input data: ", input_data)

    # Extract question_type and uuid
    question_type = input_data.get("question_type", "Policy")
    uuid = input_data.get("uuid")
    if not uuid:
        raise ValueError("Input JSON payload missing 'uuid' field")

    gdpr_drive_path = "/content/drive/MyDrive/210 Capstone/policy/GDPR.pdf"

    if question_type == "Policy":
        company_name = input_data.get("company_name", "").strip()
        if not company_name:
            raise ValueError("Input JSON payload missing 'company_name' field for Policy questions.")
        policy_paths = f"/content/drive/MyDrive/210 Capstone/policy/{company_name}.pdf"
        if not os.path.exists(policy_paths):
            raise FileNotFoundError(f"The policy file for {company_name} was not found at {policy_paths}")
        print(f"Policy file located at: {policy_paths}")
    else:
        company_name = None
        policy_paths = None

    if question_type == "GDPR" and not os.path.exists(gdpr_drive_path):
        raise FileNotFoundError(f"The GDPR document was not found at {gdpr_drive_path}")

    print(f"GDPR document located at: {gdpr_drive_path}")

    return policy_paths, gdpr_drive_path, company_name, uuid, question_type

# %%
# Define the function to load PDF content
def load_pdf_content_with_page_count(pdf_path: str) -> Tuple[List[str], int]:
    """
    Load the content of a PDF and return the text from each page along with the page count.

    Args:
        pdf_path: Path to the PDF file.

    Returns:
        tuple: (List of page contents as strings, Total number of pages)
    """
    try:
        document = fitz.open(pdf_path)
        #print(f"Document opened successfully. Page count: {len(document)}")
        contents = [page.get_text() for page in document]
        num_pages = len(contents)
        document.close()
        return contents, num_pages
    except Exception as e:
        logger.error(f"Failed to load PDF content from {pdf_path}: {e}")
        return [], 0


# Define the function to load policy and GDPR documents
def load_policy_document(policy_path: str, gdpr_path: str) -> Tuple[List[str], List[str]]:
    """
    Load a single policy document and the GDPR document with proper error handling.

    Parameters:
    - policy_path (str): Path to the company policy PDF.
    - gdpr_path (str): Path to the GDPR reference PDF.

    Returns:
    - tuple: (list of policy content as strings, gdpr contents)
    """
    base_embeddings = HuggingFaceEmbeddings(model_name="multi-qa-mpnet-base-dot-v1")
    if base_embeddings is None:
        logger.error("Failed to initialize embeddings")
        return [], []

    policy_contents, policy_pages = load_pdf_content_with_page_count(policy_path)
    logger.info(f"Loaded policy document ({Path(policy_path).name}): {policy_pages} pages")

    # Load GDPR document
    gdpr_contents, gdpr_pages = load_pdf_content_with_page_count(gdpr_path)
    logger.info(f"Loaded GDPR document ({Path(gdpr_path).name}): {gdpr_pages} pages")

    return policy_contents, gdpr_contents

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def extract_formatted_text(pdf_path: str) -> List[Dict]:
    """
    Extract text with its formatting information from PDF.
    Returns list of dictionaries containing text and its formatting properties.
    """
    formatted_blocks = []
    try:
        doc = fitz.open(pdf_path)
        position = 0

        for page_num, page in enumerate(doc):
            blocks = page.get_text("dict")["blocks"]
            prev_y1 = None

            for block in blocks:
                if "lines" in block:
                    for line in block["lines"]:
                        y0 = line["bbox"][1]
                        line_spacing = y0 - prev_y1 if prev_y1 is not None else 0
                        prev_y1 = line["bbox"][3]

                        for span in line["spans"]:
                            text = span["text"].strip()
                            if text:
                                formatted_blocks.append({
                                    "text": text,
                                    "font_name": span["font"],
                                    "font_size": span["size"],
                                    "is_bold": "bold" in span["font"].lower() or span["flags"] & 2**4 != 0,
                                    "line_spacing": line_spacing,
                                    "position": position,
                                    "page_num": page_num + 1
                                })
                            position += len(text) + 1

        return formatted_blocks
    except Exception as e:
        print(f"Error extracting formatted text: {e}")
        return []

def analyze_document_formatting(blocks: List[Dict]) -> Dict:
    """
    Analyze document formatting to establish baseline metrics.
    """
    stats = defaultdict(list)

    for block in blocks:
        stats["font_sizes"].append(block["font_size"])
        stats["line_spacings"].append(block["line_spacing"])

    return {
        "avg_font_size": sum(stats["font_sizes"]) / len(stats["font_sizes"]),
        "max_font_size": max(stats["font_sizes"]),
        "avg_line_spacing": sum(stats["line_spacings"]) / len(stats["line_spacings"]) if stats["line_spacings"] else 0
    }

def identify_potential_headers(blocks: List[Dict], format_stats: Dict) -> List[Dict]:
    potential_headers = []
    print("calculating potential headers")

    for block in blocks:
        formatting_score = 0
        characteristics = []

        # Format-based scoring
        if block["font_size"] > format_stats["avg_font_size"]:
            formatting_score += 2
            characteristics.append("larger_font")

        if block["is_bold"]:
            formatting_score += 2
            characteristics.append("bold")

        if block["line_spacing"] > format_stats["avg_line_spacing"] * 1.5:
            formatting_score += 1
            characteristics.append("increased_spacing")

        word_count = len(block["text"].split())
        if word_count <= 10:
            formatting_score += 1
            characteristics.append("short_text")

        if block["text"].istitle() or block["text"].isupper():
            formatting_score += 1
            characteristics.append("title_case_or_caps")

        if formatting_score >= 3:
            potential_headers.append({
                "header": block["text"],
                "position": block["position"]
            })

    return potential_headers

def chunk_policy_by_headers(headers: List[Dict], blocks: List[Dict]) -> List[Dict]:
    """
    Chunk the policy text based on section headers using the original formatted blocks.
    """
    chunks = []
    full_text = ""
    current_position = 0

    for block in blocks:
        full_text += block["text"] + "\n"

    for i, header_data in enumerate(headers):
        start_pos = header_data["position"]
        end_pos = headers[i + 1]["position"] if i + 1 < len(headers) else len(full_text)
        chunk_text = full_text[start_pos:end_pos].strip()

        chunks.append({
            "header": header_data["header"],
            "content": chunk_text
        })

    return chunks

def process_policy(pdf_path: str) -> Dict:
    """
    Process a single PDF policy document and extract sections based on formatting only.
    No GPT validation needed.
    """
    try:
        # Extract text with formatting
        formatted_blocks = extract_formatted_text(pdf_path)
        if not formatted_blocks:
            return {"status": "error", "pdf_path": pdf_path, "message": "Failed to extract formatted text"}

        # Analyze document formatting
        format_stats = analyze_document_formatting(formatted_blocks)

        # Get headers based on formatting only
        confirmed_headers = identify_potential_headers(formatted_blocks, format_stats)

        if not confirmed_headers:
            return {"status": "error", "pdf_path": pdf_path, "message": "No headers found in the document"}

        chunks = chunk_policy_by_headers(confirmed_headers, formatted_blocks)

        return {
            "status": "success",
            "pdf_path": pdf_path,
            "total_chunks": len(chunks),
            "chunks": chunks
        }

    except Exception as e:
        return {"status": "error", "pdf_path": pdf_path, "message": str(e)}


def further_chunk_policy(company_name: str, uuid: str, policy: Dict, chunk_size: int = 1000, chunk_overlap: int = 50) -> List[Dict]:
    """
    Further split each chunk's content for a single company policy using a Recursive Text Splitter.

    Args:
        policy (Dict): A dictionary representing the policy document with its chunks.
        chunk_size (int): The maximum size of each sub-chunk.
        chunk_overlap (int): The overlap between consecutive sub-chunks.

    Returns:
        List[Dict]: A list of refined sub-chunks with metadata.
    """
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        length_function=len,
        is_separator_regex=False
    )
    refined_chunks = []

    #pdf_path = policy["pdf_path"]
    #company_name = policy_paths.split('/')[-1].replace('.pdf', '').capitalize()

    for chunk in policy["chunks"]:
        try:
            sub_chunks = text_splitter.split_text(chunk["content"])

            for i, sub_chunk in enumerate(sub_chunks, 1):
                refined_chunks.append({
                    "page_content": sub_chunk,
                    "metadata": {
                        "company_name": company_name,
                        "uuid": uuid,
                        "pdf_path": policy["pdf_path"],
                        "header": chunk["header"],
                        "chunk_index": i,
                        "total_sub_chunks": len(sub_chunks),
                        "document_type": "Policy"
                    }
                })
        except Exception as e:
            print(f"Error processing chunk for company {company_name} with header '{chunk['header']}': {str(e)}")
            continue

    return refined_chunks


def chunk_gdpr_by_section(gdpr_contents: List[str]) -> List[Document]:
    """
    Chunk GDPR text into sections based on articles and recitals, without mapping to policy categories.

    Parameters:
    - gdpr_contents (List[str]): List containing GDPR text.

    Returns:
    - List[Document]: List of Document objects, each representing a chunk of a GDPR section.
    """
    try:
        text_splitter = RecursiveCharacterTextSplitter(chunk_size=1500, chunk_overlap=50)
        documents = []
        full_text = "\n".join(gdpr_contents)

        recital_pattern = re.compile(r"\((\d+)\)\s", re.MULTILINE)
        article_pattern = re.compile(r"(Article\s(\d+))\b", re.IGNORECASE)

        all_matches = [(match.start(), match.group(1), 'recital') for match in re.finditer(recital_pattern, full_text)]
        all_matches += [(match.start(), match.group(1), 'article', match.group(2)) for match in re.finditer(article_pattern, full_text)]
        all_matches.sort()

        for i, (start, header, section_type, *article_number) in enumerate(all_matches):
            end = all_matches[i + 1][0] if i + 1 < len(all_matches) else len(full_text)
            section_text = full_text[start:end].strip()

            section_header = None

            if section_type == 'article' and article_number:
                article_number = article_number[0].strip()
                section_header = f"Article {article_number}"

            elif section_type == 'recital':
                section_header = f"Recital {header}"

            chunks = text_splitter.split_text(section_text)

            for chunk in chunks:
                documents.append(Document(
                    page_content=chunk,
                    metadata={
                        "header": section_header
                    }
                ))

        print(f"\nTotal documents created: {len(documents)}")
        return documents

    except Exception as e:
        print(f"Error processing GDPR contents: {e}")
        return []

# %%
def initialize_falcon_pipeline(
    model_name: str = "tiiuae/falcon-7b-instruct",
    max_new_tokens: int = 1500,
    temperature: float = 0.55,
    top_p: float = 0.9,
    repetition_penalty: float = 1.3,
    offload_folder: str = "offload_folder",
    use_auth_token: Optional[str] = None
) -> pipeline:
    """
    Initialize the Falcon text-generation pipeline with quantization.
    No token required for public models.
    """
    quantization_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_use_double_quant=True,
        llm_int8_enable_fp32_cpu_offload=True
    )

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        device_map="auto",
        torch_dtype=torch.float16,
        quantization_config=quantization_config,
        offload_folder=offload_folder,
        trust_remote_code=True
    )

    tokenizer = AutoTokenizer.from_pretrained(
        model_name,
        padding_side="right",
        truncation=True,
        trust_remote_code=True
    )

    falcon_pipe = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        max_new_tokens=max_new_tokens,
        temperature=temperature,
        top_p=top_p,
        do_sample=True,
        repetition_penalty=repetition_penalty,
        torch_dtype=torch.float16
    )

    falcon_pipe.model.config.pad_token_id = falcon_pipe.model.config.eos_token_id
    return falcon_pipe

# %%
# def format_falcon_output(raw_text):
#     """
#     Formats the Falcon model's raw output into structured sections.
#     """
#     sections = raw_text.split("\n\n")  # Separate into paragraphs
#     main_answer = sections[0] if sections else "No answer generated."
#     key_points = sections[1:] if len(sections) > 1 else []

#     formatted_output = f"**Main Answer:**\n{main_answer.strip()}\n\n**Key Points:**\n"
#     for point in key_points:
#         formatted_output += f"- {point.strip()}\n"
#     return formatted_output


def format_falcon_output(raw_text):
    if not raw_text.strip():
        return "**Main Answer:**\nNo answer could be generated.\n\n**Key Points:**\n- No details available."

    sections = raw_text.split("\n\n")
    main_answer = sections[0].strip() if sections else "No answer generated."
    key_points = list(set(sections[1:]))  # Remove duplicates

    formatted_output = f"**Main Answer:**\n{main_answer}\n\n**Key Points:**\n"
    if key_points:
        for point in key_points:
            formatted_output += f"- {point.strip()}\n"
    else:
        formatted_output += "- No key points available.\n"

    return formatted_output

# %%
def further_chunk_gdpr_content(company_name: str, initial_documents: List[Document]) -> List[Document]:
    """Further split GDPR content into smaller chunks while preserving metadata."""
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1200, chunk_overlap=50)
    gdpr_chunks = []

    for document in initial_documents:
        sub_chunks = text_splitter.split_text(document.page_content)
        for sub_chunk in sub_chunks:
            gdpr_chunks.append(Document(
                page_content=sub_chunk,
                metadata={
                    "header": document.metadata.get("header"),
                    "document_type": "GDPR"
                }
            ))
    print(f"[DEBUG] Further chunked GDPR content for company {company_name}")
    return gdpr_chunks

def prepare_documents_for_vectorstore(chunks: List[Document]) -> List[Document]:
    """Prepare documents for vector store with consistent metadata handling."""
    documents = []

    for idx, chunk in enumerate(chunks):
        if isinstance(chunk, dict):
            chunk = Document(page_content=chunk['page_content'], metadata=chunk['metadata'])

        doc_type = chunk.metadata.get("document_type", "Unknown")

        metadata_company_name = chunk.metadata.get("company_name", "").lower()
        uuid = chunk.metadata.get("uuid", "")

        metadata = {
            "chunk_number": idx + 1,
            "document_type": doc_type,
            "company_name": metadata_company_name,
            "header": chunk.metadata.get("header", ""),
            "doc_link": (
                "https://eur-lex.europa.eu/legal-content/EN/TXT/PDF/?uri=CELEX:32016R0679"
                if doc_type == "GDPR"
                else f"/content/drive/MyDrive/210 Capstone/policy/{metadata_company_name}.pdf"
            )
        }

        documents.append(Document(
            page_content=chunk.page_content,
            metadata=metadata
        ))
        print(f"[DEBUG] Prepared document {idx + 1} with metadata: {metadata}")

    return documents

def setup_vectorstore(documents: List[Document], embeddings, qdrant_url: str, qdrant_api_key: str) -> Optional[Qdrant]:
    """Initialize and populate the vector store using a Qdrant cloud instance."""
    try:
        # Connect to the Qdrant client
        qdrant_client = QdrantClient(url=qdrant_url, api_key=qdrant_api_key)
        print("[DEBUG] Connected to Qdrant cloud instance")

        collection_name = "policy_pulse_db"

        test_embedding = embeddings.embed_query("")
        #print(f"[DEBUG] Embedding output type: {type(test_embedding)}")
        #print(f"[DEBUG] Embedding output sample: {test_embedding}")

        test_embedding = embeddings.embed_query("")
        if isinstance(test_embedding, list):
          test_embedding = np.array(test_embedding)
        embedding_size = test_embedding.shape[0]
        print(f"[DEBUG] Detected embedding size: {embedding_size}")

        # Recreate the collection
        try:
            qdrant_client.recreate_collection(
                collection_name=collection_name,
                vectors_config={
                    "size": embedding_size,
                    "distance": "Cosine"
                }
            )
            print(f"[DEBUG] Collection '{collection_name}' recreated successfully")
        except Exception as e:
            print(f"[ERROR] Failed to recreate collection: {e}")
            return None

        # Add documents to the vectorstore
        try:
            vectorstore = Qdrant(
                client=qdrant_client,
                collection_name=collection_name,
                embeddings=embeddings
            )
            vectorstore.add_documents(documents)
            print("[DEBUG] Documents added to Qdrant collection")
            return vectorstore
        except Exception as e:
            print(f"[ERROR] Failed to add documents to vectorstore: {e}")
            return None

    except Exception as e:
        print(f"[ERROR] Error setting up vector store: {e}")
        return None


def create_policy_prompt_template() -> ChatPromptTemplate:
    """
    Creates a ChatPromptTemplate for the GDPR compliance expert.

    Returns:
        ChatPromptTemplate: Configured template for generating structured answers.
    """
    prompt_role = "You are a GDPR compliance expert tasked with providing accurate, structured answers."
    prompt_task = "Using only the provided context, generate a comprehensive response that includes all required sections."
    prompt_context = "Context:\n{context}"
    prompt_question = "Question:\n{question}"
    prompt_instruction = """Answer the question by referring specifically to the context.
    Structure your response exactly as follows:

    Main Answer:
    [Provide a concise answer using the context information]

    Key Points:
    • [List key points as bullet points]
    • [Each point should start with a bullet point]
    • [Extract at least 3-4 key points]

    GDPR References:
    [Must include specific GDPR articles mentioned or most relevant to the context. Use format: 'Article X - Title']"""

    # Combine all parts into the template
    policy_pulse_template = f"""<s>[INST] {prompt_role}
    {prompt_task}

    {prompt_context}

    {prompt_question}

    {prompt_instruction} [/INST]"""

    # Return the ChatPromptTemplate object
    return ChatPromptTemplate.from_template(policy_pulse_template)

# def create_policy_prompt_template() -> ChatPromptTemplate:
#     """
#     Creates a ChatPromptTemplate for the GDPR compliance expert.
#     """
#     prompt_role = "You are a GDPR compliance expert who MUST answer in the exact format specified."
#     prompt_task = """Using ONLY the provided context, generate a structured response.
#     You must ALWAYS use the format specified below, even if you feel the context is insufficient."""

#     prompt_context = "Context:\n{context}"
#     prompt_question = "Question:\n{question}"
#     prompt_instruction = """You MUST structure your response EXACTLY as follows:

#     Main Answer:
#     [Write a concise 2-3 sentence answer using ONLY information from the context]

#     Key Points:
#     • [Start each point with a bullet]
#     • [Include at least 3 points from the context]
#     • [Be specific and cite actual details from context]

#     GDPR References:
#     [List any GDPR articles mentioned in context. If none mentioned, write "No specific GDPR articles referenced in provided context."]"""

#     policy_pulse_template = f"""<s>[INST] {prompt_role}
#     {prompt_task}

#     {prompt_context}

#     {prompt_question}

#     {prompt_instruction} [/INST]"""

#     return ChatPromptTemplate.from_template(policy_pulse_template)

def classify_question_type(company_name, question: str) -> tuple:
    """
    Classify if a question is about a specific company policy or general GDPR.
    Returns "Policy" if a company name is identified in the question,
    otherwise returns "GDPR".

    Args:
        question: The question text

    Returns:
        Tuple: ("Policy" or "GDPR", matched company name or None)
    """
   #company_name = "bitpay"
    if company_name in question:
      company_name = company_name.lower()
    return "Policy" if company_name else ("GDPR", None)

def clean_generated_response(response: str) -> str:
    """
    This function cleans the generated response to remove any unwanted content
    such as initial instructions or repeated context.
    """
    cleaned_response = re.sub(r'Human: <s>\[INST\].*?\[/INST\]', '', response, flags=re.DOTALL)

    cleaned_response = re.sub(r'Context:\s*{.*?}\n', '', cleaned_response, flags=re.DOTALL)

    cleaned_response = re.sub(r'Question:\s*{.*?}\n', '', cleaned_response, flags=re.DOTALL)

    cleaned_response = cleaned_response.strip()

    return cleaned_response


def process_single_question(company, question_type,  question, qdrant_vectorstore, gdpr_retriever, rag_chain_falcon):
    """
    Process a single question using the RAG system and return the generated answer.

    Args:
        question (str): The question to process.
        qdrant_vectorstore: Qdrant vector store for policy documents.
        gdpr_retriever: Retriever for GDPR-related documents.
        rag_chain_falcon: RAG chain pipeline for generating answers.

    Returns:
        dict: A result including the question, context, generated answer, and document sources.
    """
    print(f"[PROCESSING] Question: {question}")

    dynamic_company_name = company
    #question_type = classify_question_type(dynamic_company_name, question)
    print(f"extracted company name: {dynamic_company_name}")
    print(f"extracted question_type: {question_type}")

    gdpr_results = []
    policy_results = []

    if question_type == 'GDPR':
        print(f"[PROCESSING] Retrieving GDPR content for question: {question}")
        gdpr_results = gdpr_retriever.get_relevant_documents(
            question, metadata_filters={"document_type": question_type}
        )

    elif question_type == 'Policy':
        print(f"[PROCESSING] Retrieving Policy content for question: {question} ({dynamic_company_name})")
        combined_filter = {"company_name": dynamic_company_name}
        policy_retriever = qdrant_vectorstore.as_retriever(search_kwargs={'filter': combined_filter})
        # policy_results = policy_retriever.get_relevant_documents(question)
        policy_results = qdrant_vectorstore.as_retriever(search_kwargs={'filter': {'document_type': 'Policy', 'company_name': dynamic_company_name}}).get_relevant_documents(question)


        if not policy_results:
            # print(f"[WARNING] No policy documents found for '{dynamic_company_name}'. Using broader retrieval.")
            # policy_results = qdrant_vectorstore.as_retriever().get_relevant_documents(question)
            print("[WARNING] No policy documents found. Broadening retrieval scope.")
            policy_results = qdrant_vectorstore.as_retriever().get_relevant_documents(question)


        print(f"[INFO] Retrieving GDPR articles for the question using semantic similarity")
        gdpr_results = gdpr_retriever.get_relevant_documents(question)


        print("[DEBUG] Retrieved Policy Context Snippets:")
        if policy_results:
            for i, doc in enumerate(policy_results):
                print(f"Snippet {i+1}: {doc.page_content[:200]}...")
        else:
            print("[DEBUG] No policy context snippets retrieved.")

    else:
        print(f"[ERROR] Unable to classify question type.")
        return {
            "question": question,
            "contexts": "No relevant context found.",
            "answer": "Unable to classify question type.",
            "doc_source": "N/A"
        }

    context_snippets = [doc.page_content[:500] for doc in policy_results + gdpr_results if doc.page_content]
    context_snippets_str = " ".join(context_snippets)

    document_sources = [doc.metadata.get('doc_link', 'N/A') for doc in policy_results + gdpr_results]
    document_sources_str = ", ".join(document_sources)


    # Add debug prints after retrieving documents
    context_snippets = [doc.page_content[:500] for doc in policy_results + gdpr_results if doc.page_content]
    context_snippets_str = " ".join(context_snippets)

    print(f"\n[DEBUG] Retrieved Context Snippets:")
    for i, snippet in enumerate(context_snippets):
        print(f"\nSnippet {i+1}:")
        print(snippet[:200] + "...")


    if not context_snippets_str:
        print(f"[ERROR] No context retrieved for question: {question}.")
        return {
            "question": question,
            "contexts": "No relevant context found for answering the question.",
            "answer": "No answer generated.",
            "doc_source": "N/A"
        }

    # rag_input = {"context": context_snippets_str, "question": question}
    # rag_input = {
    # "context": context_snippets_str,
    # "question": question,
    # "instructions": (
    #     "As a GDPR compliance expert, provide a detailed answer in the following format:\n"
    #     "**Main Answer:**\n[One concise sentence summarizing the key information.]\n\n"
    #     "**Key Points:**\n- [Point 1]\n- [Point 2]\n\n"
    #     "Reference GDPR articles where applicable."
    # )
    # }

    # rag_input = {
    # "context": context_snippets_str,
    # "question": question,
    # "instructions": (
    #     "Provide a GDPR-compliant answer to the question using the given context. "
    #     "Structure the response as follows:\n"
    #     "**Main Answer:** [Provide a concise, factual summary.]\n"
    #     "**Key Points:**\n- [Key Point 1]\n- [Key Point 2]\n"
    #     "Avoid redundancy and ensure relevance."
    # )}


    rag_input = {
    "context": context_snippets_str,
    "question": question,
    "instructions": (
        "Using the provided context, answer the question with specific details. Focus on 'data storage and processing' locations, "
        "GDPR compliance measures, and any relevant guidelines."
    )}

    response = rag_chain_falcon.invoke(rag_input)
    generated_answer = clean_generated_response(response)

    # Apply the formatter here
    formatted_answer = format_falcon_output(generated_answer)

    return {
        "question": question,
        "contexts": context_snippets_str,
        "answer": generated_answer,
        "answer": formatted_answer,
        "doc_source": document_sources_str
    }


def main():
    """
    Main function to process a policy document, refine chunks, interact with vector store,
    and generate responses using the RAG pipeline.
    """


    input_data = {
        "company_name": "stripe",
        "uuid": "123e4567-e89b-12d3-a456-426614174000",
        "question_type": "Policy",
        #"question": "What safeguards does Stripe implement for international data transfers?"
    }

    policy_paths, gdpr_path, company_name, uuid, document_type = fn_local_with_paths(input_data)

    policy_contents, gdpr_contents = [], []

    if document_type == "Policy":
        policy_contents, _ = load_pdf_content_with_page_count(policy_paths)
        print(f"Total pages in Policy Document ({Path(policy_paths).name}): {len(policy_contents)}")
    elif document_type == "GDPR":
        gdpr_contents, _ = load_pdf_content_with_page_count(gdpr_path)
        print(f"Total pages in GDPR PDF: {len(gdpr_contents)}")
    else:
        raise ValueError(f"Unsupported document type: {document_type}")

    print(f"Policy Path: {policy_paths if document_type == 'Policy' else 'N/A'}")
    print(f"GDPR Path: {gdpr_path if document_type == 'GDPR' else 'N/A'}")
    print(f"Company Name: {company_name}")
    print(f"UUID: {uuid}")

    # Process the uploaded policy
    if document_type == "Policy":
      result = process_policy(policy_paths)
      if result["status"] == "success":
          print(f"\nProcessed Result for {result['pdf_path']}:")
          print(f"Total number of chunks created: {result['total_chunks']}\n")
          for chunk in result["chunks"]:
              print(f"Header: {chunk['header']}")
              print(f"Content Snippet: {chunk['content'][:150]}...\n")
      else:
          print(f"Error processing {result['pdf_path']}: {result['message']}")
          return
    else:
        print("[INFO] Document type is not 'Policy'; skipping policy processing.")

    refined_chunks = []
    if document_type == "Policy":
        result = process_policy(policy_paths)
        if result["status"] == "success":
            print(f"\nProcessed Result for {result['pdf_path']}:")
            print(f"Total number of chunks created: {result['total_chunks']}\n")
            for chunk in result["chunks"]:
                print(f"Header: {chunk['header']}")
                print(f"Content Snippet: {chunk['content'][:150]}...\n")
        else:
            print(f"Error processing {result['pdf_path']}: {result['message']}")
            return

        refined_chunks = further_chunk_policy(company_name, uuid, result)
        print(f"Total number of sub-chunks created: {len(refined_chunks)}\n")
        for i, final_chunk in enumerate(refined_chunks, 1):
            print(f"Chunk {i}/{len(refined_chunks)}")
            print(f"PDF Path: {final_chunk['metadata']['pdf_path']}")
            print(f"Header: {final_chunk['metadata']['header']}")
            print(f"Sub-chunk {final_chunk['metadata']['chunk_index']}/{final_chunk['metadata']['total_sub_chunks']}")
            print(f"Content Snippet: {final_chunk['page_content'][:150]}...\n")
    elif document_type == "GDPR":
        gdpr_sentence_chunks = chunk_gdpr_by_section(gdpr_contents)
        #print("\nSample chunks:")
        for doc in gdpr_sentence_chunks[:5]:
            print(f"\nHeader: {doc.metadata['header']}")
            print(f"Content Snippet: {doc.page_content[:150]}...")

    else:
        print("[ERROR] Invalid document type provided.")


    huggingface_token = userdata.get('hf')
    falcon_pipe = initialize_falcon_pipeline(
        model_name="tiiuae/falcon-7b-instruct",
        max_new_tokens=1000,
        temperature=0.55,
        top_p=0.9,
        repetition_penalty=1.3,
        offload_folder="offload_folder",
        use_auth_token=huggingface_token
        )
    falcon_llm_lc = HuggingFacePipeline(pipeline=falcon_pipe)

    #gdpr_final_chunks = further_chunk_gdpr_content(company_name, gdpr_sentence_chunks)
    if document_type == "GDPR":
        gdpr_final_chunks = further_chunk_gdpr_content(company_name, gdpr_sentence_chunks)
    else:
        gdpr_final_chunks = []

    all_chunks = gdpr_final_chunks + refined_chunks
    all_documents = prepare_documents_for_vectorstore(all_chunks)
    print("[DEBUG] Prepared Documents for Vector Store:")
    for idx, document in enumerate(all_documents):
        print(f"Document {idx + 1}:")
        print(f"Page Content: {document.page_content[:100]}...")
        print(f"Metadata: {document.metadata}")
        print("-" * 50)

    QDRANT_URL = "https://5ccc316a-ba45-4910-b5f9-15eb181ae895.us-east4-0.gcp.cloud.qdrant.io:6333"

    qdrant_vectorstore = setup_vectorstore(
        documents=all_documents,
        embeddings=base_embeddings,
        qdrant_url=QDRANT_URL,
        qdrant_api_key=QDRANT_API_KEY
    )

    combined_filter = {"document_type": "GDPR"}
    gdpr_retriever = qdrant_vectorstore.as_retriever(search_kwargs={'filter': combined_filter})
    print(f"[TEST] Applying retrieval filter with company_name: '{company_name}'")

    policy_prompt = create_policy_prompt_template()

    rag_chain_falcon = (
        {
            "context": RunnablePassthrough(),
            "question": RunnablePassthrough()
        }
        | policy_prompt
        | falcon_llm_lc
        | RunnablePassthrough()
    )


    user_question = input("Ask your question: ")
    result = process_single_question(
        company_name,
        document_type,
        question=user_question,
        qdrant_vectorstore=qdrant_vectorstore,
        gdpr_retriever=gdpr_retriever,
        rag_chain_falcon=rag_chain_falcon
    )

    print("\nReturning the following to the UI:")
    print()
    print(result['answer'])
    print()
    print(result['doc_source'])

    return {
        "answer": result["answer"],
        "doc_source": result["doc_source"]
    }



if __name__ == "__main__":
    response = main()
# Out:
# Received input data:  {'company_name': 'stripe', 'uuid': '123e4567-e89b-12d3-a456-426614174000', 'question_type': 'Policy'}
# Policy file located at: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# GDPR document located at: /content/drive/MyDrive/210 Capstone/policy/GDPR.pdf
# Total pages in Policy Document (stripe.pdf): 29
# Policy Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# GDPR Path: N/A
# Company Name: stripe
# UUID: 123e4567-e89b-12d3-a456-426614174000
# calculating potential headers
#
# Processed Result for /content/drive/MyDrive/210 Capstone/policy/stripe.pdf:
# Total number of chunks created: 88
#
# Header: Last updated: January 16, 2024
# Content Snippet: Last updated: January 16, 2024
# This Privacy Policy includes important information about your personal data and we encourage you to read
# it carefully....
#
# Header: Welcome
# Content Snippet: Welcome
# We provide financial infrastructure for the internet. Individuals and businesses of all sizes use our
# technology and services to facilitate pu...
#
# Header: Privacy Policy
# Content Snippet: Privacy Policy
# This Privacy Policy will be updated on January 16, 2025. Please review the upcoming changes
# here
# .
# 11/26/24, 8:51 PM
# Privacy Policy
# htt...
#
# Header: 1. Personal Data we collect and how we use and
# Content Snippet: 1. Personal Data we collect and how we use and...
#
# Header: share it
# Content Snippet: share it
# Our collection and use of Personal Data differs based on whether you are an End User, End Customer,
# Representative, or Visitor, and the speci...
#
# Header: 1.1 End Users
# Content Snippet: 1.1 End Users
# We provide End User Services when we provide the Services directly to you for your personal use (e.g.,
# Link). Additional details regardi...
#
# Header: a. Personal Data we collect about End Users
# Content Snippet: a. Personal Data we collect about End Users
# Using Link or Connecting your bank account.
# Stripe offers a service called "Link," which allows you to
# sto...
#
# Header: Paying Stripe.
# Content Snippet: Paying Stripe.
# When you purchase goods or services directly from Stripe, we receive your Transaction
# Data. For instance, when you make a payment to St...
#
# Header: Identity/Verification Services
# Content Snippet: Identity/Verification Services
# . We offer an identity verification service that automates the comparison of
# your identity document (such as a driver’s...
#
# Header: More
# Content Snippet: More
# . For further information about other types of Personal Data that we may collect about End Users,
# including about your online activity and your e...
#
# Header: b. How we use and share Personal Data of End Users
# Content Snippet: b. How we use and share Personal Data of End Users
# Services
# . We use and share your Personal Data to provide the End User Services to you, which inclu...
#
# Header: Our Business Users.
# Content Snippet: Our Business Users.
# When you use Link to make payments, we share your Transaction Data with the
# Business Users you choose to do business with.
# Learn M...
#
# Header: Transactions
# Content Snippet: Transactions
# . When you use Link to make payments, we use your Personal Data (such as name, contact
# information, payment method details) saved with us...
#
# Header: Advertising
# Content Snippet: Advertising
# . We may use your Personal Data to assess your eligibility for, and offer you, other End User
# Services or promote existing End User Servic...
#
# Header: More
# Content Snippet: More
# . For further information about additional ways by which we may use and share End Users' Personal
# Data, please see the
# More ways we collect, use,...
#
# Header: 1.2 End Customers
# Content Snippet: 1.2 End Customers
# Stripe provides various Business Services to our Business Users, which include in-person or online
# checkout payment processing or pr...
#
# Header: a. Personal Data we collect about End Customers
# Content Snippet: a. Personal Data we collect about End Customers
# 11/26/24, 8:51 PM
# Privacy Policy
# https://stripe.com/privacy
# 5/29
# Transaction Data.
# If you're an End Cu...
#
# Header: Identity/Verification Information
# Content Snippet: Identity/Verification Information
# . Stripe provides a verification and fraud prevention Service that our
# Business Users can use to verify Personal Dat...
#
# Header: More
# Content Snippet: More
# . For further information about other types of Personal Data that we may collect about End
# Customers, including about your online activity, pleas...
#
# Header: b. How we use and share Personal Data of End Customers
# Content Snippet: b. How we use and share Personal Data of End Customers
# To provide our Business Services to our Business Users, we use and share End Customers' Persona...
#
# Header: More
# Content Snippet: More
# . For further information about additional ways by which we may use and share  End Customers'
# Personal Data, please see the
# More ways we collect,...
#
# Header: 1.3 Representatives
# Content Snippet: 1.3 Representatives
# We collect, use, and share Personal Data from Representatives of Business Users (for example, business
# owners) to provide our Busi...
#
# Header: a. Personal Data we collect about Representatives
# Content Snippet: a. Personal Data we collect about Representatives
# Registration and contact information.
# When you register for a Stripe account for a Business User
# (in...
#
# Header: Identification Information
# Content Snippet: Identification Information
# . As a current or potential Business User, an owner of a Business User, or a
# shareholder, officer, or director of a Busines...
#
# Header: More
# Content Snippet: More
# . For further information about other types of Personal Data that we may collect about
# Representatives, including your online activity, please se...
#
# Header: b. How we use and share Personal Data of Representatives
# Content Snippet: b. How we use and share Personal Data of Representatives
# We typically use the Personal Data of Representatives to provide the Business Services to the...
#
# Header: Business Services.
# Content Snippet: Business Services.
# We use and share Representatives’ Personal Data with Business Users to provide the
# Services requested by you or the Business User y...
#
# Header: Advertising
# Content Snippet: Advertising
# . Where allowed by applicable law, we use and share Representatives’ Personal Data with third
# parties so we can advertise and market our S...
#
# Header: More
# Content Snippet: More
# . For further information about additional ways by which we may use and share Representatives’
# Personal Data, please see the
# More ways we collect...
#
# Header: 1.4 Visitors
# Content Snippet: 1.4 Visitors
# We collect, use, and share the Personal Data of Visitors. More details about how we collect, use, and share
# Visitors’ Personal Data, alon...
#
# Header: a. Personal Data we collect about Visitors
# Content Snippet: a. Personal Data we collect about Visitors
# When you browse our Sites, we receive your Personal Data, either provided directly by you or collected
# thro...
#
# Header: More
# Content Snippet: More
# . Further details about other types of Personal Data that we may collect from Visitors, including your
# online activity, can be found in the
# More ...
#
# Header: b. How we use and share Personal Data of Visitors
# Content Snippet: b. How we use and share Personal Data of Visitors...
#
# Header: Personalization
# Content Snippet: Personalization
# . We use the data we collect from cookies and similar technologies about you to measure
# user engagement with the content on the Sites,...
#
# Header: Advertising
# Content Snippet: Advertising
# . Where allowed by applicable law, we use and share Visitors’ Personal Data with third parties
# so we can advertise and market our Services...
#
# Header: Engagement
# Content Snippet: Engagement
# . As you interact with our Sites, we use the information we collect about and through your
# devices to provide opportunities for further int...
#
# Header: More
# Content Snippet: More
# . For further information about additional ways by which we may use and share Visitors’ Personal
# Data, please see the
# More ways we collect, use, ...
#
# Header: 2. More ways we collect, use, and share
# Content Snippet: 2. More ways we collect, use, and share...
#
# Header: Personal Data
# Content Snippet: Personal Data
# In addition to the ways described above, we also process your Personal Data as follows:...
#
# Header: a. Collection of Personal Data
# Content Snippet: a. Collection of Personal Data...
#
# Header: Online Activity
# Content Snippet: Online Activity
# . Depending on the Service used and how our Business Services are implemented by the
# Business Users, we may collect information relate...
#
# Header: b. Use of Personal Data.
# Content Snippet: b. Use of Personal Data.
# The devices and browsers you use across our Sites and third party websites, apps, and other online services
# (“Third Party Sit...
#
# Header: Communications
# Content Snippet: Communications
# . We use the contact information we have about you to deliver our Services, which may
# involve sending codes via SMS for your authentica...
#
# Header: Minors
# Content Snippet: Minors
# . Our Services are not directed to children under the age of 13, and we request that they do not
# provide Personal Data to seek Services directl...
#
# Header: c. Sharing of Personal Data.
# Content Snippet: c. Sharing of Personal Data.
# Besides the sharing of Personal Data described above, we share Personal Data in the ways listed below:...
#
# Header: Stripe Affiliates
# Content Snippet: Stripe Affiliates
# . We share Personal Data with other Stripe-affiliated entities for purposes identified in this
# Policy.
# Service Providers or Processo...
#
# Header: Financial Partners
# Content Snippet: Financial Partners
# . We share Personal Data with certain Financial Partners to provide Services to Business
# Users seeking such Services as well as off...
#
# Header: Corporate Transactions
# Content Snippet: Corporate Transactions
# . If we enter or intend to enter a transaction that modifies the structure of our
# business, such as a reorganization, merger, s...
#
# Header: 3. Legal bases for processing Personal Data
# Content Snippet: 3. Legal bases for processing Personal Data
# For purposes of the General Data Protection Regulation and other applicable data protection laws, we rely
# ...
#
# Header: 4. Your rights and choices
# Content Snippet: 4. Your rights and choices
# Depending on your location and subject to applicable law, you may have choices regarding our collection,
# use, and disclosur...
#
# Header: Learn More
# Content Snippet: Learn More
# );
# Response to inquiries, delivery of Service notices, and provision of customer support;
# Promotion, analysis, modification, and improvemen...
#
# Header: a. Opting out of receiving electronic communications from us
# Content Snippet: a. Opting out of receiving electronic communications from us
# If you wish to stop receiving marketing-related emails from us, you can opt-out by clicki...
#
# Header: b. Your data protection rights
# Content Snippet: b. Your data protection rights
# Depending on your location and subject to applicable law, you may have the following rights regarding the
# Personal Data...
#
# Header: Learn
# Content Snippet: Learn
# More
# );
# The right to request that Stripe restrict the use of your Personal Data in certain circumstances, such as
# while Stripe is considering an...
#
# Header: c. Process for exercising your data protection rights
# Content Snippet: c. Process for exercising your data protection rights
# To exercise your data protection rights, visit our...
#
# Header: Privacy Center
# Content Snippet: Privacy Center
# or contact us as outlined below....
#
# Header: 5. Security and Retention
# Content Snippet: 5. Security and Retention
# We make reasonable efforts to provide a level of security appropriate to the risk associated with the
# processing of your Per...
#
# Header: 6. International Data Transfers
# Content Snippet: 6. International Data Transfers
# As a global business, it's sometimes necessary for us to transfer your Personal Data to countries other
# than your own,...
#
# Header: 7. Updates and notifications
# Content Snippet: 7. Updates and notifications
# We may change this Policy from time to time to reflect new services, changes in our privacy practices or
# relevant laws. T...
#
# Header: 8. Jurisdiction-specific provisions
# Content Snippet: 8. Jurisdiction-specific provisions...
#
# Header: Australia
# Content Snippet: Australia
# . If you are an Australian resident and dissatisfied with our handling of any complaint you raise
# under this Policy, you may consider contac...
#
# Header: Brazil
# Content Snippet: Brazil
# . You may exercise your rights by contacting our DPO at
# dpo@stripe.com
# . Brazilian residents, for
# whom the Lei Geral de Proteção de Dados Pesso...
#
# Header: Canada.
# Content Snippet: Canada.
# As used in this Policy, “applicable law” includes the Federal Personal Information Protection and
# Electronic Documents Act (PIPEDA), the Perso...
#
# Header: India
# Content Snippet: India
# . In this Policy, “applicable law” includes the Digital Personal Data Protection Act (DPDPA) once the
# DPDPA is enacted. Further, the term “data ...
#
# Header: Indonesia
# Content Snippet: Indonesia
# . In this Policy, “applicable law” includes Law No. 11 of 2008 as amended by Law No. 19 of 2016 on
# Electronic Information and Transactions, ...
#
# Header: Japan
# Content Snippet: Japan
# . In this Policy, “applicable law” includes the Act on the Protection of Personal Information (APPI).
# When we transfer Personal Data of data sub...
#
# Header: Malaysia
# Content Snippet: Malaysia
# . If you have any questions or complaints about this Policy, please contact our DPO at
# dpo@stripe.com
# ....
#
# Header: Singapore
# Content Snippet: Singapore
# . In this Policy, “applicable law” includes the Personal Data Protection Act 2012 (PDPA) (No. 26 of
# 2012) as amended from time to time. In s...
#
# Header: Switzerland
# Content Snippet: Switzerland
# . In this Policy, “applicable law” includes the Swiss Federal Act on Data Protection (FADP), as
# revised. To exercise your rights under the...
#
# Header: Thailand
# Content Snippet: Thailand
# . In this Policy, “applicable law” includes the Personal Data Protection Act 2019 (PDPA). If we rely on
# certain legal bases (such as “legal o...
#
# Header: United States
# Content Snippet: United States
# . If you are a consumer located in the United States (“US”), we process your personal
# information in accordance with US privacy laws, in...
#
# Header: 9. Contact us
# Content Snippet: 9. Contact us
# If you have any questions or complaints about this Policy, please
# contact us
# . If you are an End Customer
# (i.e., an individual doing bus...
#
# Header: 10. US Consumer Privacy Notice
# Content Snippet: 10. US Consumer Privacy Notice
# The following Consumer Privacy Notice applies to you if you are an individual who resides in the United
# States and obta...
#
# Header: FACTS
# Content Snippet: FACTS
# WHAT DOES STRIPE DO WITH YOUR PERSONAL INFORMATION?...
#
# Header: Why?
# Content Snippet: Why?
# Financial companies choose how they share your personal information.  Federal law gives
# consumers the right to limit some but not all sharing.  F...
#
# Header: What?
# Content Snippet: What?
# The types of personal information we collect and share depend on the product or service
# you have with us. This information can include:
# • Social...
#
# Header: How?
# Content Snippet: How?
# All financial companies need to share customers' personal information to run their everyday
# business. In the section below, we list the reasons f...
#
# Header: Questions?
# Content Snippet: Questions?
# Contact us at privacy@stripe.com or visit us at https://support.link.com
# Who we are
# Who is providing this
# notice?
# Stripe, Inc., Stripe Paym...
#
# Header: Definitions
# Content Snippet: Definitions...
#
# Header: Affiliates
# Content Snippet: Affiliates
# Companies related by common ownership or control. They can be financial and
# nonfinancial companies.
# • Our affiliates include companies oper...
#
# Header: Nonaffiliates
# Content Snippet: Nonaffiliates
# Companies not related by common ownership or control.  They can be financial and
# nonfinancial companies.
# • Nonaffiliates with which we s...
#
# Header: Joint
# Content Snippet: Joint
# Marketing
# A formal agreement between non-affiliated financial companies that together market
# financial products or services to you.
# • Our joint ...
#
# Header: Stripe Services Agreement
# Content Snippet: Stripe Services Agreement
# Stripe Connected Account Agreement
# Stripe Payments Company Terms
# Acquirer Terms
# Acquirer Disclosure
# Cross River Bank
# Deutsch...
#
# Header: United States
# Content Snippet: United States
# (English)
# Products & pricing
# Pricing
# Atlas
# Billing
# Capital
# Checkout
# Climate
# Connect
# Data Pipeline
# Elements
# Financial Connections
# Identit...
#
# Header: Company
# Content Snippet: Company
# Jobs
# Newsroom
# 11/26/24, 8:51 PM
# Privacy Policy
# https://stripe.com/privacy
# 27/29
# Payments
# Payment Links
# Payouts
# Radar
# Revenue Recognition
# Sigma...
#
# Header: Developers
# Content Snippet: Developers
# Documentation
# API reference
# API status
# API changelog
# Stripe Apps
# Stripe Press...
#
# Header: Support
# Content Snippet: Support
# Contact sales
# Support center
# Support plans
# CA residents:
# +1 888 926 2289...
#
# Header: © 2024 Stripe, Inc.
# Content Snippet: © 2024 Stripe, Inc.
# 11/26/24, 8:51 PM
# Privacy Policy
# https://stripe.com/privacy
# 28/29
# 11/26/24, 8:51 PM
# Privacy Policy
# https://stripe.com/privacy
# 29/2...
#
# calculating potential headers
#
# Processed Result for /content/drive/MyDrive/210 Capstone/policy/stripe.pdf:
# Total number of chunks created: 88
#
# Header: Last updated: January 16, 2024
# Content Snippet: Last updated: January 16, 2024
# This Privacy Policy includes important information about your personal data and we encourage you to read
# it carefully....
#
# Header: Welcome
# Content Snippet: Welcome
# We provide financial infrastructure for the internet. Individuals and businesses of all sizes use our
# technology and services to facilitate pu...
#
# Header: Privacy Policy
# Content Snippet: Privacy Policy
# This Privacy Policy will be updated on January 16, 2025. Please review the upcoming changes
# here
# .
# 11/26/24, 8:51 PM
# Privacy Policy
# htt...
#
# Header: 1. Personal Data we collect and how we use and
# Content Snippet: 1. Personal Data we collect and how we use and...
#
# Header: share it
# Content Snippet: share it
# Our collection and use of Personal Data differs based on whether you are an End User, End Customer,
# Representative, or Visitor, and the speci...
#
# Header: 1.1 End Users
# Content Snippet: 1.1 End Users
# We provide End User Services when we provide the Services directly to you for your personal use (e.g.,
# Link). Additional details regardi...
#
# Header: a. Personal Data we collect about End Users
# Content Snippet: a. Personal Data we collect about End Users
# Using Link or Connecting your bank account.
# Stripe offers a service called "Link," which allows you to
# sto...
#
# Header: Paying Stripe.
# Content Snippet: Paying Stripe.
# When you purchase goods or services directly from Stripe, we receive your Transaction
# Data. For instance, when you make a payment to St...
#
# Header: Identity/Verification Services
# Content Snippet: Identity/Verification Services
# . We offer an identity verification service that automates the comparison of
# your identity document (such as a driver’s...
#
# Header: More
# Content Snippet: More
# . For further information about other types of Personal Data that we may collect about End Users,
# including about your online activity and your e...
#
# Header: b. How we use and share Personal Data of End Users
# Content Snippet: b. How we use and share Personal Data of End Users
# Services
# . We use and share your Personal Data to provide the End User Services to you, which inclu...
#
# Header: Our Business Users.
# Content Snippet: Our Business Users.
# When you use Link to make payments, we share your Transaction Data with the
# Business Users you choose to do business with.
# Learn M...
#
# Header: Transactions
# Content Snippet: Transactions
# . When you use Link to make payments, we use your Personal Data (such as name, contact
# information, payment method details) saved with us...
#
# Header: Advertising
# Content Snippet: Advertising
# . We may use your Personal Data to assess your eligibility for, and offer you, other End User
# Services or promote existing End User Servic...
#
# Header: More
# Content Snippet: More
# . For further information about additional ways by which we may use and share End Users' Personal
# Data, please see the
# More ways we collect, use,...
#
# Header: 1.2 End Customers
# Content Snippet: 1.2 End Customers
# Stripe provides various Business Services to our Business Users, which include in-person or online
# checkout payment processing or pr...
#
# Header: a. Personal Data we collect about End Customers
# Content Snippet: a. Personal Data we collect about End Customers
# 11/26/24, 8:51 PM
# Privacy Policy
# https://stripe.com/privacy
# 5/29
# Transaction Data.
# If you're an End Cu...
#
# Header: Identity/Verification Information
# Content Snippet: Identity/Verification Information
# . Stripe provides a verification and fraud prevention Service that our
# Business Users can use to verify Personal Dat...
#
# Header: More
# Content Snippet: More
# . For further information about other types of Personal Data that we may collect about End
# Customers, including about your online activity, pleas...
#
# Header: b. How we use and share Personal Data of End Customers
# Content Snippet: b. How we use and share Personal Data of End Customers
# To provide our Business Services to our Business Users, we use and share End Customers' Persona...
#
# Header: More
# Content Snippet: More
# . For further information about additional ways by which we may use and share  End Customers'
# Personal Data, please see the
# More ways we collect,...
#
# Header: 1.3 Representatives
# Content Snippet: 1.3 Representatives
# We collect, use, and share Personal Data from Representatives of Business Users (for example, business
# owners) to provide our Busi...
#
# Header: a. Personal Data we collect about Representatives
# Content Snippet: a. Personal Data we collect about Representatives
# Registration and contact information.
# When you register for a Stripe account for a Business User
# (in...
#
# Header: Identification Information
# Content Snippet: Identification Information
# . As a current or potential Business User, an owner of a Business User, or a
# shareholder, officer, or director of a Busines...
#
# Header: More
# Content Snippet: More
# . For further information about other types of Personal Data that we may collect about
# Representatives, including your online activity, please se...
#
# Header: b. How we use and share Personal Data of Representatives
# Content Snippet: b. How we use and share Personal Data of Representatives
# We typically use the Personal Data of Representatives to provide the Business Services to the...
#
# Header: Business Services.
# Content Snippet: Business Services.
# We use and share Representatives’ Personal Data with Business Users to provide the
# Services requested by you or the Business User y...
#
# Header: Advertising
# Content Snippet: Advertising
# . Where allowed by applicable law, we use and share Representatives’ Personal Data with third
# parties so we can advertise and market our S...
#
# Header: More
# Content Snippet: More
# . For further information about additional ways by which we may use and share Representatives’
# Personal Data, please see the
# More ways we collect...
#
# Header: 1.4 Visitors
# Content Snippet: 1.4 Visitors
# We collect, use, and share the Personal Data of Visitors. More details about how we collect, use, and share
# Visitors’ Personal Data, alon...
#
# Header: a. Personal Data we collect about Visitors
# Content Snippet: a. Personal Data we collect about Visitors
# When you browse our Sites, we receive your Personal Data, either provided directly by you or collected
# thro...
#
# Header: More
# Content Snippet: More
# . Further details about other types of Personal Data that we may collect from Visitors, including your
# online activity, can be found in the
# More ...
#
# Header: b. How we use and share Personal Data of Visitors
# Content Snippet: b. How we use and share Personal Data of Visitors...
#
# Header: Personalization
# Content Snippet: Personalization
# . We use the data we collect from cookies and similar technologies about you to measure
# user engagement with the content on the Sites,...
#
# Header: Advertising
# Content Snippet: Advertising
# . Where allowed by applicable law, we use and share Visitors’ Personal Data with third parties
# so we can advertise and market our Services...
#
# Header: Engagement
# Content Snippet: Engagement
# . As you interact with our Sites, we use the information we collect about and through your
# devices to provide opportunities for further int...
#
# Header: More
# Content Snippet: More
# . For further information about additional ways by which we may use and share Visitors’ Personal
# Data, please see the
# More ways we collect, use, ...
#
# Header: 2. More ways we collect, use, and share
# Content Snippet: 2. More ways we collect, use, and share...
#
# Header: Personal Data
# Content Snippet: Personal Data
# In addition to the ways described above, we also process your Personal Data as follows:...
#
# Header: a. Collection of Personal Data
# Content Snippet: a. Collection of Personal Data...
#
# Header: Online Activity
# Content Snippet: Online Activity
# . Depending on the Service used and how our Business Services are implemented by the
# Business Users, we may collect information relate...
#
# Header: b. Use of Personal Data.
# Content Snippet: b. Use of Personal Data.
# The devices and browsers you use across our Sites and third party websites, apps, and other online services
# (“Third Party Sit...
#
# Header: Communications
# Content Snippet: Communications
# . We use the contact information we have about you to deliver our Services, which may
# involve sending codes via SMS for your authentica...
#
# Header: Minors
# Content Snippet: Minors
# . Our Services are not directed to children under the age of 13, and we request that they do not
# provide Personal Data to seek Services directl...
#
# Header: c. Sharing of Personal Data.
# Content Snippet: c. Sharing of Personal Data.
# Besides the sharing of Personal Data described above, we share Personal Data in the ways listed below:...
#
# Header: Stripe Affiliates
# Content Snippet: Stripe Affiliates
# . We share Personal Data with other Stripe-affiliated entities for purposes identified in this
# Policy.
# Service Providers or Processo...
#
# Header: Financial Partners
# Content Snippet: Financial Partners
# . We share Personal Data with certain Financial Partners to provide Services to Business
# Users seeking such Services as well as off...
#
# Header: Corporate Transactions
# Content Snippet: Corporate Transactions
# . If we enter or intend to enter a transaction that modifies the structure of our
# business, such as a reorganization, merger, s...
#
# Header: 3. Legal bases for processing Personal Data
# Content Snippet: 3. Legal bases for processing Personal Data
# For purposes of the General Data Protection Regulation and other applicable data protection laws, we rely
# ...
#
# Header: 4. Your rights and choices
# Content Snippet: 4. Your rights and choices
# Depending on your location and subject to applicable law, you may have choices regarding our collection,
# use, and disclosur...
#
# Header: Learn More
# Content Snippet: Learn More
# );
# Response to inquiries, delivery of Service notices, and provision of customer support;
# Promotion, analysis, modification, and improvemen...
#
# Header: a. Opting out of receiving electronic communications from us
# Content Snippet: a. Opting out of receiving electronic communications from us
# If you wish to stop receiving marketing-related emails from us, you can opt-out by clicki...
#
# Header: b. Your data protection rights
# Content Snippet: b. Your data protection rights
# Depending on your location and subject to applicable law, you may have the following rights regarding the
# Personal Data...
#
# Header: Learn
# Content Snippet: Learn
# More
# );
# The right to request that Stripe restrict the use of your Personal Data in certain circumstances, such as
# while Stripe is considering an...
#
# Header: c. Process for exercising your data protection rights
# Content Snippet: c. Process for exercising your data protection rights
# To exercise your data protection rights, visit our...
#
# Header: Privacy Center
# Content Snippet: Privacy Center
# or contact us as outlined below....
#
# Header: 5. Security and Retention
# Content Snippet: 5. Security and Retention
# We make reasonable efforts to provide a level of security appropriate to the risk associated with the
# processing of your Per...
#
# Header: 6. International Data Transfers
# Content Snippet: 6. International Data Transfers
# As a global business, it's sometimes necessary for us to transfer your Personal Data to countries other
# than your own,...
#
# Header: 7. Updates and notifications
# Content Snippet: 7. Updates and notifications
# We may change this Policy from time to time to reflect new services, changes in our privacy practices or
# relevant laws. T...
#
# Header: 8. Jurisdiction-specific provisions
# Content Snippet: 8. Jurisdiction-specific provisions...
#
# Header: Australia
# Content Snippet: Australia
# . If you are an Australian resident and dissatisfied with our handling of any complaint you raise
# under this Policy, you may consider contac...
#
# Header: Brazil
# Content Snippet: Brazil
# . You may exercise your rights by contacting our DPO at
# dpo@stripe.com
# . Brazilian residents, for
# whom the Lei Geral de Proteção de Dados Pesso...
#
# Header: Canada.
# Content Snippet: Canada.
# As used in this Policy, “applicable law” includes the Federal Personal Information Protection and
# Electronic Documents Act (PIPEDA), the Perso...
#
# Header: India
# Content Snippet: India
# . In this Policy, “applicable law” includes the Digital Personal Data Protection Act (DPDPA) once the
# DPDPA is enacted. Further, the term “data ...
#
# Header: Indonesia
# Content Snippet: Indonesia
# . In this Policy, “applicable law” includes Law No. 11 of 2008 as amended by Law No. 19 of 2016 on
# Electronic Information and Transactions, ...
#
# Header: Japan
# Content Snippet: Japan
# . In this Policy, “applicable law” includes the Act on the Protection of Personal Information (APPI).
# When we transfer Personal Data of data sub...
#
# Header: Malaysia
# Content Snippet: Malaysia
# . If you have any questions or complaints about this Policy, please contact our DPO at
# dpo@stripe.com
# ....
#
# Header: Singapore
# Content Snippet: Singapore
# . In this Policy, “applicable law” includes the Personal Data Protection Act 2012 (PDPA) (No. 26 of
# 2012) as amended from time to time. In s...
#
# Header: Switzerland
# Content Snippet: Switzerland
# . In this Policy, “applicable law” includes the Swiss Federal Act on Data Protection (FADP), as
# revised. To exercise your rights under the...
#
# Header: Thailand
# Content Snippet: Thailand
# . In this Policy, “applicable law” includes the Personal Data Protection Act 2019 (PDPA). If we rely on
# certain legal bases (such as “legal o...
#
# Header: United States
# Content Snippet: United States
# . If you are a consumer located in the United States (“US”), we process your personal
# information in accordance with US privacy laws, in...
#
# Header: 9. Contact us
# Content Snippet: 9. Contact us
# If you have any questions or complaints about this Policy, please
# contact us
# . If you are an End Customer
# (i.e., an individual doing bus...
#
# Header: 10. US Consumer Privacy Notice
# Content Snippet: 10. US Consumer Privacy Notice
# The following Consumer Privacy Notice applies to you if you are an individual who resides in the United
# States and obta...
#
# Header: FACTS
# Content Snippet: FACTS
# WHAT DOES STRIPE DO WITH YOUR PERSONAL INFORMATION?...
#
# Header: Why?
# Content Snippet: Why?
# Financial companies choose how they share your personal information.  Federal law gives
# consumers the right to limit some but not all sharing.  F...
#
# Header: What?
# Content Snippet: What?
# The types of personal information we collect and share depend on the product or service
# you have with us. This information can include:
# • Social...
#
# Header: How?
# Content Snippet: How?
# All financial companies need to share customers' personal information to run their everyday
# business. In the section below, we list the reasons f...
#
# Header: Questions?
# Content Snippet: Questions?
# Contact us at privacy@stripe.com or visit us at https://support.link.com
# Who we are
# Who is providing this
# notice?
# Stripe, Inc., Stripe Paym...
#
# Header: Definitions
# Content Snippet: Definitions...
#
# Header: Affiliates
# Content Snippet: Affiliates
# Companies related by common ownership or control. They can be financial and
# nonfinancial companies.
# • Our affiliates include companies oper...
#
# Header: Nonaffiliates
# Content Snippet: Nonaffiliates
# Companies not related by common ownership or control.  They can be financial and
# nonfinancial companies.
# • Nonaffiliates with which we s...
#
# Header: Joint
# Content Snippet: Joint
# Marketing
# A formal agreement between non-affiliated financial companies that together market
# financial products or services to you.
# • Our joint ...
#
# Header: Stripe Services Agreement
# Content Snippet: Stripe Services Agreement
# Stripe Connected Account Agreement
# Stripe Payments Company Terms
# Acquirer Terms
# Acquirer Disclosure
# Cross River Bank
# Deutsch...
#
# Header: United States
# Content Snippet: United States
# (English)
# Products & pricing
# Pricing
# Atlas
# Billing
# Capital
# Checkout
# Climate
# Connect
# Data Pipeline
# Elements
# Financial Connections
# Identit...
#
# Header: Company
# Content Snippet: Company
# Jobs
# Newsroom
# 11/26/24, 8:51 PM
# Privacy Policy
# https://stripe.com/privacy
# 27/29
# Payments
# Payment Links
# Payouts
# Radar
# Revenue Recognition
# Sigma...
#
# Header: Developers
# Content Snippet: Developers
# Documentation
# API reference
# API status
# API changelog
# Stripe Apps
# Stripe Press...
#
# Header: Support
# Content Snippet: Support
# Contact sales
# Support center
# Support plans
# CA residents:
# +1 888 926 2289...
#
# Header: © 2024 Stripe, Inc.
# Content Snippet: © 2024 Stripe, Inc.
# 11/26/24, 8:51 PM
# Privacy Policy
# https://stripe.com/privacy
# 28/29
# 11/26/24, 8:51 PM
# Privacy Policy
# https://stripe.com/privacy
# 29/2...
#
# Total number of sub-chunks created: 128
#
# Chunk 1/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Last updated: January 16, 2024
# Sub-chunk 1/1
# Content Snippet: Last updated: January 16, 2024
# This Privacy Policy includes important information about your personal data and we encourage you to read
# it carefully....
#
# Chunk 2/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Welcome
# Sub-chunk 1/2
# Content Snippet: Welcome
# We provide financial infrastructure for the internet. Individuals and businesses of all sizes use our
# technology and services to facilitate pu...
#
# Chunk 3/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Welcome
# Sub-chunk 2/2
# Content Snippet: Learn More
# .
# “Personal Data” refers to any information associated with an identified or identifiable individual, which can
# include data that you provi...
#
# Chunk 4/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Privacy Policy
# Sub-chunk 1/4
# Content Snippet: Privacy Policy
# This Privacy Policy will be updated on January 16, 2025. Please review the upcoming changes
# here
# .
# 11/26/24, 8:51 PM
# Privacy Policy
# htt...
#
# Chunk 5/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Privacy Policy
# Sub-chunk 2/4
# Content Snippet: acquirers, payout providers, and card networks that we partner with to provide the Services.
# Depending on the context, “you” might be an End Customer,...
#
# Chunk 6/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Privacy Policy
# Sub-chunk 3/4
# Content Snippet: Privacy Center
# .
# 1. Personal Data that we collect and how we use and share it
# 2. More ways we collect, use and share Personal Data
# 3. Legal bases for ...
#
# Chunk 7/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Privacy Policy
# Sub-chunk 4/4
# Content Snippet: interaction with Stripe does not involve you being an End User, End Customer, or Representative, you are
# considered a “Visitor.” For example, you are ...
#
# Chunk 8/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: 1. Personal Data we collect and how we use and
# Sub-chunk 1/1
# Content Snippet: 1. Personal Data we collect and how we use and...
#
# Chunk 9/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: share it
# Sub-chunk 1/1
# Content Snippet: share it
# Our collection and use of Personal Data differs based on whether you are an End User, End Customer,
# Representative, or Visitor, and the speci...
#
# Chunk 10/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: 1.1 End Users
# Sub-chunk 1/1
# Content Snippet: 1.1 End Users
# We provide End User Services when we provide the Services directly to you for your personal use (e.g.,
# Link). Additional details regardi...
#
# Chunk 11/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: a. Personal Data we collect about End Users
# Sub-chunk 1/2
# Content Snippet: a. Personal Data we collect about End Users
# Using Link or Connecting your bank account.
# Stripe offers a service called "Link," which allows you to
# sto...
#
# Chunk 12/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: a. Personal Data we collect about End Users
# Sub-chunk 2/2
# Content Snippet: and, in some cases, log-in credentials). You can ask us to cease the collection of such data at any time.
# Learn More
# .
# You may also choose to store yo...
#
# Chunk 13/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Paying Stripe.
# Sub-chunk 1/1
# Content Snippet: Paying Stripe.
# When you purchase goods or services directly from Stripe, we receive your Transaction
# Data. For instance, when you make a payment to St...
#
# Chunk 14/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Identity/Verification Services
# Sub-chunk 1/1
# Content Snippet: Identity/Verification Services
# . We offer an identity verification service that automates the comparison of
# your identity document (such as a driver’s...
#
# Chunk 15/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: More
# Sub-chunk 1/1
# Content Snippet: More
# . For further information about other types of Personal Data that we may collect about End Users,
# including about your online activity and your e...
#
# Chunk 16/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: b. How we use and share Personal Data of End Users
# Sub-chunk 1/1
# Content Snippet: b. How we use and share Personal Data of End Users
# Services
# . We use and share your Personal Data to provide the End User Services to you, which inclu...
#
# Chunk 17/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Our Business Users.
# Sub-chunk 1/1
# Content Snippet: Our Business Users.
# When you use Link to make payments, we share your Transaction Data with the
# Business Users you choose to do business with.
# Learn M...
#
# Chunk 18/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Transactions
# Sub-chunk 1/2
# Content Snippet: Transactions
# . When you use Link to make payments, we use your Personal Data (such as name, contact
# information, payment method details) saved with us...
#
# Chunk 19/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Transactions
# Sub-chunk 2/2
# Content Snippet: transaction. Learn more about how we may use technology to assess the fraud risk associated with an
# attempted transaction and what information we shar...
#
# Chunk 20/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Advertising
# Sub-chunk 1/1
# Content Snippet: Advertising
# . We may use your Personal Data to assess your eligibility for, and offer you, other End User
# Services or promote existing End User Servic...
#
# Chunk 21/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: More
# Sub-chunk 1/1
# Content Snippet: More
# . For further information about additional ways by which we may use and share End Users' Personal
# Data, please see the
# More ways we collect, use,...
#
# Chunk 22/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: 1.2 End Customers
# Sub-chunk 1/2
# Content Snippet: 1.2 End Customers
# Stripe provides various Business Services to our Business Users, which include in-person or online
# checkout payment processing or pr...
#
# Chunk 23/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: 1.2 End Customers
# Sub-chunk 2/2
# Content Snippet: the Business User you're doing business with for its privacy practices, choices, and controls.
# We provide more comprehensive information about our col...
#
# Chunk 24/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: a. Personal Data we collect about End Customers
# Sub-chunk 1/1
# Content Snippet: a. Personal Data we collect about End Customers
# 11/26/24, 8:51 PM
# Privacy Policy
# https://stripe.com/privacy
# 5/29
# Transaction Data.
# If you're an End Cu...
#
# Chunk 25/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Identity/Verification Information
# Sub-chunk 1/1
# Content Snippet: Identity/Verification Information
# . Stripe provides a verification and fraud prevention Service that our
# Business Users can use to verify Personal Dat...
#
# Chunk 26/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: More
# Sub-chunk 1/1
# Content Snippet: More
# . For further information about other types of Personal Data that we may collect about End
# Customers, including about your online activity, pleas...
#
# Chunk 27/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: b. How we use and share Personal Data of End Customers
# Sub-chunk 1/6
# Content Snippet: b. How we use and share Personal Data of End Customers
# To provide our Business Services to our Business Users, we use and share End Customers' Persona...
#
# Chunk 28/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: b. How we use and share Personal Data of End Customers
# Sub-chunk 2/6
# Content Snippet: transaction. As a service provider or data processor, we share Personal Data to enable transactions as
# directed by Business Users. For instance, when ...
#
# Chunk 29/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: b. How we use and share Personal Data of End Customers
# Sub-chunk 3/6
# Content Snippet: Business User. In addition to any Transaction Data we may generate or receive when these cards are used
# for purchases, we also collect and utilize you...
#
# Chunk 30/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: b. How we use and share Personal Data of End Customers
# Sub-chunk 4/6
# Content Snippet: Learn More
# .
# Fraud detection and loss prevention
# . We use your Personal Data collected across our Services to detect
# and prevent losses for you, us, o...
#
# Chunk 31/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: b. How we use and share Personal Data of End Customers
# Sub-chunk 5/6
# Content Snippet: parties (like additional third party service providers other than Stripe). Please review the Business User’s
# privacy policy for more information.
# Adve...
#
# Chunk 32/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: b. How we use and share Personal Data of End Customers
# Sub-chunk 6/6
# Content Snippet: latter uses Stripe Identity, our identity verification Service, to verify the identity of the End Customer.
# 11/26/24, 8:51 PM
# Privacy Policy
# https://s...
#
# Chunk 33/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: More
# Sub-chunk 1/1
# Content Snippet: More
# . For further information about additional ways by which we may use and share  End Customers'
# Personal Data, please see the
# More ways we collect,...
#
# Chunk 34/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: 1.3 Representatives
# Sub-chunk 1/1
# Content Snippet: 1.3 Representatives
# We collect, use, and share Personal Data from Representatives of Business Users (for example, business
# owners) to provide our Busi...
#
# Chunk 35/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: a. Personal Data we collect about Representatives
# Sub-chunk 1/1
# Content Snippet: a. Personal Data we collect about Representatives
# Registration and contact information.
# When you register for a Stripe account for a Business User
# (in...
#
# Chunk 36/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Identification Information
# Sub-chunk 1/1
# Content Snippet: Identification Information
# . As a current or potential Business User, an owner of a Business User, or a
# shareholder, officer, or director of a Busines...
#
# Chunk 37/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: More
# Sub-chunk 1/1
# Content Snippet: More
# . For further information about other types of Personal Data that we may collect about
# Representatives, including your online activity, please se...
#
# Chunk 38/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: b. How we use and share Personal Data of Representatives
# Sub-chunk 1/1
# Content Snippet: b. How we use and share Personal Data of Representatives
# We typically use the Personal Data of Representatives to provide the Business Services to the...
#
# Chunk 39/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Business Services.
# Sub-chunk 1/3
# Content Snippet: Business Services.
# We use and share Representatives’ Personal Data with Business Users to provide the
# Services requested by you or the Business User y...
#
# Chunk 40/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Business Services.
# Sub-chunk 2/3
# Content Snippet: Business User, such as Financial Partners servicing a financial product, or third party apps or services the
# Business User chooses to use alongside ou...
#
# Chunk 41/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Business Services.
# Sub-chunk 3/3
# Content Snippet: from third parties like credit bureaus and from our Services to address such risks, including to identify
# patterns of misuse and monitor for terms of ...
#
# Chunk 42/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Advertising
# Sub-chunk 1/2
# Content Snippet: Advertising
# . Where allowed by applicable law, we use and share Representatives’ Personal Data with third
# parties so we can advertise and market our S...
#
# Chunk 43/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Advertising
# Sub-chunk 2/2
# Content Snippet: Learn More
# .
# A Business User may authorize Stripe to share your Personal Data with other Business Users to facilitate the
# provision of Services throug...
#
# Chunk 44/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: More
# Sub-chunk 1/1
# Content Snippet: More
# . For further information about additional ways by which we may use and share Representatives’
# Personal Data, please see the
# More ways we collect...
#
# Chunk 45/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: 1.4 Visitors
# Sub-chunk 1/1
# Content Snippet: 1.4 Visitors
# We collect, use, and share the Personal Data of Visitors. More details about how we collect, use, and share
# Visitors’ Personal Data, alon...
#
# Chunk 46/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: a. Personal Data we collect about Visitors
# Sub-chunk 1/1
# Content Snippet: a. Personal Data we collect about Visitors
# When you browse our Sites, we receive your Personal Data, either provided directly by you or collected
# thro...
#
# Chunk 47/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: More
# Sub-chunk 1/1
# Content Snippet: More
# . Further details about other types of Personal Data that we may collect from Visitors, including your
# online activity, can be found in the
# More ...
#
# Chunk 48/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: b. How we use and share Personal Data of Visitors
# Sub-chunk 1/1
# Content Snippet: b. How we use and share Personal Data of Visitors...
#
# Chunk 49/128
# PDF Path: /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
# Header: Personalization
# Sub-chunk 1/1
# Content Snippet: Personalization
# . We use the data we collect from cookies and similar technologies about you to measure
# user engagement with the content on the Sites,...
#
# Chunk 50/128
# ...
# --------------------------------------------------
# Document 95:
# Page Content: India
# . In this Policy, “applicable law” includes the Digital Personal Data Protection Act (DPDPA) o...
# Metadata: {'chunk_number': 95, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'India', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 96:
# Page Content: number by Stripe India Private Limited and/or its third party verification partner(s). The purpose o...
# Metadata: {'chunk_number': 96, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'India', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 97:
# Page Content: Indonesia
# . In this Policy, “applicable law” includes Law No. 11 of 2008 as amended by Law No. 19 of...
# Metadata: {'chunk_number': 97, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Indonesia', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 98:
# Page Content: Japan
# . In this Policy, “applicable law” includes the Act on the Protection of Personal Information ...
# Metadata: {'chunk_number': 98, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Japan', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 99:
# Page Content: Malaysia
# . If you have any questions or complaints about this Policy, please contact our DPO at
# dpo@...
# Metadata: {'chunk_number': 99, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Malaysia', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 100:
# Page Content: Singapore
# . In this Policy, “applicable law” includes the Personal Data Protection Act 2012 (PDPA) (...
# Metadata: {'chunk_number': 100, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Singapore', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 101:
# Page Content: Switzerland
# . In this Policy, “applicable law” includes the Swiss Federal Act on Data Protection (FA...
# Metadata: {'chunk_number': 101, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Switzerland', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 102:
# Page Content: Thailand
# . In this Policy, “applicable law” includes the Personal Data Protection Act 2019 (PDPA). I...
# Metadata: {'chunk_number': 102, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Thailand', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 103:
# Page Content: United States
# . If you are a consumer located in the United States (“US”), we process your personal
# ...
# Metadata: {'chunk_number': 103, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'United States', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 104:
# Page Content: above rights
# , other rights include:
# Exercising the right to know: You have a right to request addit...
# Metadata: {'chunk_number': 104, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'United States', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 105:
# Page Content: applicable US privacy laws. You can opt out of targeted advertising and any related data “sales”
# or ...
# Metadata: {'chunk_number': 105, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'United States', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 106:
# Page Content: below for more information.
# We will verify your request by asking you to send it from the email addr...
# Metadata: {'chunk_number': 106, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'United States', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 107:
# Page Content: dispute resolution provider (free of charge) at
# https://feedback-form.truste.com/watchdog/request
# . ...
# Metadata: {'chunk_number': 107, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'United States', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 108:
# Page Content: 9. Contact us
# If you have any questions or complaints about this Policy, please
# contact us
# . If you ...
# Metadata: {'chunk_number': 108, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '9. Contact us', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 109:
# Page Content: 10. US Consumer Privacy Notice
# The following Consumer Privacy Notice applies to you if you are an in...
# Metadata: {'chunk_number': 109, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '10. US Consumer Privacy Notice', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 110:
# Page Content: FACTS
# WHAT DOES STRIPE DO WITH YOUR PERSONAL INFORMATION?...
# Metadata: {'chunk_number': 110, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'FACTS', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 111:
# Page Content: Why?
# Financial companies choose how they share your personal information.  Federal law gives
# consume...
# Metadata: {'chunk_number': 111, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Why?', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 112:
# Page Content: What?
# The types of personal information we collect and share depend on the product or service
# you ha...
# Metadata: {'chunk_number': 112, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'What?', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 113:
# Page Content: How?
# All financial companies need to share customers' personal information to run their everyday
# bus...
# Metadata: {'chunk_number': 113, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'How?', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 114:
# Page Content: No
# We don’t
# share
# 11/26/24, 8:51 PM
# Privacy Policy
# https://stripe.com/privacy
# 23/29
# For nonaffiliate...
# Metadata: {'chunk_number': 114, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'How?', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 115:
# Page Content: Questions?
# Contact us at privacy@stripe.com or visit us at https://support.link.com
# Who we are
# Who i...
# Metadata: {'chunk_number': 115, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Questions?', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 116:
# Page Content: 11/26/24, 8:51 PM
# Privacy Policy
# https://stripe.com/privacy
# 24/29
# We also collect your personal info...
# Metadata: {'chunk_number': 116, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Questions?', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 117:
# Page Content: Definitions...
# Metadata: {'chunk_number': 117, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Definitions', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 118:
# Page Content: Affiliates
# Companies related by common ownership or control. They can be financial and
# nonfinancial ...
# Metadata: {'chunk_number': 118, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Affiliates', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 119:
# Page Content: Nonaffiliates
# Companies not related by common ownership or control.  They can be financial and
# nonfi...
# Metadata: {'chunk_number': 119, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Nonaffiliates', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 120:
# Page Content: Joint
# Marketing
# A formal agreement between non-affiliated financial companies that together market
# f...
# Metadata: {'chunk_number': 120, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Joint', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 121:
# Page Content: Stripe Services Agreement
# Stripe Connected Account Agreement
# Stripe Payments Company Terms
# Acquirer ...
# Metadata: {'chunk_number': 121, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Stripe Services Agreement', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 122:
# Page Content: disclose your name, contact information, and information about your transactions.  Additional inform...
# Metadata: {'chunk_number': 122, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Stripe Services Agreement', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 123:
# Page Content: Marks Usage
# E-SIGN Disclosure
# Licenses
# Consumer Terms...
# Metadata: {'chunk_number': 123, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Stripe Services Agreement', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 124:
# Page Content: United States
# (English)
# Products & pricing
# Pricing
# Atlas
# Billing
# Capital
# Checkout
# Climate
# Connect
# Da...
# Metadata: {'chunk_number': 124, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'United States', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 125:
# Page Content: Company
# Jobs
# Newsroom
# 11/26/24, 8:51 PM
# Privacy Policy
# https://stripe.com/privacy
# 27/29
# Payments
# Pay...
# Metadata: {'chunk_number': 125, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Company', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 126:
# Page Content: Developers
# Documentation
# API reference
# API status
# API changelog
# Stripe Apps
# Stripe Press...
# Metadata: {'chunk_number': 126, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Developers', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 127:
# Page Content: Support
# Contact sales
# Support center
# Support plans
# CA residents:
# +1 888 926 2289...
# Metadata: {'chunk_number': 127, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Support', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# Document 128:
# Page Content: © 2024 Stripe, Inc.
# 11/26/24, 8:51 PM
# Privacy Policy
# https://stripe.com/privacy
# 28/29
# 11/26/24, 8:51...
# Metadata: {'chunk_number': 128, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '© 2024 Stripe, Inc.', 'doc_link': '/content/drive/MyDrive/210 Capstone/policy/stripe.pdf'}
# --------------------------------------------------
# [DEBUG] Connected to Qdrant cloud instance
# [DEBUG] Detected embedding size: 768
# <ipython-input-40-1a61bc7b3a3c>:73: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   qdrant_client.recreate_collection(
# [DEBUG] Collection 'policy_pulse_db' recreated successfully
# [DEBUG] Documents added to Qdrant collection
# [TEST] Applying retrieval filter with company_name: 'stripe'
# Ask your question: What personal data does Stripe collect from End Users of Link?
# [PROCESSING] Question: What personal data does Stripe collect from End Users of Link?
# extracted company name: stripe
# extracted question_type: Policy
# [PROCESSING] Retrieving Policy content for question: What personal data does Stripe collect from End Users of Link? (stripe)
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# [INFO] Retrieving GDPR articles for the question using semantic similarity
# [DEBUG] Retrieved Policy Context Snippets:
# Snippet 1: a. Personal Data we collect about End Users
# Using Link or Connecting your bank account.
# Stripe offers a service called "Link," which allows you to
# store your payment methods with Stripe to convenientl...
# Snippet 2: FACTS
# WHAT DOES STRIPE DO WITH YOUR PERSONAL INFORMATION?...
# Snippet 3: Transactions
# . When you use Link to make payments, we use your Personal Data (such as name, contact
# information, payment method details) saved with us to complete transactions with Stripe Business Use...
# Snippet 4: a. Personal Data we collect about End Customers
# 11/26/24, 8:51 PM
# Privacy Policy
# https://stripe.com/privacy
# 5/29
# Transaction Data.
# If you're an End Customer making payments to, receiving refunds from,...
#
# [DEBUG] Retrieved Context Snippets:
#
# Snippet 1:
# a. Personal Data we collect about End Users
# Using Link or Connecting your bank account.
# Stripe offers a service called "Link," which allows you to
# store your payment methods with Stripe to convenientl...
#
# Snippet 2:
# FACTS
# WHAT DOES STRIPE DO WITH YOUR PERSONAL INFORMATION?...
#
# Snippet 3:
# Transactions
# . When you use Link to make payments, we use your Personal Data (such as name, contact
# information, payment method details) saved with us to complete transactions with Stripe Business Use...
#
# Snippet 4:
# a. Personal Data we collect about End Customers
# 11/26/24, 8:51 PM
# Privacy Policy
# https://stripe.com/privacy
# 5/29
# Transaction Data.
# If you're an End Customer making payments to, receiving refunds from,...
#
# Returning the following to the UI:
#
# **Main Answer:**
# Stripe offers a service called "Link," which allows you to store your payment methods with Stripe to conveniently use them across our Business Users. When you sign up for Link, you agree to store your Personal Data (such as name, contact information, payment method details) with Stripe. This will allow for a more streamlined purchasing experience when using Link.
#
# **Key Points:**
# - In terms of GDPR compliance measures, Stripe has implemented various features to ensure that all data is properly protected. These include using HTTPS encryption for all communication, implementing strict access controls, and providing a number of tools to help businesses meet their GDPR obligations. Additionally, Stripe offers a number of GDPR-specific features such as data portability, deletion rights, and data retention rights.
# - Overall, Stripe is committed to ensuring that all of its services are compliant with GDPR regulations. Businesses can rest assured that their data is stored securely and in accordance with GDPR guidelines.
#
#
# /content/drive/MyDrive/210 Capstone/policy/stripe.pdf, /content/drive/MyDrive/210 Capstone/policy/stripe.pdf, /content/drive/MyDrive/210 Capstone/policy/stripe.pdf, /content/drive/MyDrive/210 Capstone/policy/stripe.pdf
