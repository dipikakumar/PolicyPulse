# %% [markdown]
#  ### PolicyPulse
#
# PolicyPulse:
#
# PolicyPulse is an AI-driven system designed to streamline the privacy policy compliance process. The project leverages a Retrieval-Augmented Generation (RAG) pipeline to analyze Financial company privacy policies (OPP Corpus)  and determine their compliance with regulations such as GDPR and CCPA. The system allows users to upload privacy policies, which are then parsed into segments. Using a combination of large language models (LLMs) and a knowledge base of regulatory documents, the system can answer compliance-related questions and flag areas where a policy may not fully adhere to the required standards.
#
# Key features:
#
# 1. Privacy Policy Fragmentation: Uploaded policies are broken down into manageable segments that can be individually analyzed.
#
# 2. Retrieval-Augmented Generation (RAG): The system retrieves relevant GDPR/CCPA guidelines and compares them with the uploaded policy segments to assess compliance.
#
# 3. Dynamic Q&A: Users can ask specific compliance questions, and the system will provide responses based on both the policy content and regulatory requirements.
#
# 4. Compliance Reporting: PolicyPulse generates a summary of compliance status, highlighting any gaps or missing information that need to be addressed.
#
# 5. Targeted Feedback: The system offers recommendations on how to make the policy compliant with GDPR/CCPA regulations.
#
#
# *  To implement a RAG system using LangChain
# *  Be able to formulate metric(s) that you may want to choose as your evaluation to what degree your system replicates gold answers (labeled data) that we will provide.
# * Try out various hyper-parameters and settings to see which configuration works the best (given your chosen metric)
# * Write a comprehensive evaluation, which also includes risks and limitations (and a lot more)
#
#
#
# Base RAG components
#
#   2.1 Text Embeddings
#   2.2 Text Chunking
#   2.3 The Vector DB & Semantic Search
#   2.4 The Language Model
#   2.5 Testing the LLM in a LangChain Chain
#   2.6. Setting up a simple RAG Chain

# %%
# !pip install --upgrade openai
# !pip -q install git+https://github.com/huggingface/transformers
# !pip install -q datasets loralib sentencepiece
# !pip -q install bitsandbytes accelerate
# !pip -q install langchain
# !pip install einops
# !pip install faiss-gpu
# !pip install --upgrade --quiet  langchain-community chromadb bs4 qdrant-client
# !pip install langchainhub

# !pip install --upgrade --quiet  wikipedia
# !pip install --upgrade --quiet  arxiv
# !pip install --upgrade --quiet  pymupdf

# !pip install xmltodict

# !pip install cohere

# !pip install unstructured
# !pip install PyMuPDF
# !pip install pdfminer.six
# !pip install qdrant-client
# !pip install sentence_transformers
# !pip install pi_heif
# !pip install unstructured_inference
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.54.4)
# Collecting openai
#   Downloading openai-1.55.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.7.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Downloading openai-1.55.0-py3-none-any.whl (389 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.5/389.5 kB 11.7 MB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.54.4
#     Uninstalling openai-1.54.4:
#       Successfully uninstalled openai-1.54.4
# Successfully installed openai-1.55.0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for transformers (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 16.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.8.0)
# Collecting faiss-gpu
#   Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Downloading faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 8.5 MB/s eta 0:00:00
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.7.2
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 38.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.9/617.9 kB 38.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 62.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.2/267.2 kB 21.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 21.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 8.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 64.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 62.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 43.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.5/409.5 kB 28.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 70.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 94.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 31.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 26.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 96.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.7/425.7 kB 37.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.2/168.2 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.1 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.28.3 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 5.28.3 which is incompatible.
# Collecting langchainhub
#   Downloading langchainhub-0.1.21-py3-none-any.whl.metadata (659 bytes)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchainhub) (24.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchainhub) (2.32.3)
# Collecting types-requests<3.0.0.0,>=2.31.0.2 (from langchainhub)
#   Downloading types_requests-2.32.0.20241016-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchainhub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchainhub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchainhub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchainhub) (2024.8.30)
# Downloading langchainhub-0.1.21-py3-none-any.whl (5.2 kB)
# Downloading types_requests-2.32.0.20241016-py3-none-any.whl (15 kB)
# Installing collected packages: types-requests, langchainhub
# Successfully installed langchainhub-0.1.21 types-requests-2.32.0.20241016
#   Preparing metadata (setup.py) ... done
#   Building wheel for wikipedia (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 4.7 MB/s eta 0:00:00
#   Building wheel for sgmllib3k (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 93.8 MB/s eta 0:00:00
# Collecting xmltodict
#   Downloading xmltodict-0.14.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Downloading xmltodict-0.14.2-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.14.2
# Collecting cohere
#   Downloading cohere-5.11.4-py3-none-any.whl.metadata (3.5 kB)
# Collecting fastavro<2.0.0,>=1.9.4 (from cohere)
#   Downloading fastavro-1.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Requirement already satisfied: httpx>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.27.2)
# Requirement already satisfied: httpx-sse==0.4.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.4.0)
# Collecting parameterized<0.10.0,>=0.9.0 (from cohere)
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pydantic>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.9.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.23.4)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.32.3)
# Requirement already satisfied: tokenizers<1,>=0.15 in /usr/local/lib/python3.10/dist-packages (from cohere) (0.20.3)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (2.32.0.20241016)
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from cohere) (4.12.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.21.2->cohere) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.21.2->cohere) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.2->cohere) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.0.0->cohere) (2.2.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers<1,>=0.15->cohere) (0.26.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere) (4.66.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.21.2->cohere) (1.2.2)
# Downloading cohere-5.11.4-py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.7/249.7 kB 8.5 MB/s eta 0:00:00
# Downloading fastavro-1.9.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 64.6 MB/s eta 0:00:00
# Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Installing collected packages: parameterized, fastavro, cohere
# Successfully installed cohere-5.11.4 fastavro-1.9.7 parameterized-0.9.0
# Collecting unstructured
#   Downloading unstructured-0.16.6-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured) (5.2.0)
# Collecting filetype (from unstructured)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from unstructured) (5.3.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from unstructured) (3.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from unstructured) (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from unstructured) (4.12.3)
# Collecting emoji (from unstructured)
#   Downloading emoji-2.14.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.10/dist-packages (from unstructured) (0.6.7)
# Collecting python-iso639 (from unstructured)
#   Downloading python_iso639-2024.10.22-py3-none-any.whl.metadata (13 kB)
# Collecting langdetect (from unstructured)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 22.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from unstructured) (1.26.4)
# Collecting rapidfuzz (from unstructured)
#   Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: backoff in /usr/local/lib/python3.10/dist-packages (from unstructured) (2.2.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from unstructured) (4.12.2)
# Collecting unstructured-client (from unstructured)
#   Downloading unstructured_client-0.28.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from unstructured) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from unstructured) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unstructured) (5.9.5)
# Collecting python-oxmsg (from unstructured)
#   Downloading python_oxmsg-0.0.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.10/dist-packages (from unstructured) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->unstructured) (2.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->unstructured) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json->unstructured) (0.9.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib->unstructured) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured) (2024.9.11)
# Collecting olefile (from python-oxmsg->unstructured)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured) (2024.8.30)
# Collecting aiofiles>=24.1.0 (from unstructured-client->unstructured)
#   Downloading aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: cryptography>=3.1 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (43.0.3)
# Requirement already satisfied: eval-type-backport<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (0.2.0)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (0.27.2)
# Collecting jsonpath-python<2.0.0,>=1.0.6 (from unstructured-client->unstructured)
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (1.6.0)
# Requirement already satisfied: pydantic<2.10.0,>=2.9.2 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (2.9.2)
# Collecting pypdf>=4.0 (from unstructured-client->unstructured)
#   Downloading pypdf-5.1.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: python-dateutil==2.8.2 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (2.8.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured) (1.0.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.1->unstructured-client->unstructured) (1.17.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->unstructured-client->unstructured) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.0.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.27.0->unstructured-client->unstructured) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.10.0,>=2.9.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<2.10.0,>=2.9.2->unstructured-client->unstructured) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured) (1.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.1->unstructured-client->unstructured) (2.22)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.2.2)
# Downloading unstructured-0.16.6-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 70.8 MB/s eta 0:00:00
# Downloading emoji-2.14.0-py3-none-any.whl (586 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.9/586.9 kB 44.7 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_iso639-2024.10.22-py3-none-any.whl (274 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.9/274.9 kB 27.7 MB/s eta 0:00:00
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_oxmsg-0.0.1-py3-none-any.whl (31 kB)
# Downloading rapidfuzz-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 84.4 MB/s eta 0:00:00
# Downloading unstructured_client-0.28.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 6.7 MB/s eta 0:00:00
# Downloading aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Downloading pypdf-5.1.0-py3-none-any.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 27.6 MB/s eta 0:00:00
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 12.5 MB/s eta 0:00:00
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=480a438b19fadeda9df52e4241ac910703d819071380d14cfa14c025b921267e
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: filetype, rapidfuzz, python-magic, python-iso639, pypdf, olefile, langdetect, jsonpath-python, emoji, aiofiles, python-oxmsg, unstructured-client, unstructured
# Successfully installed aiofiles-24.1.0 emoji-2.14.0 filetype-1.2.0 jsonpath-python-1.0.6 langdetect-1.0.9 olefile-0.47 pypdf-5.1.0 python-iso639-2024.10.22 python-magic-0.4.27 python-oxmsg-0.0.1 rapidfuzz-3.10.1 unstructured-0.16.6 unstructured-client-0.28.0
# Requirement already satisfied: PyMuPDF in /usr/local/lib/python3.10/dist-packages (1.24.14)
# Collecting pdfminer.six
#   Downloading pdfminer.six-20240706-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six) (3.4.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.22)
# Downloading pdfminer.six-20240706-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 53.0 MB/s eta 0:00:00
# Installing collected packages: pdfminer.six
# Successfully installed pdfminer.six-20240706
# Requirement already satisfied: qdrant-client in /usr/local/lib/python3.10/dist-packages (1.12.1)
# Requirement already satisfied: grpcio>=1.41.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (1.68.0)
# Requirement already satisfied: grpcio-tools>=1.41.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (1.68.0)
# Requirement already satisfied: httpx>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.20.0->qdrant-client) (0.27.2)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (1.26.4)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (2.10.1)
# Requirement already satisfied: pydantic>=1.10.8 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (2.9.2)
# Requirement already satisfied: urllib3<3,>=1.26.14 in /usr/local/lib/python3.10/dist-packages (from qdrant-client) (2.2.3)
# Requirement already satisfied: protobuf<6.0dev,>=5.26.1 in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.41.0->qdrant-client) (5.28.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from grpcio-tools>=1.41.0->qdrant-client) (75.1.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (0.14.0)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.10/dist-packages (from httpx[http2]>=0.20.0->qdrant-client) (4.1.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10.8->qdrant-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10.8->qdrant-client) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10.8->qdrant-client) (4.12.2)
# Requirement already satisfied: hyperframe<7,>=6.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /usr/local/lib/python3.10/dist-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client) (4.0.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.20.0->httpx[http2]>=0.20.0->qdrant-client) (1.2.2)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.47.0.dev0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.66.6)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.26.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (11.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.9.11)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.4.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence_transformers) (2024.8.30)
# Collecting pi_heif
#   Downloading pi_heif-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: pillow>=10.1.0 in /usr/local/lib/python3.10/dist-packages (from pi_heif) (11.0.0)
# Downloading pi_heif-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (989 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 989.0/989.0 kB 17.1 MB/s eta 0:00:00
# Installing collected packages: pi_heif
# Successfully installed pi_heif-0.20.0
# Collecting unstructured_inference
#   Downloading unstructured_inference-0.8.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting layoutparser (from unstructured_inference)
#   Downloading layoutparser-0.3.4-py3-none-any.whl.metadata (7.7 kB)
# Collecting python-multipart (from unstructured_inference)
#   Downloading python_multipart-0.0.17-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unstructured_inference) (0.26.2)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from unstructured_inference) (1.26.4)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /usr/local/lib/python3.10/dist-packages (from unstructured_inference) (4.10.0.84)
# Collecting onnx (from unstructured_inference)
#   Downloading onnx-1.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: onnxruntime>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from unstructured_inference) (1.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from unstructured_inference) (3.8.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from unstructured_inference) (2.5.1+cu121)
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (from unstructured_inference) (1.0.11)
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.10/dist-packages (from unstructured_inference) (4.47.0.dev0)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.10/dist-packages (from unstructured_inference) (3.10.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.17.0->unstructured_inference) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.17.0->unstructured_inference) (24.3.25)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.17.0->unstructured_inference) (24.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.17.0->unstructured_inference) (5.28.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.17.0->unstructured_inference) (1.13.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured_inference) (3.16.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured_inference) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured_inference) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured_inference) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured_inference) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured_inference) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured_inference) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unstructured_inference) (2024.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unstructured_inference) (4.12.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from layoutparser->unstructured_inference) (1.13.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from layoutparser->unstructured_inference) (2.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from layoutparser->unstructured_inference) (11.0.0)
# Collecting iopath (from layoutparser->unstructured_inference)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pdfplumber (from layoutparser->unstructured_inference)
#   Downloading pdfplumber-0.11.4-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 3.9 MB/s eta 0:00:00
# Collecting pdf2image (from layoutparser->unstructured_inference)
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured_inference) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured_inference) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured_inference) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured_inference) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured_inference) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured_inference) (2.8.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm->unstructured_inference) (0.20.1+cu121)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->unstructured_inference) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->unstructured_inference) (3.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.17.0->unstructured_inference) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->unstructured_inference) (1.16.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime>=1.17.0->unstructured_inference) (10.0)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath->layoutparser->unstructured_inference) (2.10.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->unstructured_inference) (3.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->layoutparser->unstructured_inference) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->layoutparser->unstructured_inference) (2024.2)
# Collecting pdfminer.six==20231228 (from pdfplumber->layoutparser->unstructured_inference)
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Collecting pypdfium2>=4.18.0 (from pdfplumber->layoutparser->unstructured_inference)
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber->layoutparser->unstructured_inference) (3.4.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber->layoutparser->unstructured_inference) (43.0.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.25.1->unstructured_inference) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.25.1->unstructured_inference) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.25.1->unstructured_inference) (2024.8.30)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber->layoutparser->unstructured_inference) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber->layoutparser->unstructured_inference) (2.22)
# Downloading unstructured_inference-0.8.1-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 4.0 MB/s eta 0:00:00
# Downloading layoutparser-0.3.4-py3-none-any.whl (19.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 90.0 MB/s eta 0:00:00
# Downloading onnx-1.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 102.2 MB/s eta 0:00:00
# Downloading python_multipart-0.0.17-py3-none-any.whl (24 kB)
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading pdfplumber-0.11.4-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 5.1 MB/s eta 0:00:00
# Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 108.2 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 98.2 MB/s eta 0:00:00
# Building wheels for collected packages: iopath
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31528 sha256=382db06a506d1a69b337ea386d87525e8a52f3d1b86530745c527b04e89cc7fc
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built iopath
# Installing collected packages: python-multipart, pypdfium2, pdf2image, onnx, iopath, pdfminer.six, pdfplumber, layoutparser, unstructured_inference
#   Attempting uninstall: pdfminer.six
#     Found existing installation: pdfminer.six 20240706
#     Uninstalling pdfminer.six-20240706:
#       Successfully uninstalled pdfminer.six-20240706
# Successfully installed iopath-0.1.10 layoutparser-0.3.4 onnx-1.17.0 pdf2image-1.17.0 pdfminer.six-20231228 pdfplumber-0.11.4 pypdfium2-4.30.0 python-multipart-0.0.17 unstructured_inference-0.8.1

# %% [markdown]
# Add your keys from the secret store (do **NOT** print them out or leave them exposed as plaintext in your notebook!):

# %% [markdown]
# ## 3. The RAG Model & Experimentation for fintech policies
#
# With this we can get started. First, we need to acquire the data, chunk it, vectorize it, and store the embeddings (and in this simple case also the docs) in our Qdrant vector db.
#
#
# ### 3.1 The Vector Database
#
# We will start by creating our datastore, Qdrant. Usually, you would deploy the vector db as a server, but in this case let's simply put everything in memory. Also, in this case we will store not only the embeddings but the whole document in the vector store.
#
# We will also create the retriever, which defines the way the documents are being retrieved. The retriever parameters define for example which method is used, how many docs are retrieved, etc. See [this LangChain link ](https://python.langchain.com/docs/modules/data_connection/retrievers/vectorstore)for more information.
#
# ## 1. Start by extracting the company name and relevant metadata from an uploaded PDF policy document.

# %% [markdown]
# ## 1. GDPR Documents Structure
#
# GDPR dcoument is split into two:
# 1. Recitals : Recitals are introductory statements found at the beginning of the document. They provide context, rationale, and intentions behind the law but do not contain binding rules. Recitals in the GDPR are numbered sequentially (1, 2, 3, etc.) and cover various topics, but they don’t establish rules by themselves.
#
# 2. Articles : Articles are the enforceable sections of the law. Each article contains specific provisions and requirements that must be followed. In the GDPR, articles outline the rights, obligations, and penalties related to personal data protection.
#
# In a RAG system, chunking recitals and articles separately helps because:
#
# Recitals: Recitals provide context and can help answer questions about why certain rules exist.
#
# Articles: Articles offer direct answers to compliance-related questions, as they contain enforceable requirements.

# %% [markdown]
# ## 1. Load privacy policy and GDPR documents and get Hugging Face Embeddings

# %%
import logging
import openai
import os
logging.basicConfig(level=logging.INFO)
from google.colab import userdata
import locale

import torch
import os
import bs4
import json
import numpy as np
import time
import pandas as pd
import openai
from openai import OpenAI

from pprint import pprint

import locale
import uuid


import fitz
import requests
from langchain.embeddings import HuggingFaceEmbeddings
from typing import Tuple, List, Optional
from pathlib import Path
import tempfile
from google.colab import files
import requests
from typing import Optional, Dict
from collections import defaultdict
from typing import List, Dict
import subprocess
import pkg_resources


from transformers import AutoTokenizer , AutoModelForCausalLM
from transformers import pipeline, BitsAndBytesConfig

from langchain.llms import HuggingFacePipeline
from langchain import PromptTemplate, LLMChain
from langchain_core.prompts import ChatPromptTemplate
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_text_splitters import CharacterTextSplitter
from langchain_core.output_parsers import StrOutputParser
from langchain import hub
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import FAISS
from langchain_community.vectorstores import Chroma
from langchain_community.vectorstores import Qdrant
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.utils.math import cosine_similarity
from langchain.schema import Document

from langchain_community.document_loaders import ArxivLoader
from langchain_community.document_loaders import TextLoader
from langchain_community.document_loaders import WikipediaLoader
from langchain_community.document_loaders import OnlinePDFLoader
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.document_loaders import PubMedLoader
from langchain.vectorstores import Qdrant
from qdrant_client import QdrantClient
from langchain.text_splitter import RecursiveCharacterTextSplitter

from langchain_community.chat_models import ChatCohere

from langchain.document_loaders import PyMuPDFLoader
from langchain.prompts import ChatPromptTemplate

from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, pipeline
import torch
from google.colab import userdata
from google.colab import drive
import re
drive.mount('/content/drive')
locale.getpreferredencoding = lambda: "UTF-8"


# Define paths dynamically based on the company name
# policy_paths = f"/content/drive/MyDrive/compliance/policies/{company_name}_eu.pdf"
# #gdpr_url = "https://eur-lex.europa.eu/legal-content/EN/TXT/PDF/?uri=CELEX:32016R0679"
# gdpr_drive_path = "/content/drive/MyDrive/compliance/GDPR_document.pdf"
base_embeddings = HuggingFaceEmbeddings(model_name="multi-qa-mpnet-base-dot-v1")

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

openai_api_key = userdata.get('OPENAI_API_KEY')
openai.api_key = openai_api_key
QDRANT_API_KEY = userdata.get('QDRANT_API_KEY')

def fn_local_with_paths(input_data: Dict) -> Tuple[Optional[str], Optional[str], str, str, str]:
    """
    Retrieve the uploaded policy file and GDPR document from Google Drive.

    Args:
        input_data (dict): Input JSON containing `file_name`, `company_name`, `uuid`, and `question_type`.

    Returns:
        tuple: Paths to policy document, GDPR document, company name, uuid, and document type.
    """
    print("Received input data: ", input_data)

    # Extract question_type and uuid
    question_type = input_data.get("question_type", "Policy")
    uuid = input_data.get("uuid")
    if not uuid:
        raise ValueError("Input JSON payload missing 'uuid' field")

    gdpr_drive_path = "/content/drive/MyDrive/compliance/policies/gdpr.pdf"

    if question_type == "Policy":
        company_name = input_data.get("company_name", "").strip()
        if not company_name:
            raise ValueError("Input JSON payload missing 'company_name' field for Policy questions.")
        policy_paths = f"/content/drive/MyDrive/compliance/policies/{company_name}.pdf"
        if not os.path.exists(policy_paths):
            raise FileNotFoundError(f"The policy file for {company_name} was not found at {policy_paths}")
        print(f"Policy file located at: {policy_paths}")
    else:
        company_name = None
        policy_paths = None

    if question_type == "GDPR" and not os.path.exists(gdpr_drive_path):
        raise FileNotFoundError(f"The GDPR document was not found at {gdpr_drive_path}")

    print(f"GDPR document located at: {gdpr_drive_path}")

    return policy_paths, gdpr_drive_path, company_name, uuid, question_type


# Define the function to load PDF content
def load_pdf_content_with_page_count(pdf_path: str) -> Tuple[List[str], int]:
    """
    Load the content of a PDF and return the text from each page along with the page count.

    Args:
        pdf_path: Path to the PDF file.

    Returns:
        tuple: (List of page contents as strings, Total number of pages)
    """
    try:
        document = fitz.open(pdf_path)
        #print(f"Document opened successfully. Page count: {len(document)}")
        contents = [page.get_text() for page in document]
        num_pages = len(contents)
        document.close()
        return contents, num_pages
    except Exception as e:
        logger.error(f"Failed to load PDF content from {pdf_path}: {e}")
        return [], 0


# Define the function to load policy and GDPR documents
def load_policy_document(policy_path: str, gdpr_path: str) -> Tuple[List[str], List[str]]:
    """
    Load a single policy document and the GDPR document with proper error handling.

    Parameters:
    - policy_path (str): Path to the company policy PDF.
    - gdpr_path (str): Path to the GDPR reference PDF.

    Returns:
    - tuple: (list of policy content as strings, gdpr contents)
    """
    base_embeddings = HuggingFaceEmbeddings(model_name="multi-qa-mpnet-base-dot-v1")
    if base_embeddings is None:
        logger.error("Failed to initialize embeddings")
        return [], []

    policy_contents, policy_pages = load_pdf_content_with_page_count(policy_path)
    logger.info(f"Loaded policy document ({Path(policy_path).name}): {policy_pages} pages")

    # Load GDPR document
    gdpr_contents, gdpr_pages = load_pdf_content_with_page_count(gdpr_path)
    logger.info(f"Loaded GDPR document ({Path(gdpr_path).name}): {gdpr_pages} pages")

    return policy_contents, gdpr_contents

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

def extract_formatted_text(pdf_path: str) -> List[Dict]:
    """
    Extract text with its formatting information from PDF.
    Returns list of dictionaries containing text and its formatting properties.
    """
    formatted_blocks = []
    try:
        doc = fitz.open(pdf_path)
        position = 0

        for page_num, page in enumerate(doc):
            blocks = page.get_text("dict")["blocks"]
            prev_y1 = None

            for block in blocks:
                if "lines" in block:
                    for line in block["lines"]:
                        y0 = line["bbox"][1]
                        line_spacing = y0 - prev_y1 if prev_y1 is not None else 0
                        prev_y1 = line["bbox"][3]

                        for span in line["spans"]:
                            text = span["text"].strip()
                            if text:
                                formatted_blocks.append({
                                    "text": text,
                                    "font_name": span["font"],
                                    "font_size": span["size"],
                                    "is_bold": "bold" in span["font"].lower() or span["flags"] & 2**4 != 0,
                                    "line_spacing": line_spacing,
                                    "position": position,
                                    "page_num": page_num + 1
                                })
                            position += len(text) + 1

        return formatted_blocks
    except Exception as e:
        print(f"Error extracting formatted text: {e}")
        return []

def analyze_document_formatting(blocks: List[Dict]) -> Dict:
    """
    Analyze document formatting to establish baseline metrics.
    """
    stats = defaultdict(list)

    for block in blocks:
        stats["font_sizes"].append(block["font_size"])
        stats["line_spacings"].append(block["line_spacing"])

    return {
        "avg_font_size": sum(stats["font_sizes"]) / len(stats["font_sizes"]),
        "max_font_size": max(stats["font_sizes"]),
        "avg_line_spacing": sum(stats["line_spacings"]) / len(stats["line_spacings"]) if stats["line_spacings"] else 0
    }

def identify_potential_headers(blocks: List[Dict], format_stats: Dict) -> List[Dict]:
    """
    Identify potential headers based on formatting characteristics.
    """
    potential_headers = []

    for block in blocks:
        formatting_score = 0
        characteristics = []

        # Check font size
        if block["font_size"] > format_stats["avg_font_size"]:
            formatting_score += 2
            characteristics.append("larger_font")

        # Check if bold
        if block["is_bold"]:
            formatting_score += 2
            characteristics.append("bold")

        # Check line spacing
        if block["line_spacing"] > format_stats["avg_line_spacing"] * 1.5:
            formatting_score += 1
            characteristics.append("increased_spacing")

        # Check text length
        word_count = len(block["text"].split())
        if word_count <= 10:
            formatting_score += 1
            characteristics.append("short_text")

        # Check for title case or all caps
        if block["text"].istitle() or block["text"].isupper():
            formatting_score += 1
            characteristics.append("title_case_or_caps")

        if formatting_score >= 3:
            potential_headers.append({
                "text": block["text"],
                "position": block["position"],
                "characteristics": characteristics,
                "formatting_score": formatting_score
            })

    return potential_headers

def confirm_headers_with_gpt(potential_headers: List[Dict], api_key: str) -> List[Dict]:
    """
    Use GPT to confirm which potential headers are actual privacy policy section headers.

    Args:
        potential_headers (List[Dict]): List of dictionaries containing potential headers
        api_key (str): Your OpenAI API key

    Returns:
        List[Dict]: Confirmed headers with their text and positions
    """
    # Initialize the OpenAI client with the API key
    client = OpenAI(api_key=api_key)
    confirmed_headers = []

    for header in potential_headers:
        prompt = f"""Analyze if this text represents a privacy policy section header.
Text: "{header['text']}"
Formatting characteristics detected:
{', '.join(header['characteristics'])}
Consider:
1. Is this a typical privacy policy topic? (e.g., data collection, processing, sharing, security, rights)
2. Does it look like a header based on its formatting? (detected: {header['formatting_score']}/7 header characteristics)
3. Is it concise and descriptive?
4. Does it introduce a new section rather than being part of content?
Is this a main section header? Answer only 'yes' or 'no'."""

        try:
            response = client.chat.completions.create(
                model="gpt-4",
                messages=[
                    {"role": "system", "content": "You are an expert at identifying section headers in privacy policies."},
                    {"role": "user", "content": prompt}
                ],
                max_tokens=10,
                temperature=0.0
            )

            answer = response.choices[0].message.content.strip().lower()

            if answer == 'yes':
                confirmed_headers.append({
                    "header": header["text"],
                    "position": header["position"]
                })

        except Exception as e:
            print(f"Error in GPT confirmation: {e}")
            continue

    return confirmed_headers

def chunk_policy_by_headers(headers: List[Dict], blocks: List[Dict]) -> List[Dict]:
    """
    Chunk the policy text based on section headers using the original formatted blocks.
    """
    chunks = []
    full_text = ""
    current_position = 0

    for block in blocks:
        full_text += block["text"] + "\n"

    for i, header_data in enumerate(headers):
        start_pos = header_data["position"]
        end_pos = headers[i + 1]["position"] if i + 1 < len(headers) else len(full_text)
        chunk_text = full_text[start_pos:end_pos].strip()

        chunks.append({
            "header": header_data["header"],
            "content": chunk_text
        })

    return chunks

def process_policy(pdf_path: str) -> Dict:
    """
    Process a single PDF policy document and extract sections.
    """
    try:
        formatted_blocks = extract_formatted_text(pdf_path)
        if not formatted_blocks:
            return {"status": "error", "pdf_path": pdf_path, "message": "Failed to extract formatted text"}

        format_stats = analyze_document_formatting(formatted_blocks)
        potential_headers = identify_potential_headers(formatted_blocks, format_stats)
        confirmed_headers = confirm_headers_with_gpt(potential_headers, openai.api_key)

        if not confirmed_headers:
            return {"status": "error", "pdf_path": pdf_path, "message": "No headers found in the document"}

        chunks = chunk_policy_by_headers(confirmed_headers, formatted_blocks)

        return {
            "status": "success",
            "pdf_path": pdf_path,
            "total_chunks": len(chunks),
            "chunks": chunks
        }

    except Exception as e:
        return {"status": "error", "pdf_path": pdf_path, "message": str(e)}


def further_chunk_policy(company_name: str, uuid: str, policy: Dict, chunk_size: int = 1000, chunk_overlap: int = 50) -> List[Dict]:
    """
    Further split each chunk's content for a single company policy using a Recursive Text Splitter.

    Args:
        policy (Dict): A dictionary representing the policy document with its chunks.
        chunk_size (int): The maximum size of each sub-chunk.
        chunk_overlap (int): The overlap between consecutive sub-chunks.

    Returns:
        List[Dict]: A list of refined sub-chunks with metadata.
    """
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,
        length_function=len,
        is_separator_regex=False
    )
    refined_chunks = []

    #pdf_path = policy["pdf_path"]
    #company_name = policy_paths.split('/')[-1].replace('.pdf', '').capitalize()

    for chunk in policy["chunks"]:
        try:
            sub_chunks = text_splitter.split_text(chunk["content"])

            for i, sub_chunk in enumerate(sub_chunks, 1):
                refined_chunks.append({
                    "page_content": sub_chunk,
                    "metadata": {
                        "company_name": company_name,
                        "uuid": uuid,
                        "pdf_path": policy["pdf_path"],
                        "header": chunk["header"],
                        "chunk_index": i,
                        "total_sub_chunks": len(sub_chunks),
                        "document_type": "Policy"
                    }
                })
        except Exception as e:
            print(f"Error processing chunk for company {company_name} with header '{chunk['header']}': {str(e)}")
            continue

    return refined_chunks


def chunk_gdpr_by_section(gdpr_contents: List[str]) -> List[Document]:
    """
    Chunk GDPR text into sections based on articles and recitals, without mapping to policy categories.

    Parameters:
    - gdpr_contents (List[str]): List containing GDPR text.

    Returns:
    - List[Document]: List of Document objects, each representing a chunk of a GDPR section.
    """
    try:
        text_splitter = RecursiveCharacterTextSplitter(chunk_size=1500, chunk_overlap=50)
        documents = []
        full_text = "\n".join(gdpr_contents)

        recital_pattern = re.compile(r"\((\d+)\)\s", re.MULTILINE)
        article_pattern = re.compile(r"(Article\s(\d+))\b", re.IGNORECASE)

        all_matches = [(match.start(), match.group(1), 'recital') for match in re.finditer(recital_pattern, full_text)]
        all_matches += [(match.start(), match.group(1), 'article', match.group(2)) for match in re.finditer(article_pattern, full_text)]
        all_matches.sort()

        for i, (start, header, section_type, *article_number) in enumerate(all_matches):
            end = all_matches[i + 1][0] if i + 1 < len(all_matches) else len(full_text)
            section_text = full_text[start:end].strip()

            section_header = None

            if section_type == 'article' and article_number:
                article_number = article_number[0].strip()
                section_header = f"Article {article_number}"

            elif section_type == 'recital':
                section_header = f"Recital {header}"

            chunks = text_splitter.split_text(section_text)

            for chunk in chunks:
                documents.append(Document(
                    page_content=chunk,
                    metadata={
                        "header": section_header
                    }
                ))

        print(f"\nTotal documents created: {len(documents)}")
        return documents

    except Exception as e:
        print(f"Error processing GDPR contents: {e}")
        return []

def initialize_mistral_pipeline(
    model_name: str = "mistralai/Mistral-7B-Instruct-v0.2",
    max_new_tokens: int = 1000,
    temperature: float = 0.55,
    top_p: float = 0.9,
    repetition_penalty: float = 1.3,
    offload_folder: str = "offload_folder",
    huggingface_token: Optional[str] = None
) -> pipeline:
    """
    Initialize the Mistral text-generation pipeline with quantization.

    Args:
        model_name (str): Name of the pre-trained model to load.
        max_new_tokens (int): Maximum number of tokens to generate.
        temperature (float): Sampling temperature for text generation.
        top_p (float): Top-p sampling for nucleus sampling.
        repetition_penalty (float): Repetition penalty for text generation.
        offload_folder (str): Directory for offloading large model files.

    Returns:
        pipeline: Configured HuggingFace pipeline for text generation.
    """
    quantization_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_use_double_quant=True,
        llm_int8_enable_fp32_cpu_offload=True
    )

    llm_mistral_model = AutoModelForCausalLM.from_pretrained(
        model_name,
        device_map="auto",
        torch_dtype=torch.float16,
        quantization_config=quantization_config,
        offload_folder=offload_folder,
        use_auth_token=huggingface_token
    )

    llm_mistral_tokenizer = AutoTokenizer.from_pretrained(
        model_name,
        padding_side="right",
        truncation=True,
        use_auth_token=huggingface_token
    )

    mistral_pipe = pipeline(
        "text-generation",
        model=llm_mistral_model,
        tokenizer=llm_mistral_tokenizer,
        max_new_tokens=max_new_tokens,
        temperature=temperature,
        top_p=top_p,
        do_sample=True,
        repetition_penalty=repetition_penalty,
        torch_dtype=torch.float16
    )

    mistral_pipe.model.config.pad_token_id = mistral_pipe.model.config.eos_token_id

    return mistral_pipe

def further_chunk_gdpr_content(company_name: str, initial_documents: List[Document]) -> List[Document]:
    """Further split GDPR content into smaller chunks while preserving metadata."""
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1200, chunk_overlap=50)
    gdpr_chunks = []

    for document in initial_documents:
        sub_chunks = text_splitter.split_text(document.page_content)
        for sub_chunk in sub_chunks:
            gdpr_chunks.append(Document(
                page_content=sub_chunk,
                metadata={
                    "header": document.metadata.get("header"),
                    "document_type": "GDPR"
                }
            ))
    print(f"[DEBUG] Further chunked GDPR content for company {company_name}")
    return gdpr_chunks

def prepare_documents_for_vectorstore(chunks: List[Document]) -> List[Document]:
    """Prepare documents for vector store with consistent metadata handling."""
    documents = []

    for idx, chunk in enumerate(chunks):
        if isinstance(chunk, dict):
            chunk = Document(page_content=chunk['page_content'], metadata=chunk['metadata'])

        doc_type = chunk.metadata.get("document_type", "Unknown")

        metadata_company_name = chunk.metadata.get("company_name", "").lower()
        uuid = chunk.metadata.get("uuid", "")

        metadata = {
            "chunk_number": idx + 1,
            "document_type": doc_type,
            "company_name": metadata_company_name,
            "header": chunk.metadata.get("header", ""),
            "doc_link": (
                "https://eur-lex.europa.eu/legal-content/EN/TXT/PDF/?uri=CELEX:32016R0679"
                if doc_type == "GDPR"
                else f"/content/drive/MyDrive/compliance/policies/{metadata_company_name}.pdf"
            )
        }

        documents.append(Document(
            page_content=chunk.page_content,
            metadata=metadata
        ))
        print(f"[DEBUG] Prepared document {idx + 1} with metadata: {metadata}")

    return documents

def setup_vectorstore(documents: List[Document], embeddings, qdrant_url: str, qdrant_api_key: str) -> Optional[Qdrant]:
    """Initialize and populate the vector store using a Qdrant cloud instance."""
    try:
        # Connect to the Qdrant client
        qdrant_client = QdrantClient(url=qdrant_url, api_key=qdrant_api_key)
        print("[DEBUG] Connected to Qdrant cloud instance")

        collection_name = "policy_pulse_db"

        test_embedding = embeddings.embed_query("")
        #print(f"[DEBUG] Embedding output type: {type(test_embedding)}")
        #print(f"[DEBUG] Embedding output sample: {test_embedding}")

        test_embedding = embeddings.embed_query("")
        if isinstance(test_embedding, list):
          test_embedding = np.array(test_embedding)
        embedding_size = test_embedding.shape[0]
        print(f"[DEBUG] Detected embedding size: {embedding_size}")

        # Recreate the collection
        try:
            qdrant_client.recreate_collection(
                collection_name=collection_name,
                vectors_config={
                    "size": embedding_size,
                    "distance": "Cosine"
                }
            )
            print(f"[DEBUG] Collection '{collection_name}' recreated successfully")
        except Exception as e:
            print(f"[ERROR] Failed to recreate collection: {e}")
            return None

        # Add documents to the vectorstore
        try:
            vectorstore = Qdrant(
                client=qdrant_client,
                collection_name=collection_name,
                embeddings=embeddings
            )
            vectorstore.add_documents(documents)
            print("[DEBUG] Documents added to Qdrant collection")
            return vectorstore
        except Exception as e:
            print(f"[ERROR] Failed to add documents to vectorstore: {e}")
            return None

    except Exception as e:
        print(f"[ERROR] Error setting up vector store: {e}")
        return None


def create_policy_prompt_template() -> ChatPromptTemplate:
    """
    Creates a ChatPromptTemplate for the GDPR compliance expert.

    Returns:
        ChatPromptTemplate: Configured template for generating structured answers.
    """
    prompt_role = "You are a GDPR compliance expert tasked with providing accurate, structured answers."
    prompt_task = "Using only the provided context, generate a comprehensive response that includes all required sections."
    prompt_context = "Context:\n{context}"
    prompt_question = "Question:\n{question}"
    prompt_instruction = """Answer the question by referring specifically to the context.
    Structure your response exactly as follows:

    Main Answer:
    [Provide a concise answer using the context information]

    Key Points:
    • [List key points as bullet points]
    • [Each point should start with a bullet point]
    • [Extract at least 3-4 key points]

    GDPR References:
    [Must include specific GDPR articles mentioned or most relevant to the context. Use format: 'Article X - Title']"""

    # Combine all parts into the template
    policy_pulse_template = f"""<s>[INST] {prompt_role}
    {prompt_task}

    {prompt_context}

    {prompt_question}

    {prompt_instruction} [/INST]"""

    # Return the ChatPromptTemplate object
    return ChatPromptTemplate.from_template(policy_pulse_template)

def classify_question_type(company_name, question: str) -> tuple:
    """
    Classify if a question is about a specific company policy or general GDPR.
    Returns "Policy" if a company name is identified in the question,
    otherwise returns "GDPR".

    Args:
        question: The question text

    Returns:
        Tuple: ("Policy" or "GDPR", matched company name or None)
    """
   #company_name = "bitpay"
    if company_name in question:
      company_name = company_name.lower()
    return "Policy" if company_name else ("GDPR", None)

def clean_generated_response(response: str) -> str:
    """
    This function cleans the generated response to remove any unwanted content
    such as initial instructions or repeated context.
    """
    cleaned_response = re.sub(r'Human: <s>\[INST\].*?\[/INST\]', '', response, flags=re.DOTALL)

    cleaned_response = re.sub(r'Context:\s*{.*?}\n', '', cleaned_response, flags=re.DOTALL)

    cleaned_response = re.sub(r'Question:\s*{.*?}\n', '', cleaned_response, flags=re.DOTALL)

    cleaned_response = cleaned_response.strip()

    return cleaned_response


def process_single_question(company, question_type,  question, qdrant_vectorstore, gdpr_retriever, rag_chain_mistral):
    """
    Process a single question using the RAG system and return the generated answer.

    Args:
        question (str): The question to process.
        qdrant_vectorstore: Qdrant vector store for policy documents.
        gdpr_retriever: Retriever for GDPR-related documents.
        rag_chain_mistral: RAG chain pipeline for generating answers.

    Returns:
        dict: A result including the question, context, generated answer, and document sources.
    """
    print(f"[PROCESSING] Question: {question}")

    dynamic_company_name = company
    #question_type = classify_question_type(dynamic_company_name, question)
    print(f"extracted company name: {dynamic_company_name}")
    print(f"extracted question_type: {question_type}")

    gdpr_results = []
    policy_results = []

    if question_type == 'GDPR':
        print(f"[PROCESSING] Retrieving GDPR content for question: {question}")
        gdpr_results = gdpr_retriever.get_relevant_documents(
            question, metadata_filters={"document_type": question_type}
        )

    elif question_type == 'Policy':
        print(f"[PROCESSING] Retrieving Policy content for question: {question} ({dynamic_company_name})")
        combined_filter = {"company_name": dynamic_company_name}
        policy_retriever = qdrant_vectorstore.as_retriever(search_kwargs={'filter': combined_filter})
        policy_results = policy_retriever.get_relevant_documents(question)

        if not policy_results:
            print(f"[WARNING] No policy documents found for '{dynamic_company_name}'. Using broader retrieval.")
            policy_results = qdrant_vectorstore.as_retriever().get_relevant_documents(question)

        print(f"[INFO] Retrieving GDPR articles for the question using semantic similarity")
        gdpr_results = gdpr_retriever.get_relevant_documents(question)

    else:
        print(f"[ERROR] Unable to classify question type.")
        return {
            "question": question,
            "contexts": "No relevant context found.",
            "answer": "Unable to classify question type.",
            "doc_source": "N/A"
        }

    context_snippets = [doc.page_content[:500] for doc in policy_results + gdpr_results if doc.page_content]
    context_snippets_str = " ".join(context_snippets)

    document_sources = [doc.metadata.get('doc_link', 'N/A') for doc in policy_results + gdpr_results]
    document_sources_str = ", ".join(document_sources)

    if not context_snippets_str:
        print(f"[ERROR] No context retrieved for question: {question}.")
        return {
            "question": question,
            "contexts": "No relevant context found for answering the question.",
            "answer": "No answer generated.",
            "doc_source": "N/A"
        }

    rag_input = {"context": context_snippets_str, "question": question}
    response = rag_chain_mistral.invoke(rag_input)
    generated_answer = clean_generated_response(response)

    return {
        "question": question,
        "contexts": context_snippets_str,
        "answer": generated_answer,
        "doc_source": document_sources_str
    }


def main():
    """
    Main function to process a policy document, refine chunks, interact with vector store,
    and generate responses using the RAG pipeline.
    """


    input_data = {
        "company_name": "stripe",
        "uuid": "123e4567-e89b-12d3-a456-426614174000",
        "question_type": "Policy",
        #"question": "What safeguards does Stripe implement for international data transfers?"
    }

    policy_paths, gdpr_path, company_name, uuid, document_type = fn_local_with_paths(input_data)

    policy_contents, gdpr_contents = [], []

    if document_type == "Policy":
        policy_contents, _ = load_pdf_content_with_page_count(policy_paths)
        print(f"Total pages in Policy Document ({Path(policy_paths).name}): {len(policy_contents)}")
    elif document_type == "GDPR":
        gdpr_contents, _ = load_pdf_content_with_page_count(gdpr_path)
        print(f"Total pages in GDPR PDF: {len(gdpr_contents)}")
    else:
        raise ValueError(f"Unsupported document type: {document_type}")

    print(f"Policy Path: {policy_paths if document_type == 'Policy' else 'N/A'}")
    print(f"GDPR Path: {gdpr_path if document_type == 'GDPR' else 'N/A'}")
    print(f"Company Name: {company_name}")
    print(f"UUID: {uuid}")

    # Process the uploaded policy
    if document_type == "Policy":
      result = process_policy(policy_paths)
      if result["status"] == "success":
          print(f"\nProcessed Result for {result['pdf_path']}:")
          print(f"Total number of chunks created: {result['total_chunks']}\n")
          for chunk in result["chunks"]:
              print(f"Header: {chunk['header']}")
              print(f"Content Snippet: {chunk['content'][:150]}...\n")
      else:
          print(f"Error processing {result['pdf_path']}: {result['message']}")
          return
    else:
        print("[INFO] Document type is not 'Policy'; skipping policy processing.")

    refined_chunks = []
    if document_type == "Policy":
        result = process_policy(policy_paths)
        if result["status"] == "success":
            print(f"\nProcessed Result for {result['pdf_path']}:")
            print(f"Total number of chunks created: {result['total_chunks']}\n")
            for chunk in result["chunks"]:
                print(f"Header: {chunk['header']}")
                print(f"Content Snippet: {chunk['content'][:150]}...\n")
        else:
            print(f"Error processing {result['pdf_path']}: {result['message']}")
            return

        refined_chunks = further_chunk_policy(company_name, uuid, result)
        print(f"Total number of sub-chunks created: {len(refined_chunks)}\n")
        for i, final_chunk in enumerate(refined_chunks, 1):
            print(f"Chunk {i}/{len(refined_chunks)}")
            print(f"PDF Path: {final_chunk['metadata']['pdf_path']}")
            print(f"Header: {final_chunk['metadata']['header']}")
            print(f"Sub-chunk {final_chunk['metadata']['chunk_index']}/{final_chunk['metadata']['total_sub_chunks']}")
            print(f"Content Snippet: {final_chunk['page_content'][:150]}...\n")
    elif document_type == "GDPR":
        gdpr_sentence_chunks = chunk_gdpr_by_section(gdpr_contents)
        #print("\nSample chunks:")
        for doc in gdpr_sentence_chunks[:5]:
            print(f"\nHeader: {doc.metadata['header']}")
            print(f"Content Snippet: {doc.page_content[:150]}...")

    else:
        print("[ERROR] Invalid document type provided.")


    huggingface_token = userdata.get('HUGGINGFACE_TOKEN')
    mistral_pipe = initialize_mistral_pipeline(
        model_name="mistralai/Mistral-7B-Instruct-v0.2",
        max_new_tokens=1000,
        temperature=0.55,
        top_p=0.9,
        repetition_penalty=1.3,
        offload_folder="offload_folder",
        huggingface_token=huggingface_token
    )
    mistral_llm_lc = HuggingFacePipeline(pipeline=mistral_pipe)

    #gdpr_final_chunks = further_chunk_gdpr_content(company_name, gdpr_sentence_chunks)
    if document_type == "GDPR":
        gdpr_final_chunks = further_chunk_gdpr_content(company_name, gdpr_sentence_chunks)
    else:
        gdpr_final_chunks = []

    all_chunks = gdpr_final_chunks + refined_chunks
    all_documents = prepare_documents_for_vectorstore(all_chunks)
    print("[DEBUG] Prepared Documents for Vector Store:")
    for idx, document in enumerate(all_documents):
        print(f"Document {idx + 1}:")
        print(f"Page Content: {document.page_content[:100]}...")
        print(f"Metadata: {document.metadata}")
        print("-" * 50)

    QDRANT_URL = "https://5ccc316a-ba45-4910-b5f9-15eb181ae895.us-east4-0.gcp.cloud.qdrant.io:6333"

    qdrant_vectorstore = setup_vectorstore(
        documents=all_documents,
        embeddings=base_embeddings,
        qdrant_url=QDRANT_URL,
        qdrant_api_key=QDRANT_API_KEY
    )

    combined_filter = {"document_type": "GDPR"}
    gdpr_retriever = qdrant_vectorstore.as_retriever(search_kwargs={'filter': combined_filter})
    print(f"[TEST] Applying retrieval filter with company_name: '{company_name}'")

    policy_prompt = create_policy_prompt_template()

    rag_chain_mistral = (
        {
            "context": RunnablePassthrough(),
            "question": RunnablePassthrough()
        }
        | policy_prompt
        | mistral_llm_lc
        | RunnablePassthrough()
    )


    user_question = input("Ask your question: ")
    result = process_single_question(
        company_name,
        document_type,
        question=user_question,
        qdrant_vectorstore=qdrant_vectorstore,
        gdpr_retriever=gdpr_retriever,
        rag_chain_mistral=rag_chain_mistral
    )

    print("\nReturning the following to the UI:")
    print()
    print(result['answer'])
    print()
    print(result['doc_source'])

    return {
        "answer": result["answer"],
        "doc_source": result["doc_source"]
    }



if __name__ == "__main__":
    response = main()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Received input data:  {'company_name': 'stripe', 'uuid': '123e4567-e89b-12d3-a456-426614174000', 'question_type': 'Policy'}
# Policy file located at: /content/drive/MyDrive/compliance/policies/stripe.pdf
# GDPR document located at: /content/drive/MyDrive/compliance/policies/gdpr.pdf
# Total pages in Policy Document (stripe.pdf): 33
# Policy Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# GDPR Path: N/A
# Company Name: stripe
# UUID: 123e4567-e89b-12d3-a456-426614174000
#
# Processed Result for /content/drive/MyDrive/compliance/policies/stripe.pdf:
# Total number of chunks created: 60
#
# Header: Privacy Policy
# Content Snippet: Privacy Policy
# Privacy Policy
# https://stripe.com/privacy
# 2 of 33
# 10/27/24, 1:41 PM
# entities (“Business Users”) that directly and indirectly provide us...
#
# Header: 1. Personal Data we collect and how we
# Content Snippet: 1. Personal Data we collect and how we...
#
# Header: use and share it
# Content Snippet: use and share it
# Our collection and use of Personal Data differs based on whether you are an End User, End
# Customer, Representative, or Visitor, and t...
#
# Header: 1.1 End Users
# Content Snippet: 1.1 End Users
# We provide End User Services when we provide the Services directly to you for your personal
# use (e.g., Link). Additional details regardi...
#
# Header: a. Personal Data we collect about End Users
# Content Snippet: a. Personal Data we collect about End Users
# Using Link or Connecting your bank account.
# Stripe offers a service called "Link," which
# allows you to sto...
#
# Header: Identity/Verification Services
# Content Snippet: Identity/Verification Services
# . We offer an identity verification service that automates the
# comparison of your identity document (such as a driver’s...
#
# Header: b. How we use and share Personal Data of End Users
# Content Snippet: b. How we use and share Personal Data of End Users...
#
# Header: Services
# Content Snippet: Services
# . We use and share your Personal Data to provide the End User Services to you, which
# includes support, personalization (such as language pref...
#
# Header: Our Business Users.
# Content Snippet: Our Business Users.
# When you use Link to make payments, we share your Transaction Data
# with the Business Users you choose to do business with.
# Learn M...
#
# Header: Transactions
# Content Snippet: Transactions
# . When you use Link to make payments, we use your Personal Data (such as
# name, contact information, payment method details) saved with us...
#
# Header: Advertising
# Content Snippet: Advertising
# . We may use your Personal Data to assess your eligibility for, and offer you, other
# End User Services or promote existing End User Servic...
#
# Header: 1.2 End Customers
# Content Snippet: 1.2 End Customers
# Stripe provides various Business Services to our Business Users, which include in-person or
# online checkout payment processing or pr...
#
# Header: a. Personal Data we collect about End Customers
# Content Snippet: a. Personal Data we collect about End Customers...
#
# Header: Transaction Data.
# Content Snippet: Transaction Data.
# If you're an End Customer making payments to, receiving refunds from,
# initiating a purchase or donation, or otherwise transacting wi...
#
# Header: Identity/Verification Information
# Content Snippet: Identity/Verification Information
# . Stripe provides a verification and fraud prevention Service
# that our Business Users can use to verify Personal Dat...
#
# Header: b. How we use and share Personal Data of End Customers
# Content Snippet: b. How we use and share Personal Data of End Customers
# To provide our Business Services to our Business Users, we use and share End Customers'
# Persona...
#
# Header: 1.3 Representatives
# Content Snippet: 1.3 Representatives
# We collect, use, and share Personal Data from Representatives of Business Users (for
# example, business owners) to provide our Busi...
#
# Header: a. Personal Data we collect about Representatives
# Content Snippet: a. Personal Data we collect about Representatives
# Registration and contact information.
# When you register for a Stripe account for a Business
# User (in...
#
# Header: Identification Information
# Content Snippet: Identification Information
# . As a current or potential Business User, an owner of a Business
# User, or a shareholder, officer, or director of a Busines...
#
# Header: b. How we use and share Personal Data of Representatives
# Content Snippet: b. How we use and share Personal Data of Representatives
# We typically use the Personal Data of Representatives to provide the Business Services to the...
#
# Header: Business Services.
# Content Snippet: Business Services.
# We use and share Representatives’ Personal Data with Business Users to
# provide the Services requested by you or the Business User y...
#
# Header: Advertising
# Content Snippet: Advertising
# . Where allowed by applicable law, we use and share Representatives’ Personal
# Data with third parties so we can advertise and market our S...
#
# Header: 1.4 Visitors
# Content Snippet: 1.4 Visitors
# We collect, use, and share the Personal Data of Visitors. More details about how we collect,
# use, and share Visitors’ Personal Data, alon...
#
# Header: a. Personal Data we collect about Visitors
# Content Snippet: a. Personal Data we collect about Visitors
# When you browse our Sites, we receive your Personal Data, either provided directly by you or
# collected thro...
#
# Header: b. How we use and share Personal Data of Visitors
# Content Snippet: b. How we use and share Personal Data of Visitors...
#
# Header: Personalization
# Content Snippet: Personalization
# . We use the data we collect from cookies and similar technologies about you
# to measure user engagement with the content on the Sites,...
#
# Header: Advertising
# Content Snippet: Advertising
# . Where allowed by applicable law, we use and share Visitors’ Personal Data with
# third parties so we can advertise and market our Services...
#
# Header: 2. More ways we collect, use, and share
# Content Snippet: 2. More ways we collect, use, and share...
#
# Header: Personal Data
# Content Snippet: Personal Data
# In addition to the ways described above, we also process your Personal Data as follows:...
#
# Header: a. Collection of Personal Data
# Content Snippet: a. Collection of Personal Data...
#
# Header: Online Activity
# Content Snippet: Online Activity
# . Depending on the Service used and how our Business Services are
# Privacy Policy
# https://stripe.com/privacy
# 13 of 33
# 10/27/24, 1:41 PM...
#
# Header: b. Use of Personal Data.
# Content Snippet: b. Use of Personal Data.
# Besides the use of Personal Data described above, we use Personal Data in the ways listed
# below:
# Improving and Developing our...
#
# Header: Communications
# Content Snippet: Communications
# . We use the contact information we have about you to deliver our Services,
# which may involve sending codes via SMS for your authentica...
#
# Header: Minors
# Content Snippet: Minors
# . Our Services are not directed to children under the age of 13, and we request that they
# do not provide Personal Data to seek Services directl...
#
# Header: c. Sharing of Personal Data.
# Content Snippet: c. Sharing of Personal Data.
# Besides the sharing of Personal Data described above, we share Personal Data in the ways
# listed below:...
#
# Header: Stripe Affiliates
# Content Snippet: Stripe Affiliates
# . We share Personal Data with other Stripe-affiliated entities for purposes
# identified in this Policy.
# Service Providers or Processo...
#
# Header: Financial Partners
# Content Snippet: Financial Partners
# . We share Personal Data with certain Financial Partners to provide Services
# to Business Users seeking such Services as well as off...
#
# Header: Corporate Transactions
# Content Snippet: Corporate Transactions
# . If we enter or intend to enter a transaction that modifies the
# Privacy Policy
# https://stripe.com/privacy
# 16 of 33
# 10/27/24, 1...
#
# Header: 3. Legal bases for processing Personal
# Content Snippet: 3. Legal bases for processing Personal...
#
# Header: Data
# Content Snippet: Data
# For purposes of the General Data Protection Regulation and other applicable data protection
# laws, we rely on a number of legal bases to process y...
#
# Header: 4. Your rights and choices
# Content Snippet: 4. Your rights and choices
# Depending on your location and subject to applicable law, you may have choices regarding
# our collection, use, and disclosur...
#
# Header: a. Opting out of receiving electronic communications from
# Content Snippet: a. Opting out of receiving electronic communications from
# us
# If you wish to stop receiving marketing-related emails from us, you can opt-out by clicki...
#
# Header: b. Your data protection rights
# Content Snippet: b. Your data protection rights
# Depending on your location and subject to applicable law, you may have the following rights
# regarding the Personal Data...
#
# Header: c. Process for exercising your data protection rights
# Content Snippet: c. Process for exercising your data protection rights
# To exercise your data protection rights, visit our...
#
# Header: Privacy Center
# Content Snippet: Privacy Center
# or contact us as outlined
# below.
# The right to request confirmation of whether Stripe is processing Personal Data associated
# with you, a...
#
# Header: 5. Security and Retention
# Content Snippet: 5. Security and Retention
# We make reasonable efforts to provide a level of security appropriate to the risk associated
# with the processing of your Per...
#
# Header: 6. International Data Transfers
# Content Snippet: 6. International Data Transfers
# As a global business, it's sometimes necessary for us to transfer your Personal Data to
# countries other than your own,...
#
# Header: 7. Updates and notifications
# Content Snippet: 7. Updates and notifications
# We may change this Policy from time to time to reflect new services, changes in our privacy
# practices or relevant laws. T...
#
# Header: 8. Jurisdiction-specific provisions
# Content Snippet: 8. Jurisdiction-specific provisions
# Australia
# . If you are an Australian resident and dissatisfied with our handling of any complaint
# you raise under ...
#
# Header: Brazil
# Content Snippet: Brazil
# . You may exercise your rights by contacting our DPO at
# dpo@stripe.com
# . Brazilian
# residents, for whom the Lei Geral de Proteção de Dados Pesso...
#
# Header: 9. Contact us
# Content Snippet: 9. Contact us
# If you have any questions or complaints about this Policy, please
# contact us
# . If you are an End
# Customer (i.e., an individual doing bus...
#
# Header: 10. US Consumer Privacy Notice
# Content Snippet: 10. US Consumer Privacy Notice
# The following Consumer Privacy Notice applies to you if you are an individual who resides in
# the United States and obta...
#
# Header: FACTS
# Content Snippet: FACTS
# WHAT DOES STRIPE DO WITH YOUR PERSONAL INFORMATION?
# Why?
# Financial companies choose how they share your personal information.  Federal
# law gives...
#
# Header: • Social Security Number
# Content Snippet: • Social Security Number
# • Contact details
# • Account balances and transaction history
# Privacy Policy
# https://stripe.com/privacy
# 27 of 33
# 10/27/24, 1:4...
#
# Header: Questions?
# Content Snippet: Questions?
# Contact us at privacy@stripe.com or visit us at https://support.link.com
# Who we are
# Who is providing this
# notice?
# Stripe, Inc., Stripe Paym...
#
# Header: Definitions
# Content Snippet: Definitions...
#
# Header: Affiliates
# Content Snippet: Affiliates
# Companies related by common ownership or control. They can be
# financial and nonfinancial companies.
# • Our affiliates include companies oper...
#
# Header: Nonaffiliates
# Content Snippet: Nonaffiliates
# Companies not related by common ownership or control.  They can be
# financial and nonfinancial companies.
# • Nonaffiliates with which we s...
#
# Header: Integrations &
# Content Snippet: Integrations &
# custom solutions
# Stripe App
# Marketplace
# Partner ecosystem
# Professional
# services...
#
# Header: Developers
# Content Snippet: Developers
# Documentation
# API reference
# API status
# API changelog
# Stripe Apps
# Annual conference
# Privacy & terms
# Prohibited &
# restricted
# businesses
# Licen...
#
#
# Processed Result for /content/drive/MyDrive/compliance/policies/stripe.pdf:
# Total number of chunks created: 59
#
# Header: Privacy Policy
# Content Snippet: Privacy Policy
# Privacy Policy
# https://stripe.com/privacy
# 2 of 33
# 10/27/24, 1:41 PM
# entities (“Business Users”) that directly and indirectly provide us...
#
# Header: 1. Personal Data we collect and how we
# Content Snippet: 1. Personal Data we collect and how we...
#
# Header: use and share it
# Content Snippet: use and share it
# Our collection and use of Personal Data differs based on whether you are an End User, End
# Customer, Representative, or Visitor, and t...
#
# Header: 1.1 End Users
# Content Snippet: 1.1 End Users
# We provide End User Services when we provide the Services directly to you for your personal
# use (e.g., Link). Additional details regardi...
#
# Header: a. Personal Data we collect about End Users
# Content Snippet: a. Personal Data we collect about End Users
# Using Link or Connecting your bank account.
# Stripe offers a service called "Link," which
# allows you to sto...
#
# Header: Identity/Verification Services
# Content Snippet: Identity/Verification Services
# . We offer an identity verification service that automates the
# comparison of your identity document (such as a driver’s...
#
# Header: b. How we use and share Personal Data of End Users
# Content Snippet: b. How we use and share Personal Data of End Users...
#
# Header: Services
# Content Snippet: Services
# . We use and share your Personal Data to provide the End User Services to you, which
# includes support, personalization (such as language pref...
#
# Header: Our Business Users.
# Content Snippet: Our Business Users.
# When you use Link to make payments, we share your Transaction Data
# with the Business Users you choose to do business with.
# Learn M...
#
# Header: Transactions
# Content Snippet: Transactions
# . When you use Link to make payments, we use your Personal Data (such as
# name, contact information, payment method details) saved with us...
#
# Header: Advertising
# Content Snippet: Advertising
# . We may use your Personal Data to assess your eligibility for, and offer you, other
# End User Services or promote existing End User Servic...
#
# Header: 1.2 End Customers
# Content Snippet: 1.2 End Customers
# Stripe provides various Business Services to our Business Users, which include in-person or
# online checkout payment processing or pr...
#
# Header: a. Personal Data we collect about End Customers
# Content Snippet: a. Personal Data we collect about End Customers...
#
# Header: Transaction Data.
# Content Snippet: Transaction Data.
# If you're an End Customer making payments to, receiving refunds from,
# initiating a purchase or donation, or otherwise transacting wi...
#
# Header: Identity/Verification Information
# Content Snippet: Identity/Verification Information
# . Stripe provides a verification and fraud prevention Service
# that our Business Users can use to verify Personal Dat...
#
# Header: b. How we use and share Personal Data of End Customers
# Content Snippet: b. How we use and share Personal Data of End Customers
# To provide our Business Services to our Business Users, we use and share End Customers'
# Persona...
#
# Header: 1.3 Representatives
# Content Snippet: 1.3 Representatives
# We collect, use, and share Personal Data from Representatives of Business Users (for
# example, business owners) to provide our Busi...
#
# Header: a. Personal Data we collect about Representatives
# Content Snippet: a. Personal Data we collect about Representatives
# Registration and contact information.
# When you register for a Stripe account for a Business
# User (in...
#
# Header: Identification Information
# Content Snippet: Identification Information
# . As a current or potential Business User, an owner of a Business
# User, or a shareholder, officer, or director of a Busines...
#
# Header: b. How we use and share Personal Data of Representatives
# Content Snippet: b. How we use and share Personal Data of Representatives
# We typically use the Personal Data of Representatives to provide the Business Services to the...
#
# Header: Business Services.
# Content Snippet: Business Services.
# We use and share Representatives’ Personal Data with Business Users to
# provide the Services requested by you or the Business User y...
#
# Header: Advertising
# Content Snippet: Advertising
# . Where allowed by applicable law, we use and share Representatives’ Personal
# Data with third parties so we can advertise and market our S...
#
# Header: 1.4 Visitors
# Content Snippet: 1.4 Visitors
# We collect, use, and share the Personal Data of Visitors. More details about how we collect,
# use, and share Visitors’ Personal Data, alon...
#
# Header: a. Personal Data we collect about Visitors
# Content Snippet: a. Personal Data we collect about Visitors
# When you browse our Sites, we receive your Personal Data, either provided directly by you or
# collected thro...
#
# Header: b. How we use and share Personal Data of Visitors
# Content Snippet: b. How we use and share Personal Data of Visitors...
#
# Header: Personalization
# Content Snippet: Personalization
# . We use the data we collect from cookies and similar technologies about you
# to measure user engagement with the content on the Sites,...
#
# Header: Advertising
# Content Snippet: Advertising
# . Where allowed by applicable law, we use and share Visitors’ Personal Data with
# third parties so we can advertise and market our Services...
#
# Header: 2. More ways we collect, use, and share
# Content Snippet: 2. More ways we collect, use, and share...
#
# Header: Personal Data
# Content Snippet: Personal Data
# In addition to the ways described above, we also process your Personal Data as follows:...
#
# Header: a. Collection of Personal Data
# Content Snippet: a. Collection of Personal Data...
#
# Header: Online Activity
# Content Snippet: Online Activity
# . Depending on the Service used and how our Business Services are
# Privacy Policy
# https://stripe.com/privacy
# 13 of 33
# 10/27/24, 1:41 PM...
#
# Header: b. Use of Personal Data.
# Content Snippet: b. Use of Personal Data.
# Besides the use of Personal Data described above, we use Personal Data in the ways listed
# below:
# Improving and Developing our...
#
# Header: Communications
# Content Snippet: Communications
# . We use the contact information we have about you to deliver our Services,
# which may involve sending codes via SMS for your authentica...
#
# Header: Minors
# Content Snippet: Minors
# . Our Services are not directed to children under the age of 13, and we request that they
# do not provide Personal Data to seek Services directl...
#
# Header: c. Sharing of Personal Data.
# Content Snippet: c. Sharing of Personal Data.
# Besides the sharing of Personal Data described above, we share Personal Data in the ways
# listed below:...
#
# Header: Stripe Affiliates
# Content Snippet: Stripe Affiliates
# . We share Personal Data with other Stripe-affiliated entities for purposes
# identified in this Policy.
# Service Providers or Processo...
#
# Header: Financial Partners
# Content Snippet: Financial Partners
# . We share Personal Data with certain Financial Partners to provide Services
# to Business Users seeking such Services as well as off...
#
# Header: Corporate Transactions
# Content Snippet: Corporate Transactions
# . If we enter or intend to enter a transaction that modifies the
# Privacy Policy
# https://stripe.com/privacy
# 16 of 33
# 10/27/24, 1...
#
# Header: 3. Legal bases for processing Personal
# Content Snippet: 3. Legal bases for processing Personal...
#
# Header: Data
# Content Snippet: Data
# For purposes of the General Data Protection Regulation and other applicable data protection
# laws, we rely on a number of legal bases to process y...
#
# Header: 4. Your rights and choices
# Content Snippet: 4. Your rights and choices
# Depending on your location and subject to applicable law, you may have choices regarding
# our collection, use, and disclosur...
#
# Header: a. Opting out of receiving electronic communications from
# Content Snippet: a. Opting out of receiving electronic communications from
# us
# If you wish to stop receiving marketing-related emails from us, you can opt-out by clicki...
#
# Header: b. Your data protection rights
# Content Snippet: b. Your data protection rights
# Depending on your location and subject to applicable law, you may have the following rights
# regarding the Personal Data...
#
# Header: c. Process for exercising your data protection rights
# Content Snippet: c. Process for exercising your data protection rights
# To exercise your data protection rights, visit our...
#
# Header: Privacy Center
# Content Snippet: Privacy Center
# or contact us as outlined
# below.
# The right to request confirmation of whether Stripe is processing Personal Data associated
# with you, a...
#
# Header: 5. Security and Retention
# Content Snippet: 5. Security and Retention
# We make reasonable efforts to provide a level of security appropriate to the risk associated
# with the processing of your Per...
#
# Header: 6. International Data Transfers
# Content Snippet: 6. International Data Transfers
# As a global business, it's sometimes necessary for us to transfer your Personal Data to
# countries other than your own,...
#
# Header: 7. Updates and notifications
# Content Snippet: 7. Updates and notifications
# We may change this Policy from time to time to reflect new services, changes in our privacy
# practices or relevant laws. T...
#
# Header: 8. Jurisdiction-specific provisions
# Content Snippet: 8. Jurisdiction-specific provisions
# Australia
# . If you are an Australian resident and dissatisfied with our handling of any complaint
# you raise under ...
#
# Header: 9. Contact us
# Content Snippet: 9. Contact us
# If you have any questions or complaints about this Policy, please
# contact us
# . If you are an End
# Customer (i.e., an individual doing bus...
#
# Header: 10. US Consumer Privacy Notice
# Content Snippet: 10. US Consumer Privacy Notice
# The following Consumer Privacy Notice applies to you if you are an individual who resides in
# the United States and obta...
#
# Header: FACTS
# Content Snippet: FACTS
# WHAT DOES STRIPE DO WITH YOUR PERSONAL INFORMATION?
# Why?
# Financial companies choose how they share your personal information.  Federal
# law gives...
#
# Header: • Social Security Number
# Content Snippet: • Social Security Number
# • Contact details
# • Account balances and transaction history
# Privacy Policy
# https://stripe.com/privacy
# 27 of 33
# 10/27/24, 1:4...
#
# Header: Questions?
# Content Snippet: Questions?
# Contact us at privacy@stripe.com or visit us at https://support.link.com
# Who we are
# Who is providing this
# notice?
# Stripe, Inc., Stripe Paym...
#
# Header: Definitions
# Content Snippet: Definitions...
#
# Header: Affiliates
# Content Snippet: Affiliates
# Companies related by common ownership or control. They can be
# financial and nonfinancial companies.
# • Our affiliates include companies oper...
#
# Header: Nonaffiliates
# Content Snippet: Nonaffiliates
# Companies not related by common ownership or control.  They can be
# financial and nonfinancial companies.
# • Nonaffiliates with which we s...
#
# Header: Integrations &
# Content Snippet: Integrations &
# custom solutions
# Stripe App
# Marketplace
# Partner ecosystem
# Professional
# services...
#
# Header: Developers
# Content Snippet: Developers
# Documentation
# API reference
# API status
# API changelog
# Stripe Apps
# Annual conference
# Privacy & terms
# Prohibited &
# restricted
# businesses
# Licen...
#
# Total number of sub-chunks created: 107
#
# Chunk 1/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Privacy Policy
# Sub-chunk 1/4
# Content Snippet: Privacy Policy
# Privacy Policy
# https://stripe.com/privacy
# 2 of 33
# 10/27/24, 1:41 PM
# entities (“Business Users”) that directly and indirectly provide us...
#
# Chunk 2/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Privacy Policy
# Sub-chunk 2/4
# Content Snippet: transactions you request. Some Transaction Data is Personal Data and may include: your
# name, email address, contact number, billing and shipping addre...
#
# Chunk 3/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Privacy Policy
# Sub-chunk 3/4
# Content Snippet: buying a pair of shoes from a Business User using Stripe Checkout for payment processing, but
# are not directly transacting with Stripe, we refer to yo...
#
# Chunk 4/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Privacy Policy
# Sub-chunk 4/4
# Content Snippet: 3. Legal bases for processing data
# 4. Your rights and choices
# 5. Security and retention
# 6. International data transfers
# 7. Updates and notifications
# 8...
#
# Chunk 5/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 1. Personal Data we collect and how we
# Sub-chunk 1/1
# Content Snippet: 1. Personal Data we collect and how we...
#
# Chunk 6/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: use and share it
# Sub-chunk 1/1
# Content Snippet: use and share it
# Our collection and use of Personal Data differs based on whether you are an End User, End
# Customer, Representative, or Visitor, and t...
#
# Chunk 7/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 1.1 End Users
# Sub-chunk 1/1
# Content Snippet: 1.1 End Users
# We provide End User Services when we provide the Services directly to you for your personal
# use (e.g., Link). Additional details regardi...
#
# Chunk 8/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: a. Personal Data we collect about End Users
# Sub-chunk 1/2
# Content Snippet: a. Personal Data we collect about End Users
# Using Link or Connecting your bank account.
# Stripe offers a service called "Link," which
# allows you to sto...
#
# Chunk 9/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: a. Personal Data we collect about End Users
# Sub-chunk 2/2
# Content Snippet: the collection of such data at any time.
# Learn More
# .
# You may also choose to store your identity documents (such as your driver’s license) using
# Link ...
#
# Chunk 10/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Identity/Verification Services
# Sub-chunk 1/1
# Content Snippet: Identity/Verification Services
# . We offer an identity verification service that automates the
# comparison of your identity document (such as a driver’s...
#
# Chunk 11/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: b. How we use and share Personal Data of End Users
# Sub-chunk 1/1
# Content Snippet: b. How we use and share Personal Data of End Users...
#
# Chunk 12/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Services
# Sub-chunk 1/1
# Content Snippet: Services
# . We use and share your Personal Data to provide the End User Services to you, which
# includes support, personalization (such as language pref...
#
# Chunk 13/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Our Business Users.
# Sub-chunk 1/1
# Content Snippet: Our Business Users.
# When you use Link to make payments, we share your Transaction Data
# with the Business Users you choose to do business with.
# Learn M...
#
# Chunk 14/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Transactions
# Sub-chunk 1/2
# Content Snippet: Transactions
# . When you use Link to make payments, we use your Personal Data (such as
# name, contact information, payment method details) saved with us...
#
# Chunk 15/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Transactions
# Sub-chunk 2/2
# Content Snippet: how we may use technology to assess the fraud risk associated with an attempted transaction
# and what information we share with Business Users and Fina...
#
# Chunk 16/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Advertising
# Sub-chunk 1/1
# Content Snippet: Advertising
# . We may use your Personal Data to assess your eligibility for, and offer you, other
# End User Services or promote existing End User Servic...
#
# Chunk 17/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 1.2 End Customers
# Sub-chunk 1/2
# Content Snippet: 1.2 End Customers
# Stripe provides various Business Services to our Business Users, which include in-person or
# online checkout payment processing or pr...
#
# Chunk 18/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 1.2 End Customers
# Sub-chunk 2/2
# Content Snippet: for its privacy practices, choices, and controls.
# We provide more comprehensive information about our collection, use, and sharing of End
# Customer Per...
#
# Chunk 19/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: a. Personal Data we collect about End Customers
# Sub-chunk 1/1
# Content Snippet: a. Personal Data we collect about End Customers...
#
# Chunk 20/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Transaction Data.
# Sub-chunk 1/1
# Content Snippet: Transaction Data.
# If you're an End Customer making payments to, receiving refunds from,
# initiating a purchase or donation, or otherwise transacting wi...
#
# Chunk 21/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Identity/Verification Information
# Sub-chunk 1/2
# Content Snippet: Identity/Verification Information
# . Stripe provides a verification and fraud prevention Service
# that our Business Users can use to verify Personal Dat...
#
# Chunk 22/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Identity/Verification Information
# Sub-chunk 2/2
# Content Snippet: Learn More
# .
# More
# . For further information about other types of Personal Data that we may collect about
# End Customers, including about your online ac...
#
# Chunk 23/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: b. How we use and share Personal Data of End Customers
# Sub-chunk 1/6
# Content Snippet: b. How we use and share Personal Data of End Customers
# To provide our Business Services to our Business Users, we use and share End Customers'
# Persona...
#
# Chunk 24/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: b. How we use and share Personal Data of End Customers
# Sub-chunk 2/6
# Content Snippet: to your transaction. As a service provider or data processor, we share Personal Data to enable
# transactions as directed by Business Users. For instanc...
#
# Chunk 25/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: b. How we use and share Personal Data of End Customers
# Sub-chunk 3/6
# Content Snippet: generate or receive when these cards are used for purchases, we also collect and utilize your
# Personal Data to provide and manage these products, incl...
#
# Chunk 26/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: b. How we use and share Personal Data of End Customers
# Sub-chunk 4/6
# Content Snippet: Learn More
# .
# Fraud detection and loss prevention
# . We use your Personal Data collected across our
# Services to detect and prevent losses for you, us, o...
#
# Chunk 27/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: b. How we use and share Personal Data of End Customers
# Sub-chunk 5/6
# Content Snippet: third parties (like additional third party service providers other than Stripe). Please review the
# Business User’s privacy policy for more information...
#
# Chunk 28/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: b. How we use and share Personal Data of End Customers
# Sub-chunk 6/6
# Content Snippet: Stripe account, including data related to its End Customers, via Stripe Connect.
# Sharing information that you have provided to us with a Business User...
#
# Chunk 29/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 1.3 Representatives
# Sub-chunk 1/1
# Content Snippet: 1.3 Representatives
# We collect, use, and share Personal Data from Representatives of Business Users (for
# example, business owners) to provide our Busi...
#
# Chunk 30/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: a. Personal Data we collect about Representatives
# Sub-chunk 1/1
# Content Snippet: a. Personal Data we collect about Representatives
# Registration and contact information.
# When you register for a Stripe account for a Business
# User (in...
#
# Chunk 31/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Identification Information
# Sub-chunk 1/2
# Content Snippet: Identification Information
# . As a current or potential Business User, an owner of a Business
# User, or a shareholder, officer, or director of a Busines...
#
# Chunk 32/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Identification Information
# Sub-chunk 2/2
# Content Snippet: share Personal Data
# section below....
#
# Chunk 33/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: b. How we use and share Personal Data of Representatives
# Sub-chunk 1/1
# Content Snippet: b. How we use and share Personal Data of Representatives
# We typically use the Personal Data of Representatives to provide the Business Services to the...
#
# Chunk 34/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Business Services.
# Sub-chunk 1/4
# Content Snippet: Business Services.
# We use and share Representatives’ Personal Data with Business Users to
# provide the Services requested by you or the Business User y...
#
# Chunk 35/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Business Services.
# Sub-chunk 2/4
# Content Snippet: party apps or services the Business User chooses to use alongside our Business Services.
# Here are common examples of such sharing:
# If you are a Busine...
#
# Chunk 36/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Business Services.
# Sub-chunk 3/4
# Content Snippet: terms of service violations. Stripe may share Representatives' Personal Data with Business
# Payment method providers, like Visa or WeChat Pay, require ...
#
# Chunk 37/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Business Services.
# Sub-chunk 4/4
# Content Snippet: laundering and sanctions screening in accordance with applicable law....
#
# Chunk 38/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Advertising
# Sub-chunk 1/1
# Content Snippet: Advertising
# . Where allowed by applicable law, we use and share Representatives’ Personal
# Data with third parties so we can advertise and market our S...
#
# Chunk 39/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 1.4 Visitors
# Sub-chunk 1/1
# Content Snippet: 1.4 Visitors
# We collect, use, and share the Personal Data of Visitors. More details about how we collect,
# use, and share Visitors’ Personal Data, alon...
#
# Chunk 40/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: a. Personal Data we collect about Visitors
# Sub-chunk 1/1
# Content Snippet: a. Personal Data we collect about Visitors
# When you browse our Sites, we receive your Personal Data, either provided directly by you or
# collected thro...
#
# Chunk 41/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: b. How we use and share Personal Data of Visitors
# Sub-chunk 1/1
# Content Snippet: b. How we use and share Personal Data of Visitors...
#
# Chunk 42/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Personalization
# Sub-chunk 1/1
# Content Snippet: Personalization
# . We use the data we collect from cookies and similar technologies about you
# to measure user engagement with the content on the Sites,...
#
# Chunk 43/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Advertising
# Sub-chunk 1/2
# Content Snippet: Advertising
# . Where allowed by applicable law, we use and share Visitors’ Personal Data with
# third parties so we can advertise and market our Services...
#
# Chunk 44/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Advertising
# Sub-chunk 2/2
# Content Snippet: Personal Data, please see the
# More ways we collect, use, and share Personal Data
# section
# below....
#
# Chunk 45/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 2. More ways we collect, use, and share
# Sub-chunk 1/1
# Content Snippet: 2. More ways we collect, use, and share...
#
# Chunk 46/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Personal Data
# Sub-chunk 1/1
# Content Snippet: Personal Data
# In addition to the ways described above, we also process your Personal Data as follows:...
#
# Chunk 47/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: a. Collection of Personal Data
# Sub-chunk 1/1
# Content Snippet: a. Collection of Personal Data...
#
# Chunk 48/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Online Activity
# Sub-chunk 1/2
# Content Snippet: Online Activity
# . Depending on the Service used and how our Business Services are
# Privacy Policy
# https://stripe.com/privacy
# 13 of 33
# 10/27/24, 1:41 PM...
#
# Chunk 49/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Online Activity
# Sub-chunk 2/2
# Content Snippet: Forums and Discussion Groups
# . If our Sites allow posting of content, we collect Personal Data
# that you provide in connection with the post....
#
# Chunk 50/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: b. Use of Personal Data.
# Sub-chunk 1/1
# Content Snippet: b. Use of Personal Data.
# Besides the use of Personal Data described above, we use Personal Data in the ways listed
# below:
# Improving and Developing our...
#
# Chunk 51/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Communications
# Sub-chunk 1/5
# Content Snippet: Communications
# . We use the contact information we have about you to deliver our Services,
# which may involve sending codes via SMS for your authentica...
#
# Chunk 52/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Communications
# Sub-chunk 2/5
# Content Snippet: 14 of 33
# 10/27/24, 1:41 PM
# information we have about you to provide information about our Services and our affiliates’
# services, invite you to partici...
#
# Chunk 53/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Communications
# Sub-chunk 3/5
# Content Snippet: program, or promotion, we use the Personal Data you provide to manage the offer, program,
# or promotion. We also use the Personal Data you provide, alo...
#
# Chunk 54/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Communications
# Sub-chunk 4/5
# Content Snippet: you, or from our Business Users, Financial Partners, and other third parties for the same
# purposes. Furthermore, to protect our Services, we may recei...
#
# Chunk 55/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Communications
# Sub-chunk 5/5
# Content Snippet: doing business with restricted persons or in certain business fields, among other legal
# obligations. For example, we may monitor transaction patterns ...
#
# Chunk 56/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Minors
# Sub-chunk 1/1
# Content Snippet: Minors
# . Our Services are not directed to children under the age of 13, and we request that they
# do not provide Personal Data to seek Services directl...
#
# Chunk 57/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: c. Sharing of Personal Data.
# Sub-chunk 1/1
# Content Snippet: c. Sharing of Personal Data.
# Besides the sharing of Personal Data described above, we share Personal Data in the ways
# listed below:...
#
# Chunk 58/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Stripe Affiliates
# Sub-chunk 1/1
# Content Snippet: Stripe Affiliates
# . We share Personal Data with other Stripe-affiliated entities for purposes
# identified in this Policy.
# Service Providers or Processo...
#
# Chunk 59/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Financial Partners
# Sub-chunk 1/1
# Content Snippet: Financial Partners
# . We share Personal Data with certain Financial Partners to provide Services
# to Business Users seeking such Services as well as off...
#
# Chunk 60/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Corporate Transactions
# Sub-chunk 1/2
# Content Snippet: Corporate Transactions
# . If we enter or intend to enter a transaction that modifies the
# Privacy Policy
# https://stripe.com/privacy
# 16 of 33
# 10/27/24, 1...
#
# Chunk 61/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Corporate Transactions
# Sub-chunk 2/2
# Content Snippet: Services, rights, privacy, safety, and property of Stripe, you, and others, including against
# malicious or fraudulent activity; and to respond to vali...
#
# Chunk 62/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 3. Legal bases for processing Personal
# Sub-chunk 1/1
# Content Snippet: 3. Legal bases for processing Personal...
#
# Chunk 63/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Data
# Sub-chunk 1/5
# Content Snippet: Data
# For purposes of the General Data Protection Regulation and other applicable data protection
# laws, we rely on a number of legal bases to process y...
#
# Chunk 64/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Data
# Sub-chunk 2/5
# Content Snippet: Accounting, auditing, and billing activities; and
# Privacy Policy
# https://stripe.com/privacy
# 17 of 33
# 10/27/24, 1:41 PM
# service activities.
# b. Legal Co...
#
# Chunk 65/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Data
# Sub-chunk 3/5
# Content Snippet: business interests to process your Personal Data. The following list provides an example of
# the business purposes for which we have a legitimate inter...
#
# Chunk 66/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Data
# Sub-chunk 4/5
# Content Snippet: through understanding their effectiveness and optimizing our digital assets;
# Analysis and advertisement of our Services, and related improvements;
# Agg...
#
# Chunk 67/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Data
# Sub-chunk 5/5
# Content Snippet: you have the right to withdraw your consent at any time, and such a withdrawal will not impact
# the legality of processing performed based on the conse...
#
# Chunk 68/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 4. Your rights and choices
# Sub-chunk 1/1
# Content Snippet: 4. Your rights and choices
# Depending on your location and subject to applicable law, you may have choices regarding
# our collection, use, and disclosur...
#
# Chunk 69/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: a. Opting out of receiving electronic communications from
# Sub-chunk 1/1
# Content Snippet: a. Opting out of receiving electronic communications from
# us
# If you wish to stop receiving marketing-related emails from us, you can opt-out by clicki...
#
# Chunk 70/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: b. Your data protection rights
# Sub-chunk 1/1
# Content Snippet: b. Your data protection rights
# Depending on your location and subject to applicable law, you may have the following rights
# regarding the Personal Data...
#
# Chunk 71/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: c. Process for exercising your data protection rights
# Sub-chunk 1/1
# Content Snippet: c. Process for exercising your data protection rights
# To exercise your data protection rights, visit our...
#
# Chunk 72/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Privacy Center
# Sub-chunk 1/2
# Content Snippet: Privacy Center
# or contact us as outlined
# below.
# The right to request confirmation of whether Stripe is processing Personal Data associated
# with you, a...
#
# Chunk 73/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: Privacy Center
# Sub-chunk 2/2
# Content Snippet: previous consent;
# The right to object to the processing of your Personal Data if we are processing your data
# based on our legitimate interests; unless...
#
# Chunk 74/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 5. Security and Retention
# Sub-chunk 1/2
# Content Snippet: 5. Security and Retention
# We make reasonable efforts to provide a level of security appropriate to the risk associated
# with the processing of your Per...
#
# Chunk 75/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 5. Security and Retention
# Sub-chunk 2/2
# Content Snippet: contact us
# immediately.
# We retain your Personal Data for as long as we continue to provide the Services to you or our
# Business Users, or for a period ...
#
# Chunk 76/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 6. International Data Transfers
# Sub-chunk 1/2
# Content Snippet: 6. International Data Transfers
# As a global business, it's sometimes necessary for us to transfer your Personal Data to
# countries other than your own,...
#
# Chunk 77/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 6. International Data Transfers
# Sub-chunk 2/2
# Content Snippet: such transfer. In certain situations, we may be required to disclose Personal Data in response
# to lawful requests from officials, such as law enforcem...
#
# Chunk 78/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 7. Updates and notifications
# Sub-chunk 1/2
# Content Snippet: 7. Updates and notifications
# We may change this Policy from time to time to reflect new services, changes in our privacy
# practices or relevant laws. T...
#
# Chunk 79/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 7. Updates and notifications
# Sub-chunk 2/2
# Content Snippet: International Data Transfer Addendum issued by the Information Commissioner’s Office. You
# can obtain a copy of the relevant Standard Contractual Claus...
#
# Chunk 80/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 8. Jurisdiction-specific provisions
# Sub-chunk 1/13
# Content Snippet: 8. Jurisdiction-specific provisions
# Australia
# . If you are an Australian resident and dissatisfied with our handling of any complaint
# you raise under ...
#
# Chunk 81/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 8. Jurisdiction-specific provisions
# Sub-chunk 2/13
# Content Snippet: Stripe’s Chief Privacy Officer is the person in charge of personal information, including
# under the Quebec Private Sector Act.  You may contact them v...
#
# Chunk 82/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 8. Jurisdiction-specific provisions
# Sub-chunk 3/13
# Content Snippet: dpo@stripe.com
# . If you are
# a resident of the EEA or if Stripe Payments Europe Limited is identified as your data controller,
# and you believe our proc...
#
# Chunk 83/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 8. Jurisdiction-specific provisions
# Sub-chunk 4/13
# Content Snippet: 23 of 33
# 10/27/24, 1:41 PM
# once the DPDPA is enacted. Further, the term “data controller” includes “data fiduciaries,” and
# the term “data subject” inc...
#
# Chunk 84/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 8. Jurisdiction-specific provisions
# Sub-chunk 5/13
# Content Snippet: process as required under applicable laws. Your provision of Aadhaar details is purely
# voluntary, and you may provide other identification documents a...
#
# Chunk 85/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 8. Jurisdiction-specific provisions
# Sub-chunk 6/13
# Content Snippet: the Implementation of Electronic Systems and Transactions, and Minister of Communication
# and Informatics Regulation No. 20 of 2016 on Personal Data Pr...
#
# Chunk 86/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 8. Jurisdiction-specific provisions
# Sub-chunk 7/13
# Content Snippet: protect your data and where your data is located, please see above or contact us as described
# below. For a description of foreign systems and framewor...
#
# Chunk 87/107
# PDF Path: /content/drive/MyDrive/compliance/policies/stripe.pdf
# Header: 8. Jurisdiction-specific provisions
# Sub-chunk 8/13
# Content Snippet: dpo@stripe.com
# .
# Switzerland
# . In this Policy, “applicable law” includes the Swiss Federal Act on Data Protection
# (FADP), as revised. To exercise your...
#
# Chunk 88/107
# ...
# --------------------------------------------------
# Document 72:
# Page Content: Privacy Center
# or contact us as outlined
# below.
# The right to request confirmation of whether Stripe ...
# Metadata: {'chunk_number': 72, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Privacy Center', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 73:
# Page Content: previous consent;
# The right to object to the processing of your Personal Data if we are processing y...
# Metadata: {'chunk_number': 73, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Privacy Center', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 74:
# Page Content: 5. Security and Retention
# We make reasonable efforts to provide a level of security appropriate to t...
# Metadata: {'chunk_number': 74, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '5. Security and Retention', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 75:
# Page Content: contact us
# immediately.
# We retain your Personal Data for as long as we continue to provide the Servi...
# Metadata: {'chunk_number': 75, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '5. Security and Retention', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 76:
# Page Content: 6. International Data Transfers
# As a global business, it's sometimes necessary for us to transfer yo...
# Metadata: {'chunk_number': 76, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '6. International Data Transfers', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 77:
# Page Content: such transfer. In certain situations, we may be required to disclose Personal Data in response
# to la...
# Metadata: {'chunk_number': 77, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '6. International Data Transfers', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 78:
# Page Content: 7. Updates and notifications
# We may change this Policy from time to time to reflect new services, ch...
# Metadata: {'chunk_number': 78, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '7. Updates and notifications', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 79:
# Page Content: International Data Transfer Addendum issued by the Information Commissioner’s Office. You
# can obtain...
# Metadata: {'chunk_number': 79, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '7. Updates and notifications', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 80:
# Page Content: 8. Jurisdiction-specific provisions
# Australia
# . If you are an Australian resident and dissatisfied w...
# Metadata: {'chunk_number': 80, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '8. Jurisdiction-specific provisions', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 81:
# Page Content: Stripe’s Chief Privacy Officer is the person in charge of personal information, including
# under the ...
# Metadata: {'chunk_number': 81, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '8. Jurisdiction-specific provisions', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 82:
# Page Content: dpo@stripe.com
# . If you are
# a resident of the EEA or if Stripe Payments Europe Limited is identified...
# Metadata: {'chunk_number': 82, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '8. Jurisdiction-specific provisions', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 83:
# Page Content: 23 of 33
# 10/27/24, 1:41 PM
# once the DPDPA is enacted. Further, the term “data controller” includes “...
# Metadata: {'chunk_number': 83, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '8. Jurisdiction-specific provisions', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 84:
# Page Content: process as required under applicable laws. Your provision of Aadhaar details is purely
# voluntary, an...
# Metadata: {'chunk_number': 84, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '8. Jurisdiction-specific provisions', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 85:
# Page Content: the Implementation of Electronic Systems and Transactions, and Minister of Communication
# and Informa...
# Metadata: {'chunk_number': 85, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '8. Jurisdiction-specific provisions', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 86:
# Page Content: protect your data and where your data is located, please see above or contact us as described
# below....
# Metadata: {'chunk_number': 86, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '8. Jurisdiction-specific provisions', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 87:
# Page Content: dpo@stripe.com
# .
# Switzerland
# . In this Policy, “applicable law” includes the Swiss Federal Act on Da...
# Metadata: {'chunk_number': 87, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '8. Jurisdiction-specific provisions', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 88:
# Page Content: Privacy Act ( "CCPA"), Colorado Privacy Act, Connecticut Act Concerning Personal Data Privacy
# and On...
# Metadata: {'chunk_number': 88, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '8. Jurisdiction-specific provisions', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 89:
# Page Content: categories of sources of personal information; and categories of third parties with
# whom we disclose...
# Metadata: {'chunk_number': 89, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '8. Jurisdiction-specific provisions', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 90:
# Page Content: we may provide the data to third party partners, such as advertising partners,
# analytics providers, ...
# Metadata: {'chunk_number': 90, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '8. Jurisdiction-specific provisions', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 91:
# Page Content: using the methods described in the Contact Us section below. Please note that rights
# under some U.S....
# Metadata: {'chunk_number': 91, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '8. Jurisdiction-specific provisions', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 92:
# Page Content: submit a request on your behalf by contacting us using the methods described in the
# Contact Us secti...
# Metadata: {'chunk_number': 92, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '8. Jurisdiction-specific provisions', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 93:
# Page Content: 9. Contact us
# If you have any questions or complaints about this Policy, please
# contact us
# . If you ...
# Metadata: {'chunk_number': 93, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '9. Contact us', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 94:
# Page Content: 10. US Consumer Privacy Notice
# The following Consumer Privacy Notice applies to you if you are an in...
# Metadata: {'chunk_number': 94, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '10. US Consumer Privacy Notice', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 95:
# Page Content: FACTS
# WHAT DOES STRIPE DO WITH YOUR PERSONAL INFORMATION?
# Why?
# Financial companies choose how they s...
# Metadata: {'chunk_number': 95, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'FACTS', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 96:
# Page Content: • Social Security Number
# • Contact details
# • Account balances and transaction history
# Privacy Policy...
# Metadata: {'chunk_number': 96, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '• Social Security Number', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 97:
# Page Content: Services to you
# Yes
# No
# For joint marketing with other financial companies
# Yes
# No
# For our affiliates'...
# Metadata: {'chunk_number': 97, 'document_type': 'Policy', 'company_name': 'stripe', 'header': '• Social Security Number', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 98:
# Page Content: Questions?
# Contact us at privacy@stripe.com or visit us at https://support.link.com
# Who we are
# Who i...
# Metadata: {'chunk_number': 98, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Questions?', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 99:
# Page Content: Connections
# We also collect your personal information from others, such as
# Privacy Policy
# https://st...
# Metadata: {'chunk_number': 99, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Questions?', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 100:
# Page Content: Definitions...
# Metadata: {'chunk_number': 100, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Definitions', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 101:
# Page Content: Affiliates
# Companies related by common ownership or control. They can be
# financial and nonfinancial ...
# Metadata: {'chunk_number': 101, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Affiliates', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 102:
# Page Content: Nonaffiliates
# Companies not related by common ownership or control.  They can be
# financial and nonfi...
# Metadata: {'chunk_number': 102, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Nonaffiliates', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 103:
# Page Content: Other important information
# Vermont: If your account with us is associated with a Vermont billing ad...
# Metadata: {'chunk_number': 103, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Nonaffiliates', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 104:
# Page Content: or provide products and services you request, at your instruction, as required for institution
# risk ...
# Metadata: {'chunk_number': 104, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Nonaffiliates', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 105:
# Page Content: Data Processing Agreement
# Data Transfers Addendum
# Stripe Privacy Center
# Intellectual Property
# Intell...
# Metadata: {'chunk_number': 105, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Nonaffiliates', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 106:
# Page Content: Integrations &
# custom solutions
# Stripe App
# Marketplace
# Partner ecosystem
# Professional
# services...
# Metadata: {'chunk_number': 106, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Integrations &', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# Document 107:
# Page Content: Developers
# Documentation
# API reference
# API status
# API changelog
# Stripe Apps
# Annual conference
# Privac...
# Metadata: {'chunk_number': 107, 'document_type': 'Policy', 'company_name': 'stripe', 'header': 'Developers', 'doc_link': '/content/drive/MyDrive/compliance/policies/stripe.pdf'}
# --------------------------------------------------
# [DEBUG] Connected to Qdrant cloud instance
# [DEBUG] Detected embedding size: 768
# <ipython-input-3-8f0a4e2b2ddc>:629: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   qdrant_client.recreate_collection(
# [DEBUG] Collection 'policy_pulse_db' recreated successfully
# [DEBUG] Documents added to Qdrant collection
# [TEST] Applying retrieval filter with company_name: 'stripe'
# Ask your question: How does Stripe balance GDPR compliance with global financial regulations?
# [PROCESSING] Question: How does Stripe balance GDPR compliance with global financial regulations?
# extracted company name: stripe
# extracted question_type: Policy
# [PROCESSING] Retrieving Policy content for question: How does Stripe balance GDPR compliance with global financial regulations? (stripe)
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# [INFO] Retrieving GDPR articles for the question using semantic similarity
#
# Returning the following to the UI:
#
# Main Answer:
# Stripe ensures GDPR compliance while handling internationaldata transfers to countries with varying data protection regulations, primarilythe United States, by balancing both GDPR requirements andglobalfinancialregulations. This approach enables themto meet theirlegal and regulatory obligations, detect and preventfraud, complywith tax, accounting, and financial reportingrequirements, andrespond tovalid legalrequests fromauthorities.
#
# Key Points:
# • Legal and Regulatory Obligations: Complies with laws and regulations whentransferring personal data between regions, ensuring adherence toprivacylaws like GDPR.
# • Fraud Detection & Prevention Activities: Enables effectivemonitoring,detection, and prevention of maliciousor fraudulentactivity across itsplatform, protecting users and maintaining trust.
# • Financial Reporting Requirements: Adheres totax,accounting, and financialreportingsystemsfor proper record keeping andtransparency.
# • ValidLegalRequests: Responds tolegitimate demandsfromcourts,lawenforcementagencies,regulators,andothergovernmentauthorities, safeguarding nationalsecurityinterests and upholding ruleoflawprinciples.
#
# /content/drive/MyDrive/compliance/policies/stripe.pdf, /content/drive/MyDrive/compliance/policies/stripe.pdf, /content/drive/MyDrive/compliance/policies/stripe.pdf, /content/drive/MyDrive/compliance/policies/stripe.pdf
