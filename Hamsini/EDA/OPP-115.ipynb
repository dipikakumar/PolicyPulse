# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
import matplotlib.pyplot as plt
import seaborn as sns
import os
import plotly.express as px
import json
pd.set_option('display.max_colwidth', None)
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/UCB-MIDS/SEM-6/Capstone/Compliance/OPP-115/annotations/'
annotations_df = pd.read_csv(file_path + '1713_latinpost.com.csv')

# Inspect the first few rows of the data
annotations_df.head(1)
# Out:
#    21360  test_category_labeling_highlight_upitt   95  3843  0  Other  \
# 0  20756  test_category_labeling_highlight_upitt  103  3843  1  Other
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  {"Other Type": {"selectedText": "Privacy Policy Last Modified: March 25, 2013", "startIndexInSegment": 0, "endIndexInSegment": 54, "value": "Introductory/Generic"}}  \
# 0  {"Other Type": {"selectedText": "This is the privacy policy (\"Privacy Policy\") for LatinPost.com (\"Site,\" \"we,\" \"us,\" or \"our\"). This Privacy Policy is intended to explain our privacy practices and covers the following areas: When This Privacy Policy Applies. U.S. Governing Law; Safe Harbor. Collection and Use of Personal Information and Other Information (Other than Wireless Marketing Services and Associated Promotional Opportunities). Opting-out of Certain Uses of your Personal Information and Other Information (Other than Wireless Marketing Services and Associated Promotional Opportunities). Wireless Marketing Services and Associated Promotional Opportunities. Sharing and Disclosure of Personal Information and Other Information. Reviewing, Updating or Deleting Certain Information. Protection of Information. Your California Privacy Rights. Changes to this Privacy Policy and Notice. Miscellaneous.", "startIndexInSegment": 0, "endIndexInSegment": 1118, "value": "Introductory/Generic"}}
#
#    3/25/13  http://www.latinpost.com/privacypolicy
# 0  3/25/13  http://www.latinpost.com/privacypolicy

# %%
annotations_df.shape
# Out:
# (531, 9)

# %%
annotations_df.columns
# Out:
# Index(['21360', 'test_category_labeling_highlight_upitt', '95', '3843', '0',
#        'Other',
#        '{"Other Type": {"selectedText": "Privacy Policy Last Modified: March 25, 2013", "startIndexInSegment": 0, "endIndexInSegment": 54, "value": "Introductory/Generic"}}',
#        '3/25/13', 'http://www.latinpost.com/privacypolicy'],
#       dtype='object')

# %%
column_headers = ['doc_id', 'test_category', 'segment_number', 'unique_polciy_identifier', 'label', 'policy_category', 'segment_details', 'policy_date', 'url']

# %%
annotations_df.columns = column_headers

# %%
annotations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 531 entries, 0 to 530
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   doc_id                    531 non-null    int64
#  1   test_category             531 non-null    object
#  2   segment_number            531 non-null    int64
#  3   unique_polciy_identifier  531 non-null    int64
#  4   label                     531 non-null    int64
#  5   policy_category           531 non-null    object
#  6   segment_details           531 non-null    object
#  7   policy_date               531 non-null    object
#  8   url                       531 non-null    object
# dtypes: int64(4), object(5)
# memory usage: 37.5+ KB

# %%
annotations_df['policy_date'] = pd.to_datetime(annotations_df['policy_date'], format='%m/%d/%y')

annotations_df['year'] = annotations_df['policy_date'].dt.year
annotations_df[['policy_date', 'year']].head()
# Out:
#   policy_date  year
# 0  2013-03-25  2013
# 1  2013-03-25  2013
# 2  2013-03-25  2013
# 3  2013-03-25  2013
# 4  2013-03-25  2013

# %%
annotations_df.head(1)
# Out:
#    doc_id                           test_category  segment_number  \
# 0   20756  test_category_labeling_highlight_upitt             103
#
#    unique_polciy_identifier  label policy_category  \
# 0                      3843      1           Other
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       segment_details  \
# 0  {"Other Type": {"selectedText": "This is the privacy policy (\"Privacy Policy\") for LatinPost.com (\"Site,\" \"we,\" \"us,\" or \"our\"). This Privacy Policy is intended to explain our privacy practices and covers the following areas: When This Privacy Policy Applies. U.S. Governing Law; Safe Harbor. Collection and Use of Personal Information and Other Information (Other than Wireless Marketing Services and Associated Promotional Opportunities). Opting-out of Certain Uses of your Personal Information and Other Information (Other than Wireless Marketing Services and Associated Promotional Opportunities). Wireless Marketing Services and Associated Promotional Opportunities. Sharing and Disclosure of Personal Information and Other Information. Reviewing, Updating or Deleting Certain Information. Protection of Information. Your California Privacy Rights. Changes to this Privacy Policy and Notice. Miscellaneous.", "startIndexInSegment": 0, "endIndexInSegment": 1118, "value": "Introductory/Generic"}}
#
#   policy_date                                     url  year
# 0  2013-03-25  http://www.latinpost.com/privacypolicy  2013

# %%
print(annotations_df.shape)
# Out:
# (531, 10)

# %% [markdown]
# ### 1. Policy category distribution

# %%
category_count = annotations_df['policy_category'].value_counts()

fig = px.bar(category_count,
             x=category_count.index,
             y=category_count.values,
             labels={'x': 'Policy Category', 'y': 'Count'},
             title='Distribution of Policy Categories',
             width=1000,
             height=600)

fig.update_layout(title={'text': 'Distribution of Policy Categories', 'x':0.5, 'xanchor': 'center', 'yanchor': 'top'},xaxis_title='Policy Category' )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c58fe644-964c-4f9e-b962-79080e6b4e10" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c58fe644-964c-4f9e-b962-79080e6b4e10")) {                    Plotly.newPlot(                        "c58fe644-964c-4f9e-b962-79080e6b4e10",                        [{"alignmentgroup":"True","hovertemplate":"policy_category=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["First Party Collection\u002fUse","Third Party Sharing\u002fCollection","Other","User Choice\u002fControl","International and Specific Audiences","Data Security","User Access, Edit and Deletion","Policy Change","Data Retention"],"xaxis":"x","y":[172,124,81,80,26,21,15,11,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color" ...

# %% [markdown]
# ### 2. Text Length analysis

# %%
def extract_selected_text(segment):
    try:
        segment_dict = json.loads(segment)  # Convert string to dictionary
        # Iterate through all possible sub-fields that contain 'selectedText'
        for key, value in segment_dict.items():
            if 'selectedText' in value:
                return value.get("selectedText", "")
        return ""
    except json.JSONDecodeError:
        return ""

# Apply the function to extract 'selectedText' across all possible fields
annotations_df['selectedText'] = annotations_df['segment_details'].apply(extract_selected_text)

# %% [markdown]
# ### 3. Distribtuion of Text Length

# %%
# Create a new column 'text_length' by applying len() on 'selectedText'
annotations_df['text_length'] = annotations_df['selectedText'].apply(len)

# Display the updated DataFrame
annotations_df[['policy_category', 'selectedText', 'text_length']].head(2)
# Out:
#   policy_category  \
# 0           Other
# 1           Other
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      selectedText  \
# 0  This is the privacy policy ("Privacy Policy") for LatinPost.com ("Site," "we," "us," or "our"). This Privacy Policy is intended to explain our privacy practices and covers the following areas: When This Privacy Policy Applies. U.S. Governing Law; Safe Harbor. Collection and Use of Personal Information and Other Information (Other than Wireless Marketing Services and Associated Promotional Opportunities). Opting-out of Certain Uses of your Personal Information and Other Information (Other than Wireless Marketing Services and Associated Promotional Opportunities). Wireless Marketing Services and Associated Promotional Opportunities. Sharing and Disclosure of Personal Information and Other Information. Reviewing, Updating or Deleting Certain Information. Protection of Information. Your California Privacy Rights. Changes to this Privacy Policy and Notice. Miscellaneous.
# 1  This is the privacy policy ("Privacy Policy") for LatinPost.com ("Site," "we," "us," or "our"). This Privacy Policy is intended to explain our privacy practices and covers the following areas: When This Privacy Policy Applies. U.S. Governing Law; Safe Harbor. Collection and Use of Personal Information and Other Information (Other than Wireless Marketing Services and Associated Promotional Opportunities). Opting-out of Certain Uses of your Personal Information and Other Information (Other than Wireless Marketing Services and Associated Promotional Opportunities). Wireless Marketing Services and Associated Promotional Opportunities. Sharing and Disclosure of Personal Information and Other Information. Reviewing, Updating or Deleting Certain Information. Protection of Information. Your California Privacy Rights. Changes to this Privacy Policy and Notice. Miscellaneous.
#
#    text_length
# 0          878
# 1          878

# %%
fig = px.histogram(annotations_df, x='text_length', nbins=50, labels={'text_length': 'Text Length'},
                   title='Distribution of Policy Segment Length in Selected Segments')

# Update layout with centered title and custom size
fig.update_layout(title={'x':0.5, 'xanchor': 'center'},
                  xaxis_title='Text Length',
                  yaxis_title='Count',
                  width=800,  # Set width
                  height=500)  # Set height

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="436e74fa-c9ee-4035-ac9b-78e402ae3256" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("436e74fa-c9ee-4035-ac9b-78e402ae3256")) {                    Plotly.newPlot(                        "436e74fa-c9ee-4035-ac9b-78e402ae3256",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Text Length=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":50,"offsetgroup":"","orientation":"v","showlegend":false,"x":[878,878,4,4,4,1076,423,422,714,459,750,1132,24,1132,1132,4,4,552,4,4,42,42,33,4,4,4,77,35,35,35,35,35,35,64,58,58,36,42,42,104,4,4,4,4,21,21,21,21,21,21,21,21,21,21,21,21,5,303,223,918,41,67,35,36,4,12,4,12,4,12,4,12,12,4,12,4,12,4,12,4,12,4,12,4,12,4,12,4,12,12,12,12,12,12,12,12,12,4,4,4,4,4,4,4,4,4,1377,54,328,328,105,76,371,399,244,474,267,262,262,310,105,105,105,314,12,57,57,279,471,57,63,192,33,192,545,171,12,131,126,600,75,285,189,189,398,399,389,12,131,131,131,400,400,218,218,535,535,38,111,230,251,230,70,1509,1191,1191,213,176,271,389,4,12,42,29,4,42,38,13,13,31,31,31,322,12,27,27,27,27,27,13,30,61,24,12,12,12,12,12,12,11,16,12,12,62,12,12,13,18,15,6,195,748,267,267,241,242,359,360,799,799,1816,1816,110,263,516,263,660,660,569,534,165,106,354,354,230,665,665,26,189,130,583,564,879,879,686,686,412,413,248,248,200,200,95,29,878,700,338,273,149,459,254,1132,401,132,132,132,132,68,68,30,30,30,12,12,12,12,77,10,10,10,16,79,43,43,78,78,78,78,13,13,13,13,8,8,8,8,8,8,8,8,8,8,8,8,8,81,28,100,30,30,30,30,210,210,210,210,171,65,65,65,41,12,31,12,432,12,107,12,12,312,312,12,82,12,47,12,158,12,12,70,70,12,104,113,113,8,8,12,49,37,78,4,4,4,4,4,4,4,12,12,12,12,12,12,4,35,35,35,35,4,35,35,35,35,35,35,35,35,35,35,4,944,232,232,232,232,232,232,232,145,76,23,14,399,273,47,115,128,157,127,127,34,34,28,57,72,191,63,120,71,545,117,117,117,28,42,473,115,75,210,106,210,6,6,141,43,43,43,53,53,12,12,12,16,218,535,38,62,93,217,10,474,30,474,83,232,97,97,207,47,47,36,38,32,17,17,34,34,12,27,27,27,34,34,34,131,56,104,72,72,21,21,42,12,12,12,12,13,92,12,52,12,18,13,24,94,45,141,59,19,31,227,227,32,156,156,32,1157,118,249,395,406,59,49,137,233,19,129,35,211,142,6,19,230,69,10,665,16,16,12,190,367,879,6,6,170,314,214,229,190,95],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111 ...

# %%
empty_selected_text_count = (annotations_df['selectedText'].str.strip() == '').sum()
print(f"Number of empty selectedText entries: {empty_selected_text_count}")
# Out:
# Number of empty selectedText entries: 0

# %%
fig = px.box(annotations_df, x='policy_category', y='text_length',
             labels={'policy_category': 'Policy Category', 'text_length': 'Text Length'},
             title='Policy Length Distribution Across Policy Categories')
fig.update_layout(title={'x':0.5, 'xanchor': 'center'}, width=1000, height=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2bc6a19c-7068-46ab-abb5-1a3451c91d8a" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2bc6a19c-7068-46ab-abb5-1a3451c91d8a")) {                    Plotly.newPlot(                        "2bc6a19c-7068-46ab-abb5-1a3451c91d8a",                        [{"alignmentgroup":"True","hovertemplate":"Policy Category=%{x}\u003cbr\u003eText Length=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Other","Other","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","Other","User Choice\u002fControl","Other","International and Specific Audiences","International and Specific Audiences","International and Specific Audiences","International and Specific Audiences","Third Party Sharing\u002fCollection","International and Specific Audiences","International and Specific Audiences","First Party Collection\u002fUse","First Party Collection\u002fUse","Other","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","Data Security","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","User Choice\u002fControl","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","Other","Third Party Sharing\u002fCollection","Other","Third Party Sharing\u002fCollection","User Choice\u002fControl","Third Party Sharing\u002fCollection","Third Party Sharing\u002fCollection","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First Party Collection\u002fUse","First P ...
